# %%
import os.path
import torch
import torch.nn as nn
import torchvision
from torchvision import transforms
import pandas as pd
import dlib
import numpy as np
import copy
import pickle

# %% [markdown]
# Loading mode, get test_img names etc.

# %%
# input labels.
label = pd.read_csv("labels/fairface_label_val.csv")
imgs_path = "fairface-img-margin025-trainval/val"
img_names = [os.path.join(imgs_path, x) for x in os.listdir(imgs_path)]
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")

model_fair_7 = torchvision.models.resnet34(pretrained=True)
model_fair_7.fc = nn.Linear(model_fair_7.fc.in_features, 9)
# if runs on a machine without GPU, should do map_location=torch.device('cpu')
#model_fair_7.load_state_dict(torch.load('fair_face_models/fairface_alldata_20191111.pt')) 
model_fair_7.load_state_dict(torch.load('fair_face_models/my_fairface_model_biased.pt'))
model_fair_7 = model_fair_7.to(device)


# trans

trans = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
# Out:
# /home/clydechx/FairFace/env/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/clydechx/FairFace/env/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %% [markdown]
# Start running the model.

# %%
# # Define a hook for all ReLU layers to compute the sum of activations of each filter
# activation = {}
# def relu_hook(module, input, output, layer_name):
#     activation[layer_name] = output.detach()
# # Register the hook for all ReLU layers
# for layer_name, layer in model.named_modules():
#     if isinstance(layer, torch.nn.ReLU):
#         layer.register_forward_hook(relu_hook, layer_name=layer_name)
num_filters = {}
activation = {}
filter_sums = {}
def get_activation(name):
    def hook(model, input, output):
        # Squeeze the tensor to remove the dimension with size 1
        squeezed_tensor = torch.squeeze(output.detach())
        activation[name] = squeezed_tensor
        # If squeezed_tensor has more than one dimension, flatten it
        if len(squeezed_tensor.shape) > 1:
            flattened_tensor = torch.flatten(squeezed_tensor, start_dim=1)
        else:
            flattened_tensor = squeezed_tensor
        # Sum along the second dimension if it exists, otherwise keep the tensor as is
        if flattened_tensor.dim() > 1:
            summed_tensor = flattened_tensor.sum(dim=1)
        else:
            summed_tensor = flattened_tensor
        # Convert the tensor to a list
        summed_list = summed_tensor.tolist()
        filter_sums[name] = summed_list
        num_filters[name] = len(summed_list)
    return hook

for name, layer in model_fair_7.named_modules():
    if isinstance(layer, torch.nn.ReLU):
        layer.register_forward_hook(get_activation(name))

# %%
# Define class labels for CIFAR-10
classes = ['Black+Female', 'Black+Male', 'East Asian+Female', 'East Asian+Male', 'Indian+Female', 'Indian+Male', 'Latino_Hispanic+Female', 'Latino_Hispanic+Male', 'Middle Eastern+Female', 'Middle Eastern+Male', 'Southeast Asian+Female', 'Southeast Asian+Male', 'White+Female', 'White+Male']
# Define variables to track accuracy and class-wise accuracy
correct = 0
total = 0
class_correct = [0] * 14
class_total = [0] * 14



# in FairFace model we have the following map.
race_dict = {
            0: 'White',
            1: 'Black',
            2: 'Latino_Hispanic',
            3: 'East Asian',
            4: 'Southeast Asian',
            5: 'Indian',
            6: 'Middle Eastern'
        }
gender_dict = { 0:'Male' , 1 :'Female'}
# this is a map from race and gender to class.
my_class_map = {
    (1, 1): 0,
    (1, 0): 1,
    (3, 1): 2,
    (3, 0): 3,
    (5, 1): 4,
    (5, 0): 5,
    (2, 1): 6,
    (2, 0): 7,
    (6, 1): 8,
    (6, 0): 9,
    (4, 1): 10,
    (4, 0): 11,
    (0, 1): 12,
    (0, 0): 13
}

image_predictation_result = {cl: {} for cl in range(len(classes))}
activation_all_images = []
filtersum_all_images = []
miss_predicated_images = []
# Set the model to evaluation mode
model_fair_7.eval()
my_label = pd.read_csv("labels/fairface_label_val.csv")
for index, img_name in enumerate(img_names):
    if index % 1000 == 0:
        print("Predicting... {}/{}".format(index, len(img_names)))
    img_name_in_label =  'val/' +img_name.split('/')[-1]
    label_row = my_label[my_label['file'] == img_name_in_label].iloc[0]
    
    # load image, run model.
    image = dlib.load_rgb_image(img_name)
    image = trans(image)
    image = image.view(1, 3, 224, 224)  # reshape image to match model dimensions (1 batch size)
    image = image.to(device)
    
    outputs = model_fair_7(image)
    outputs = outputs.cpu().detach().numpy()
    outputs = np.squeeze(outputs)
    
    race_outputs = outputs[:7]
    gender_outputs = outputs[7:9]
    
    race_score = np.exp(race_outputs) / np.sum(np.exp(race_outputs))
    gender_score = np.exp(gender_outputs) / np.sum(np.exp(gender_outputs))

    race_pred = np.argmax(race_score)
    gender_pred = np.argmax(gender_score)

    predict_class = my_class_map[(race_pred,gender_pred)]
    label_class_name = label_row['race']+"+" + label_row['gender']
    label_class = classes.index(label_class_name)
    
    
    total +=1
    class_total[label_class] += 1
    image_predictation_result[label_class ][index] = predict_class
    filtersum_all_images.append(copy.deepcopy(filter_sums))
    
    # predict correctly 
    if predict_class == label_class:
        correct+=1
        class_correct[label_class]+=1
    # predict wrongly
    else:
        miss_predicated_images.append(index)
        print("Predicted label: {}, Ground truth: {}".format(predict_class, label_class))
# Out:
# Predicting... 0/10954
# Predicted label: 3, Ground truth: 11
# Predicted label: 9, Ground truth: 5
# Predicted label: 2, Ground truth: 10
# Predicted label: 1, Ground truth: 0
# Predicted label: 8, Ground truth: 12
# Predicted label: 9, Ground truth: 13
# Predicted label: 3, Ground truth: 11
# Predicted label: 5, Ground truth: 10
# Predicted label: 3, Ground truth: 11
# Predicted label: 11, Ground truth: 3
# Predicted label: 9, Ground truth: 5
# Predicted label: 11, Ground truth: 7
# Predicted label: 10, Ground truth: 2
# Predicted label: 5, Ground truth: 1
# Predicted label: 2, Ground truth: 4
# Predicted label: 10, Ground truth: 2
# Predicted label: 2, Ground truth: 8
# Predicted label: 12, Ground truth: 8
# Predicted label: 7, Ground truth: 11
# Predicted label: 7, Ground truth: 5
# Predicted label: 6, Ground truth: 4
# Predicted label: 12, Ground truth: 6
# Predicted label: 8, Ground truth: 4
# Predicted label: 12, Ground truth: 8
# Predicted label: 13, Ground truth: 5
# Predicted label: 12, Ground truth: 13
# Predicted label: 10, Ground truth: 2
# Predicted label: 8, Ground truth: 7
# Predicted label: 2, Ground truth: 10
# Predicted label: 5, Ground truth: 7
# Predicted label: 7, Ground truth: 13
# Predicted label: 3, Ground truth: 10
# Predicted label: 9, Ground truth: 5
# Predicted label: 4, Ground truth: 12
# Predicted label: 10, Ground truth: 6
# Predicted label: 13, Ground truth: 7
# Predicted label: 10, Ground truth: 0
# Predicted label: 3, Ground truth: 11
# Predicted label: 7, Ground truth: 13
# Predicted label: 7, Ground truth: 6
# Predicted label: 5, Ground truth: 11
# Predicted label: 7, Ground truth: 9
# Predicted label: 3, Ground truth: 11
# Predicted label: 9, Ground truth: 4
# Predicted label: 13, Ground truth: 11
# Predicted label: 2, Ground truth: 10
# Predicted label: 13, Ground truth: 9
# Predicted label: 11, Ground truth: 5
# Predicted label: 6, Ground truth: 8
# Predicted label: 4, Ground truth: 7
# Predicted label: 10, Ground truth: 2
# Predicted label: 3, Ground truth: 9
# Predicted label: 4, Ground truth: 6
# Predicted label: 2, Ground truth: 0
# Predicted label: 7, Ground truth: 12
# Predicted label: 5, Ground truth: 4
# Predicted label: 12, Ground truth: 6
# Predicted label: 11, Ground truth: 10
# Predicted label: 7, Ground truth: 9
# Predicted label: 8, Ground truth: 9
# Predicted label: 6, Ground truth: 11
# Predicted label: 4, Ground truth: 8
# Predicted label: 13, Ground truth: 12
# Predicted label: 4, Ground truth: 0
# Predicted label: 3, Ground truth: 11
# Predicted label: 6, Ground truth: 4
# Predicted label: 12, Ground truth: 13
# Predicted label: 3, Ground truth: 13
# Predicted label: 9, Ground truth: 7
# Predicted label: 9, Ground truth: 5
# Predicted label: 13, Ground truth: 8
# Predicted label: 13, Ground truth: 7
# Predicted label: 7, Ground truth: 5
# Predicted label: 6, Ground truth: 10
# Predicted label: 10, Ground truth: 0
# Predicted label: 12, Ground truth: 13
# Predicted label: 10, Ground truth: 6
# Predicted label: 10, Ground truth: 3
# Predicted label: 8, Ground truth: 12
# Predicted label: 3, Ground truth: 11
# Predicted label: 3, Ground truth: 7
# Predicted label: 12, Ground truth: 6
# Predicted label: 13, Ground truth: 12
# Predicted label: 10, Ground truth: 2
# Predicted label: 10, Ground truth: 11
# Predicted label: 5, Ground truth: 4
# Predicted label: 11, Ground truth: 1
# Predicted label: 2, Ground truth: 6
# Predicted label: 9, Ground truth: 13
# Predicted label: 11, Ground truth: 10
# Predicted label: 9, Ground truth: 5
# Predicted label: 6, Ground truth: 1
# Predicted label: 3, Ground truth: 11
# Predicted label: 2, Ground truth: 1
# Predicted label: 4, Ground truth: 6
# Predicted label: 5, Ground truth: 11
# Predicted label: 9, Ground truth: 7
# Predicted label: 12, Ground truth: 6
# Predicted label: 12, Ground truth: 6
# Predicted label: 10, Ground truth: 0
# Predicted label: 9, Ground truth: 5
# Predicted label: 7, Ground truth: 4
# Predicted label: 10, Ground truth: 2
# Predicted label: 10, Ground truth: 6
# Predicted label: 6, Ground truth: 4
# Predicted label: 8, Ground truth: 6
# Predicted label: 4, Ground truth: 8
# Predicted label: 12, Ground truth: 6
# Predicted label: 2, Ground truth: 6
# Predicted label: 13, Ground truth: 5
# Predicted label: 11, Ground truth: 7
# Predicted label: 2, Ground truth: 3
# Predicted label: 10, Ground truth: 2
# Predicted label: 9, Ground truth: 7
# Predicted label: 11, Ground truth: 5
# Predicted label: 7, Ground truth: 13
# Predicted label: 12, Ground truth: 8
# Predicted label: 9, Ground truth: 11
# Predicted label: 0, Ground truth: 1
# Predicted label: 3, Ground truth: 11
# Predicted label: 9, Ground truth: 13
# Predicted label: 2, Ground truth: 10
# Predicted label: 0, Ground truth: 1
# Predicted label: 2, Ground truth: 3
# Predicted label: 12, Ground truth: 13
# Predicted label: 3, Ground truth: 7
# Predicted label: 5, Ground truth: 9
# Predicted label: 4, Ground truth: 5
# Predicted label: 6, Ground truth: 0
# Predicted label: 6, Ground truth: 10
# Predicted label: 5, Ground truth: 9
# Predicted label: 4, Ground truth: 6
# Predicted label: 6, Ground truth: 8
# Predicted label: 0, Ground truth: 1
# Predicted label: 6, Ground truth: 0
# Predicted label: 12, Ground truth: 2
# Predicted label: 9, Ground truth: 13
# Predicted label: 7, Ground truth: 9
# Predicted label: 13, Ground truth: 7
# Predicted label: 6, Ground truth: 8
# Predicted label: 6, Ground truth: 12
# Predicted label: 9, Ground truth: 5
# Predicted label: 0, Ground truth: 1
# Predicted label: 9, Ground truth: 1
# Predicted label: 13, Ground truth: 12
# Predicted label: 3, Ground truth: 13
# Predicted label: 5, Ground truth: 6
# Predicted label: 13, Ground truth: 9
# Predicted label: 3, Ground truth: 11
# Predicted label: 2, Ground truth: 3
# Predicted label: 10, Ground truth: 6
# Predicted label: 7, Ground truth: 5
# Predicted label: 12, Ground truth: 6
# Predicted label: 9, Ground truth: 13
# Predicted label: 5, Ground truth: 7
# Predicted label: 6, Ground truth: 4
# Predicted label: 6, Ground truth: 12
# Predicted label: 13, Ground truth: 7
# Predicted label: 12, Ground truth: 7
# Predicted label: 3, Ground truth: 11
# Predicted label: 6, Ground truth: 12
# Predicted label: 6, Ground truth: 0
# Predicted label: 7, Ground truth: 3
# Predicted label: 10, Ground truth: 2
# Predicted label: 12, Ground truth: 6
# Predicted label: 1, Ground truth: 5
# Predicted label: 9, Ground truth: 5
# Predicted label: 10, Ground truth: 11
# Predicted label: 9, Ground truth: 3
# Predicted label: 3, Ground truth: 11
# Predicted label: 7, Ground truth: 13
# Predicted label: 6, Ground truth: 10
# Predicted label: 6, Ground truth: 8
# Predicted label: 2, Ground truth: 11
# Predicted label: 13, Ground truth: 7
# Predicted label: 6, Ground truth: 4
# Predicted label: 2, Ground truth: 11
# Predicted label: 6, Ground truth: 4
# Predicted label: 13, Ground truth: 9
# Predicted label: 7, Ground truth: 9
# Predicted label: 13, Ground truth: 7
# Predicted label: 0, Ground truth: 1
# Predicted label: 11, Ground truth: 7
# Predicted label: 12, Ground truth: 8
# Predicted label: 4, Ground truth: 6
# Predicted label: 8, Ground truth: 0
# Predicted label: 12, Ground truth: 6
# Predicted label: 4, Ground truth: 12
# Predicted label: 7, Ground truth: 1
# Predicted label: 0, Ground truth: 1
# Predicted label: 10, Ground truth: 2
# Predicted label: 9, Ground truth: 7
# Predicted label: 3, Ground truth: 11
# Predicted label: 2, Ground truth: 11
# Predicted label: 13, Ground truth: 12
# Predicted label: 10, Ground truth: 11
# Predicted label: 4, Ground truth: 10
# Predicted label: 3, Ground truth: 11
# Predicted label: 2, Ground truth: 10
# Predicted label: 12, Ground truth: 6
# Predicted label: 13, Ground truth: 7
# Predicted label: 12, Ground truth: 9
# Predicted label: 8, Ground truth: 12
# Predicted label: 7, Ground truth: 5
# Predicted label: 8, Ground truth: 12
# Predicted label: 12, Ground truth: 2
# Predicted label: 2, Ground truth: 10
# Predicted label: 1, Ground truth: 5
# Predicted label: 0, Ground truth: 1
# Predicted label: 2, Ground truth: 10
# Predicted label: 7, Ground truth: 5
# Predicted label: 10, Ground truth: 2
# Predicted label: 13, Ground truth: 9
# Predicted label: 12, Ground truth: 8
# Predicted label: 13, Ground truth: 7
# Predicted label: 2, Ground truth: 10
# Predicted label: 10, Ground truth: 6
# Predicted label: 2, Ground truth: 10
# Predicted label: 12, Ground truth: 8
# Predicted label: 10, Ground truth: 2
# Predicted label: 13, Ground truth: 9
# Predicted label: 2, Ground truth: 10
# Predicted label: 4, Ground truth: 6
# Predicted label: 7, Ground truth: 1
# Predicted label: 6, Ground truth: 12
# Predicted label: 10, Ground truth: 2
# Predicted label: 3, Ground truth: 11
# Predicted label: 10, Ground truth: 3
# Predicted label: 12, Ground truth: 7
# Predicted label: 3, Ground truth: 11
# Predicted label: 13, Ground truth: 7
# Predicted label: 8, Ground truth: 12
# Predicted label: 9, Ground truth: 5
# Predicted label: 2, Ground truth: 6
# Predicted label: 13, Ground truth: 9
# Predicted label: 12, Ground truth: 13
# Predicted label: 11, Ground truth: 5
# Predicted label: 9, Ground truth: 13
# Predicted label: 2, Ground truth: 3
# Predicted label: 3, Ground truth: 11
# Predicted label: 2, Ground truth: 10
# Predicted label: 2, Ground truth: 10
# Predicted label: 0, Ground truth: 1
# Predicted label: 11, Ground truth: 3
# Predicted label: 9, Ground truth: 5
# Predicted label: 4, Ground truth: 1
# Predicted label: 10, Ground truth: 0
# Predicted label: 8, Ground truth: 6
# Predicted label: 12, Ground truth: 13
# Predicted label: 12, Ground truth: 13
# Predicted label: 13, Ground truth: 7
# Predicted label: 0, Ground truth: 4
# Predicted label: 10, Ground truth: 1
# Predicted label: 2, Ground truth: 11
# Predicted label: 9, Ground truth: 5
# Predicted label: 13, Ground truth: 7
# Predicted label: 3, Ground truth: 2
# Predicted label: 6, Ground truth: 8
# Predicted label: 13, Ground truth: 5
# Predicted label: 12, Ground truth: 6
# Predicted label: 2, Ground truth: 10
# Predicted label: 3, Ground truth: 11
# Predicted label: 3, Ground truth: 11
# Predicted label: 12, Ground truth: 8
# Predicted label: 6, Ground truth: 4
# Predicted label: 10, Ground truth: 2
# Predicted label: 7, Ground truth: 5
# Predicted label: 6, Ground truth: 4
# Predicted label: 2, Ground truth: 10
# Predicted label: 4, Ground truth: 12
# Predicted label: 2, Ground truth: 12
# Predicted label: 10, Ground truth: 1
# Predicted label: 2, Ground truth: 11
# Predicted label: 12, Ground truth: 8
# Predicted label: 13, Ground truth: 7
# Predicted label: 2, Ground truth: 10
# Predicted label: 1, Ground truth: 0
# Predicted label: 5, Ground truth: 7
# Predicted label: 6, Ground truth: 4
# Predicted label: 9, Ground truth: 13
# Predicted label: 10, Ground truth: 4
# Predicted label: 2, Ground truth: 10
# Predicted label: 7, Ground truth: 11
# Predicted label: 13, Ground truth: 9
# Predicted label: 12, Ground truth: 6
# Predicted label: 9, Ground truth: 1
# Predicted label: 6, Ground truth: 5
# Predicted label: 4, Ground truth: 6
# Predicted label: 2, Ground truth: 4
# Predicted label: 9, Ground truth: 7
# Predicted label: 13, Ground truth: 12
# Predicted label: 4, Ground truth: 0
# Predicted label: 3, Ground truth: 13
# Predicted label: 4, Ground truth: 7
# Predicted label: 8, Ground truth: 13
# Predicted label: 6, Ground truth: 10
# Predicted label: 12, Ground truth: 4
# Predicted label: 5, Ground truth: 6
# Predicted label: 0, Ground truth: 1
# Predicted label: 4, Ground truth: 7
# Predicted label: 2, Ground truth: 10
# Predicted label: 7, Ground truth: 11
# Predicted label: 2, Ground truth: 11
# Predicted label: 13, Ground truth: 7
# Predicted label: 3, Ground truth: 7
# Predicted label: 5, Ground truth: 7
# Predicted label: 10, Ground truth: 2
# Predicted label: 6, Ground truth: 1
# Predicted label: 7, Ground truth: 5
# Predicted label: 13, Ground truth: 11
# Predicted label: 2, Ground truth: 12
# Predicted label: 4, Ground truth: 6
# Predicted label: 5, Ground truth: 9
# Predicted label: 13, Ground truth: 5
# Predicted label: 1, Ground truth: 0
# Predicted label: 13, Ground truth: 9
# Predicted label: 4, Ground truth: 1
# Predicted label: 12, Ground truth: 11
# Predicted label: 12, Ground truth: 6
# Predicted label: 10, Ground truth: 2
# Predicted label: 7, Ground truth: 11
# Predicted label: 9, Ground truth: 11
# Predicted label: 3, Ground truth: 11
# Predicted label: 12, Ground truth: 8
# Predicted label: 13, Ground truth: 12
# Predicted label: 13, Ground truth: 7
# Predicted label: 0, Ground truth: 1
# Predicted label: 13, Ground truth: 7
# Predicted label: 13, Ground truth: 3
# Predicted label: 11, Ground truth: 3
# Predicted label: 12, Ground truth: 8
# Predicted label: 3, Ground truth: 11
# Predicted label: 8, Ground truth: 6
# Predicted label: 3, Ground truth: 11
# Predicted label: 0, Ground truth: 1
# Predicted label: 6, Ground truth: 8
# Predicted label: 10, Ground truth: 2
# Predicted label: 12, Ground truth: 2
# Predicted label: 12, Ground truth: 6
# Predicted label: 7, Ground truth: 13
# Predicted label: 7, Ground truth: 13
# Predicted label: 4, Ground truth: 0
# Predicted label: 3, Ground truth: 13
# Predicted label: 0, Ground truth: 1
# Predicted label: 7, Ground truth: 4
# Predicted label: 2, Ground truth: 12
# Predicted label: 10, Ground truth: 2
# Predicted label: 10, Ground truth: 11
# Predicted label: 11, Ground truth: 3
# Predicted label: 10, Ground truth: 4
# Predicted label: 4, Ground truth: 8
# Predicted label: 2, Ground truth: 10
# Predicted label: 13, Ground truth: 11
# Predicted label: 12, Ground truth: 9
# Predicted label: 8, Ground truth: 6
# Predicted label: 12, Ground truth: 6
# Predicted label: 7, Ground truth: 5
# Predicted label: 6, Ground truth: 1
# Predicted label: 13, Ground truth: 9
# Predicted label: 0, Ground truth: 7
# Predicted label: 13, Ground truth: 7
# Predicted label: 6, Ground truth: 10
# Predicted label: 7, Ground truth: 11
# Predicted label: 2, Ground truth: 11
# Predicted label: 9, Ground truth: 13
# Predicted label: 13, Ground truth: 11
# Predicted label: 6, Ground truth: 12
# Predicted label: 10, Ground truth: 3
# Predicted label: 11, Ground truth: 1
# Predicted label: 1, Ground truth: 7
# Predicted label: 12, Ground truth: 6
# Predicted label: 10, Ground truth: 2
# Predicted label: 0, Ground truth: 5
# Predicted label: 6, Ground truth: 12
# Predicted label: 2, Ground truth: 10
# Predicted label: 9, Ground truth: 8
# Predicted label: 5, Ground truth: 7
# Predicted label: 11, Ground truth: 5
# Predicted label: 9, Ground truth: 13
# Predicted label: 13, Ground truth: 7
# Predicted label: 3, Ground truth: 7
# Predicted label: 13, Ground truth: 12
# Predicted label: 6, Ground truth: 0
# Predicted label: 5, Ground truth: 11
# Predicted label: 13, Ground truth: 9
# Predicted label: 7, Ground truth: 1
# Predicted label: 3, Ground truth: 11
# Predicted label: 8, Ground truth: 6
# Predicted label: 13, Ground truth: 7
# Predicted label: 10, Ground truth: 2
# Predicted label: 12, Ground truth: 6
# Predicted label: 10, Ground truth: 3
# Predicted label: 10, Ground truth: 6
# Predicted label: 3, Ground truth: 11
# Predicted label: 2, Ground truth: 6
# Predicted label: 12, Ground truth: 6
# Predicted label: 13, Ground truth: 5
# Predicted label: 7, Ground truth: 5
# Predicted label: 13, Ground truth: 5
# Predicted label: 6, Ground truth: 9
# Predicted label: 2, Ground truth: 10
# Predicted label: 0, Ground truth: 1
# Predicted label: 8, Ground truth: 13
# Predicted label: 2, Ground truth: 6
# Predicted label: 1, Ground truth: 0
# Predicted label: 7, Ground truth: 5
# Predicted label: 11, Ground truth: 3
# Predicted label: 9, Ground truth: 5
# Predicted label: 6, Ground truth: 12
# Predicted label: 4, Ground truth: 0
# Predicted label: 4, Ground truth: 0
# Predicted label: 5, Ground truth: 7
# Predicted label: 7, Ground truth: 11
# Predicted label: 5, Ground truth: 1
# Predicted label: 2, Ground truth: 10
# Predicted label: 3, Ground truth: 11
# Predicted label: 6, Ground truth: 4
# Predicted label: 12, Ground truth: 8
# Predicted label: 9, Ground truth: 4
# Predicted label: 13, Ground truth: 9
# Predicted label: 7, Ground truth: 13
# Predicted label: 1, Ground truth: 5
# Predicted label: 5, Ground truth: 7
# Predicted label: 9, Ground truth: 8
# Predicted label: 8, Ground truth: 4
# Predicted label: 7, Ground truth: 13
# Predicted label: 10, Ground truth: 2
# Predicted label: 9, Ground truth: 13
# Predicted label: 4, Ground truth: 5
# Predicted label: 9, Ground truth: 13
# Predicted label: 9, Ground truth: 13
# Predicted label: 10, Ground truth: 2
# Predicted label: 10, Ground truth: 11
# Predicted label: 12, Ground truth: 6
# Predicted label: 0, Ground truth: 1
# Predicted label: 6, Ground truth: 12
# Predicted label: 12, Ground truth: 6
# Predicted label: 8, Ground truth: 9
# Predicted label: 11, Ground truth: 5
# Predicting... 1000/10954
# Predicted label: 2, Ground truth: 10
# Predicted label: 1, Ground truth: 0
# Predicted label: 4, Ground truth: 6
# Predicted label: 7, Ground truth: 11
# Predicted label: 10, Ground truth: 6
# Predicted label: 9, Ground truth: 7
# Predicted label: 7, Ground truth: 9
# Predicted label: 7, Ground truth: 5
# Predicted label: 13, Ground truth: 12
# Predicted label: 4, Ground truth: 6
# Predicted label: 10, Ground truth: 6
# Predicted label: 13, Ground truth: 3
# Predicted label: 9, Ground truth: 13
# Predicted label: 7, Ground truth: 9
# Predicted label: 3, Ground truth: 11
# Predicted label: 9, Ground truth: 1
# Predicted label: 2, Ground truth: 10
# Predicted label: 2, Ground truth: 10
# Predicted label: 6, Ground truth: 4
# Predicted label: 8, Ground truth: 0
# Predicted label: 13, Ground truth: 7
# Predicted label: 8, Ground truth: 12
# Predicted label: 11, Ground truth: 1
# Predicted label: 11, Ground truth: 3
# Predicted label: 9, Ground truth: 7
# Predicted label: 13, Ground truth: 12
# Predicted label: 6, Ground truth: 4
# Predicted label: 9, Ground truth: 7
# Predicted label: 13, Ground truth: 7
# Predicted label: 0, Ground truth: 1
# Predicted label: 4, Ground truth: 8
# Predicted label: 8, Ground truth: 6
# Predicted label: 11, Ground truth: 13
# Predicted label: 3, Ground truth: 11
# Predicted label: 2, Ground truth: 10
# Predicted label: 0, Ground truth: 4
# Predicted label: 6, Ground truth: 12
# Predicted label: 2, Ground truth: 8
# Predicted label: 0, Ground truth: 1
# Predicted label: 0, Ground truth: 1
# Predicted label: 3, Ground truth: 11
# Predicted label: 3, Ground truth: 11
# Predicted label: 5, Ground truth: 1
# Predicted label: 3, Ground truth: 7
# Predicted label: 5, Ground truth: 7
# Predicted label: 10, Ground truth: 2
# Predicted label: 12, Ground truth: 6
# Predicted label: 10, Ground truth: 6
# Predicted label: 12, Ground truth: 13
# Predicted label: 3, Ground truth: 2
# Predicted label: 12, Ground truth: 6
# Predicted label: 12, Ground truth: 6
# Predicted label: 6, Ground truth: 12
# Predicted label: 11, Ground truth: 2
# Predicted label: 10, Ground truth: 2
# Predicted label: 9, Ground truth: 13
# Predicted label: 5, Ground truth: 1
# Predicted label: 12, Ground truth: 10
# Predicted label: 4, Ground truth: 6
# Predicted label: 9, Ground truth: 5
# Predicted label: 13, Ground truth: 1
# Predicted label: 11, Ground truth: 3
# Predicted label: 4, Ground truth: 12
# Predicted label: 7, Ground truth: 13
# Predicted label: 7, Ground truth: 1
# Predicted label: 2, Ground truth: 11
# Predicted label: 12, Ground truth: 6
# Predicted label: 1, Ground truth: 0
# Predicted label: 12, Ground truth: 6
# Predicted label: 13, Ground truth: 9
# Predicted label: 3, Ground truth: 11
# Predicted label: 4, Ground truth: 5
# Predicted label: 6, Ground truth: 12
# Predicted label: 0, Ground truth: 4
# Predicted label: 6, Ground truth: 11
# Predicted label: 12, Ground truth: 13
# Predicted label: 9, Ground truth: 5
# Predicted label: 10, Ground truth: 11
# Predicted label: 5, Ground truth: 4
# Predicted label: 6, Ground truth: 0
# Predicted label: 13, Ground truth: 9
# Predicted label: 6, Ground truth: 0
# Predicted label: 7, Ground truth: 9
# Predicted label: 12, Ground truth: 6
# Predicted label: 4, Ground truth: 0
# Predicted label: 3, Ground truth: 13
# Predicted label: 8, Ground truth: 6
# Predicted label: 3, Ground truth: 11
# Predicted label: 4, Ground truth: 0
# Predicted label: 3, Ground truth: 5
# Predicted label: 8, Ground truth: 10
# Predicted label: 4, Ground truth: 5
# Predicted label: 7, Ground truth: 9
# Predicted label: 13, Ground truth: 9
# Predicted label: 13, Ground truth: 9
# Predicted label: 2, Ground truth: 10
# Predicted label: 4, Ground truth: 6
# Predicted label: 5, Ground truth: 7
# Predicted label: 4, Ground truth: 0
# Predicted label: 9, Ground truth: 7
# Predicted label: 2, Ground truth: 6
# Predicted label: 2, Ground truth: 10
# Predicted label: 2, Ground truth: 6
# Predicted label: 11, Ground truth: 3
# Predicted label: 3, Ground truth: 7
# Predicted label: 9, Ground truth: 13
# Predicted label: 13, Ground truth: 9
# Predicted label: 3, Ground truth: 13
# Predicted label: 10, Ground truth: 2
# Predicted label: 9, Ground truth: 13
# Predicted label: 3, Ground truth: 7
# Predicted label: 6, Ground truth: 8
# Predicted label: 7, Ground truth: 1
# Predicted label: 3, Ground truth: 5
# Predicted label: 6, Ground truth: 10
# Predicted label: 12, Ground truth: 13
# Predicted label: 1, Ground truth: 0
# Predicted label: 4, Ground truth: 1
# Predicted label: 12, Ground truth: 8
# Predicted label: 10, Ground truth: 6
# Predicted label: 5, Ground truth: 4
# Predicted label: 4, Ground truth: 12
# Predicted label: 6, Ground truth: 12
# Predicted label: 9, Ground truth: 13
# Predicted label: 11, Ground truth: 3
# Predicted label: 3, Ground truth: 5
# Predicted label: 12, Ground truth: 13
# Predicted label: 4, Ground truth: 6
# Predicted label: 5, Ground truth: 11
# Predicted label: 10, Ground truth: 8
# Predicted label: 7, Ground truth: 5
# Predicted label: 1, Ground truth: 5
# Predicted label: 9, Ground truth: 6
# Predicted label: 13, Ground truth: 9
# Predicted label: 0, Ground truth: 4
# Predicted label: 2, Ground truth: 7
# Predicted label: 12, Ground truth: 13
# Predicted label: 10, Ground truth: 0
# Predicted label: 4, Ground truth: 6
# Predicted label: 2, Ground truth: 6
# Predicted label: 10, Ground truth: 2
# Predicted label: 10, Ground truth: 11
# Predicted label: 3, Ground truth: 11
# Predicted label: 9, Ground truth: 13
# Predicted label: 0, Ground truth: 6
# Predicted label: 2, Ground truth: 0
# Predicted label: 13, Ground truth: 9
# Predicted label: 6, Ground truth: 0
# Predicted label: 7, Ground truth: 5
# Predicted label: 5, Ground truth: 4
# Predicted label: 10, Ground truth: 2
# Predicted label: 8, Ground truth: 4
# Predicted label: 13, Ground truth: 9
# Predicted label: 2, Ground truth: 10
# Predicted label: 13, Ground truth: 9
# Predicted label: 10, Ground truth: 3
# Predicted label: 6, Ground truth: 4
# Predicted label: 10, Ground truth: 2
# Predicted label: 6, Ground truth: 4
# Predicted label: 6, Ground truth: 8
# Predicted label: 3, Ground truth: 11
# Predicted label: 3, Ground truth: 11
# Predicted label: 9, Ground truth: 13
# Predicted label: 10, Ground truth: 3
# Predicted label: 6, Ground truth: 4
# Predicted label: 0, Ground truth: 13
# Predicted label: 13, Ground truth: 3
# Predicted label: 13, Ground truth: 12
# Predicted label: 4, Ground truth: 6
# Predicted label: 9, Ground truth: 13
# Predicted label: 8, Ground truth: 10
# Predicted label: 9, Ground truth: 7
# Predicted label: 12, Ground truth: 6
# Predicted label: 13, Ground truth: 7
# Predicted label: 4, Ground truth: 12
# Predicted label: 5, Ground truth: 7
# Predicted label: 2, Ground truth: 13
# Predicted label: 12, Ground truth: 2
# Predicted label: 10, Ground truth: 0
# Predicted label: 7, Ground truth: 6
# Predicted label: 10, Ground truth: 9
# Predicted label: 7, Ground truth: 13
# Predicted label: 4, Ground truth: 0
# Predicted label: 13, Ground truth: 5
# Predicted label: 6, Ground truth: 10
# Predicted label: 3, Ground truth: 13
# Predicted label: 2, Ground truth: 10
# Predicted label: 2, Ground truth: 6
# Predicted label: 10, Ground truth: 0
# Predicted label: 8, Ground truth: 0
# Predicted label: 2, Ground truth: 10
# Predicted label: 6, Ground truth: 4
# Predicted label: 11, Ground truth: 5
# Predicted label: 6, Ground truth: 4
# Predicted label: 11, Ground truth: 3
# Predicted label: 7, Ground truth: 13
# Predicted label: 0, Ground truth: 1
# Predicted label: 2, Ground truth: 3
# Predicted label: 8, Ground truth: 4
# Predicted label: 8, Ground truth: 4
# Predicted label: 7, Ground truth: 5
# Predicted label: 0, Ground truth: 10
# Predicted label: 3, Ground truth: 2
# Predicted label: 2, Ground truth: 6
# Predicted label: 10, Ground truth: 11
# Predicted label: 11, Ground truth: 13
# Predicted label: 10, Ground truth: 0
# Predicted label: 8, Ground truth: 6
# Predicted label: 2, Ground truth: 3
# Predicted label: 4, Ground truth: 6
# Predicted label: 10, Ground truth: 2
# Predicted label: 4, Ground truth: 6
# Predicted label: 4, Ground truth: 0
# Predicted label: 6, Ground truth: 0
# Predicted label: 6, Ground truth: 12
# Predicted label: 10, Ground truth: 6
# Predicted label: 12, Ground truth: 4
# Predicted label: 10, Ground truth: 11
# Predicted label: 10, Ground truth: 2
# Predicted label: 5, Ground truth: 4
# Predicted label: 9, Ground truth: 7
# Predicted label: 13, Ground truth: 9
# Predicted label: 2, Ground truth: 3
# Predicted label: 3, Ground truth: 11
# Predicted label: 3, Ground truth: 11
# Predicted label: 6, Ground truth: 10
# Predicted label: 8, Ground truth: 7
# Predicted label: 11, Ground truth: 7
# Predicted label: 6, Ground truth: 4
# Predicted label: 9, Ground truth: 5
# Predicted label: 5, Ground truth: 9
# Predicted label: 11, Ground truth: 3
# Predicted label: 8, Ground truth: 12
# Predicted label: 6, Ground truth: 8
# Predicted label: 6, Ground truth: 12
# Predicted label: 7, Ground truth: 13
# Predicted label: 12, Ground truth: 8
# Predicted label: 9, Ground truth: 7
# Predicted label: 7, Ground truth: 13
# Predicted label: 6, Ground truth: 0
# Predicted label: 12, Ground truth: 6
# Predicted label: 3, Ground truth: 13
# Predicted label: 3, Ground truth: 11
# Predicted label: 3, Ground truth: 9
# Predicted label: 13, Ground truth: 11
# Predicted label: 12, Ground truth: 2
# Predicted label: 8, Ground truth: 9
# Predicted label: 1, Ground truth: 0
# Predicted label: 8, Ground truth: 12
# Predicted label: 4, Ground truth: 1
# Predicted label: 3, Ground truth: 0
# Predicted label: 6, Ground truth: 12
# Predicted label: 4, Ground truth: 0
# Predicted label: 12, Ground truth: 6
# Predicted label: 5, Ground truth: 4
# Predicted label: 10, Ground truth: 4
# Predicted label: 6, Ground truth: 0
# Predicted label: 2, Ground truth: 10
# Predicted label: 12, Ground truth: 2
# Predicted label: 12, Ground truth: 6
# Predicted label: 10, Ground truth: 6
# Predicted label: 2, Ground truth: 6
# Predicted label: 9, Ground truth: 7
# Predicted label: 12, Ground truth: 13
# Predicted label: 9, Ground truth: 5
# Predicted label: 6, Ground truth: 0
# Predicted label: 13, Ground truth: 11
# Predicted label: 5, Ground truth: 11
# Predicted label: 13, Ground truth: 5
# Predicted label: 4, Ground truth: 0
# Predicted label: 0, Ground truth: 1
# Predicted label: 10, Ground truth: 11
# Predicted label: 7, Ground truth: 5
# Predicted label: 12, Ground truth: 7
# Predicted label: 8, Ground truth: 12
# Predicted label: 7, Ground truth: 13
# Predicted label: 9, Ground truth: 7
# Predicted label: 0, Ground truth: 1
# Predicted label: 12, Ground truth: 8
# Predicted label: 0, Ground truth: 1
# Predicted label: 6, Ground truth: 4
# Predicted label: 7, Ground truth: 5
# Predicted label: 2, Ground truth: 10
# Predicted label: 11, Ground truth: 1
# Predicted label: 9, Ground truth: 13
# Predicted label: 3, Ground truth: 11
# Predicted label: 3, Ground truth: 11
# Predicted label: 8, Ground truth: 12
# Predicted label: 10, Ground truth: 8
# Predicted label: 12, Ground truth: 2
# Predicted label: 4, Ground truth: 0
# Predicted label: 13, Ground truth: 7
# Predicted label: 9, Ground truth: 7
# Predicted label: 7, Ground truth: 9
# Predicted label: 3, Ground truth: 11
# Predicted label: 6, Ground truth: 8
# Predicted label: 0, Ground truth: 1
# Predicted label: 12, Ground truth: 6
# Predicted label: 8, Ground truth: 6
# Predicted label: 6, Ground truth: 8
# Predicted label: 4, Ground truth: 1
# Predicted label: 4, Ground truth: 6
# Predicted label: 12, Ground truth: 3
# Predicted label: 4, Ground truth: 5
# Predicted label: 7, Ground truth: 1
# Predicted label: 9, Ground truth: 13
# Predicted label: 12, Ground truth: 10
# Predicted label: 2, Ground truth: 11
# Predicted label: 5, Ground truth: 7
# Predicted label: 13, Ground truth: 5
# Predicted label: 5, Ground truth: 1
# Predicted label: 7, Ground truth: 9
# Predicted label: 4, Ground truth: 0
# Predicted label: 2, Ground truth: 6
# Predicted label: 6, Ground truth: 12
# Predicted label: 12, Ground truth: 8
# Predicted label: 13, Ground truth: 9
# Predicted label: 1, Ground truth: 0
# Predicted label: 12, Ground truth: 9
# Predicted label: 7, Ground truth: 1
# Predicted label: 5, Ground truth: 7
# Predicted label: 9, Ground truth: 7
# Predicted label: 3, Ground truth: 11
# Predicted label: 7, Ground truth: 13
# Predicted label: 11, Ground truth: 3
# Predicted label: 2, Ground truth: 10
# Predicted label: 11, Ground truth: 1
# Predicted label: 7, Ground truth: 13
# Predicted label: 8, Ground truth: 2
# Predicted label: 8, Ground truth: 6
# Predicted label: 9, Ground truth: 7
# Predicted label: 8, Ground truth: 6
# Predicted label: 12, Ground truth: 8
# Predicted label: 2, Ground truth: 3
# Predicted label: 5, Ground truth: 0
# Predicted label: 6, Ground truth: 12
# Predicted label: 13, Ground truth: 9
# Predicted label: 4, Ground truth: 10
# Predicted label: 6, Ground truth: 4
# Predicted label: 9, Ground truth: 7
# Predicted label: 13, Ground truth: 9
# Predicted label: 8, Ground truth: 12
# Predicted label: 13, Ground truth: 9
# Predicted label: 6, Ground truth: 8
# Predicted label: 13, Ground truth: 9
# Predicted label: 7, Ground truth: 1
# Predicted label: 9, Ground truth: 7
# Predicted label: 6, Ground truth: 5
# Predicted label: 6, Ground truth: 12
# Predicted label: 0, Ground truth: 4
# Predicted label: 2, Ground truth: 11
# Predicted label: 9, Ground truth: 7
# Predicted label: 4, Ground truth: 0
# Predicted label: 5, Ground truth: 7
# Predicted label: 6, Ground truth: 4
# Predicted label: 4, Ground truth: 6
# Predicted label: 10, Ground truth: 2
# Predicted label: 3, Ground truth: 11
# Predicted label: 13, Ground truth: 7
# Predicted label: 13, Ground truth: 9
# Predicted label: 11, Ground truth: 10
# Predicted label: 0, Ground truth: 4
# Predicted label: 0, Ground truth: 6
# Predicted label: 12, Ground truth: 13
# Predicted label: 8, Ground truth: 6
# Predicted label: 6, Ground truth: 4
# Predicted label: 13, Ground truth: 11
# Predicted label: 8, Ground truth: 4
# Predicted label: 3, Ground truth: 11
# Predicted label: 10, Ground truth: 12
# Predicted label: 6, Ground truth: 11
# Predicted label: 7, Ground truth: 13
# Predicted label: 10, Ground truth: 12
# Predicted label: 8, Ground truth: 6
# Predicted label: 7, Ground truth: 3
# Predicted label: 9, Ground truth: 13
# Predicted label: 2, Ground truth: 6
# Predicted label: 7, Ground truth: 1
# Predicted label: 6, Ground truth: 0
# Predicted label: 1, Ground truth: 0
# Predicted label: 12, Ground truth: 6
# Predicted label: 8, Ground truth: 6
# Predicted label: 11, Ground truth: 5
# Predicted label: 12, Ground truth: 8
# Predicted label: 4, Ground truth: 0
# Predicted label: 9, Ground truth: 1
# Predicted label: 0, Ground truth: 1
# Predicted label: 4, Ground truth: 0
# Predicted label: 13, Ground truth: 7
# Predicted label: 12, Ground truth: 6
# Predicted label: 5, Ground truth: 1
# Predicted label: 4, Ground truth: 12
# Predicted label: 8, Ground truth: 12
# Predicted label: 11, Ground truth: 2
# Predicted label: 6, Ground truth: 8
# Predicted label: 4, Ground truth: 0
# Predicted label: 6, Ground truth: 10
# Predicted label: 7, Ground truth: 6
# Predicted label: 10, Ground truth: 6
# Predicted label: 4, Ground truth: 0
# Predicted label: 5, Ground truth: 1
# Predicted label: 7, Ground truth: 9
# Predicted label: 13, Ground truth: 3
# Predicted label: 11, Ground truth: 3
# Predicted label: 6, Ground truth: 0
# Predicted label: 8, Ground truth: 6
# Predicted label: 10, Ground truth: 2
# Predicted label: 13, Ground truth: 7
# Predicted label: 6, Ground truth: 10
# Predicted label: 9, Ground truth: 5
# Predicted label: 13, Ground truth: 9
# Predicted label: 2, Ground truth: 10
# Predicted label: 12, Ground truth: 6
# Predicting... 2000/10954
# Predicted label: 5, Ground truth: 11
# Predicted label: 12, Ground truth: 6
# Predicted label: 13, Ground truth: 3
# Predicted label: 9, Ground truth: 13
# Predicted label: 6, Ground truth: 12
# Predicted label: 2, Ground truth: 10
# Predicted label: 9, Ground truth: 11
# Predicted label: 11, Ground truth: 0
# Predicted label: 5, Ground truth: 11
# Predicted label: 5, Ground truth: 7
# Predicted label: 5, Ground truth: 11
# Predicted label: 4, Ground truth: 7
# Predicted label: 5, Ground truth: 1
# Predicted label: 10, Ground truth: 3
# Predicted label: 9, Ground truth: 5
# Predicted label: 12, Ground truth: 6
# Predicted label: 8, Ground truth: 6
# Predicted label: 9, Ground truth: 5
# Predicted label: 8, Ground truth: 4
# Predicted label: 7, Ground truth: 5
# Predicted label: 7, Ground truth: 1
# Predicted label: 1, Ground truth: 4
# Predicted label: 1, Ground truth: 0
# Predicted label: 13, Ground truth: 9
# Predicted label: 4, Ground truth: 6
# Predicted label: 7, Ground truth: 5
# Predicted label: 12, Ground truth: 4
# Predicted label: 5, Ground truth: 4
# Predicted label: 13, Ground truth: 5
# Predicted label: 13, Ground truth: 9
# Predicted label: 10, Ground truth: 2
# Predicted label: 7, Ground truth: 11
# Predicted label: 4, Ground truth: 0
# Predicted label: 10, Ground truth: 2
# Predicted label: 5, Ground truth: 7
# Predicted label: 9, Ground truth: 7
# Predicted label: 3, Ground truth: 11
# Predicted label: 10, Ground truth: 1
# Predicted label: 2, Ground truth: 10
# Predicted label: 10, Ground truth: 0
# Predicted label: 6, Ground truth: 12
# Predicted label: 10, Ground truth: 0
# Predicted label: 4, Ground truth: 0
# Predicted label: 11, Ground truth: 1
# Predicted label: 5, Ground truth: 7
# Predicted label: 12, Ground truth: 6
# Predicted label: 6, Ground truth: 0
# Predicted label: 5, Ground truth: 7
# Predicted label: 3, Ground truth: 11
# Predicted label: 10, Ground truth: 6
# Predicted label: 12, Ground truth: 9
# Predicted label: 5, Ground truth: 7
# Predicted label: 2, Ground truth: 10
# Predicted label: 7, Ground truth: 1
# Predicted label: 10, Ground truth: 11
# Predicted label: 8, Ground truth: 6
# Predicted label: 13, Ground truth: 7
# Predicted label: 0, Ground truth: 1
# Predicted label: 5, Ground truth: 3
# Predicted label: 7, Ground truth: 13
# Predicted label: 3, Ground truth: 10
# Predicted label: 7, Ground truth: 1
# Predicted label: 2, Ground truth: 10
# Predicted label: 13, Ground truth: 7
# Predicted label: 0, Ground truth: 1
# Predicted label: 13, Ground truth: 4
# Predicted label: 4, Ground truth: 0
# Predicted label: 10, Ground truth: 11
# Predicted label: 0, Ground truth: 1
# Predicted label: 9, Ground truth: 7
# Predicted label: 2, Ground truth: 11
# Predicted label: 2, Ground truth: 10
# Predicted label: 3, Ground truth: 7
# Predicted label: 4, Ground truth: 6
# Predicted label: 13, Ground truth: 9
# Predicted label: 9, Ground truth: 13
# Predicted label: 11, Ground truth: 7
# Predicted label: 3, Ground truth: 11
# Predicted label: 13, Ground truth: 7
# Predicted label: 10, Ground truth: 6
# Predicted label: 4, Ground truth: 6
# Predicted label: 11, Ground truth: 7
# Predicted label: 5, Ground truth: 7
# Predicted label: 12, Ground truth: 8
# Predicted label: 0, Ground truth: 1
# Predicted label: 5, Ground truth: 11
# Predicted label: 9, Ground truth: 8
# Predicted label: 13, Ground truth: 7
# Predicted label: 13, Ground truth: 9
# Predicted label: 6, Ground truth: 5
# Predicted label: 9, Ground truth: 13
# Predicted label: 3, Ground truth: 0
# Predicted label: 2, Ground truth: 10
# Predicted label: 6, Ground truth: 12
# Predicted label: 7, Ground truth: 9
# Predicted label: 5, Ground truth: 0
# Predicted label: 7, Ground truth: 1
# Predicted label: 10, Ground truth: 2
# Predicted label: 12, Ground truth: 6
# Predicted label: 3, Ground truth: 11
# Predicted label: 9, Ground truth: 1
# Predicted label: 8, Ground truth: 2
# Predicted label: 0, Ground truth: 1
# Predicted label: 11, Ground truth: 7
# Predicted label: 10, Ground truth: 2
# Predicted label: 8, Ground truth: 4
# Predicted label: 11, Ground truth: 3
# Predicted label: 3, Ground truth: 11
# Predicted label: 6, Ground truth: 12
# Predicted label: 2, Ground truth: 6
# Predicted label: 11, Ground truth: 1
# Predicted label: 9, Ground truth: 3
# Predicted label: 12, Ground truth: 8
# Predicted label: 2, Ground truth: 11
# Predicted label: 6, Ground truth: 4
# Predicted label: 6, Ground truth: 10
# Predicted label: 2, Ground truth: 12
# Predicted label: 12, Ground truth: 13
# Predicted label: 0, Ground truth: 12
# Predicted label: 9, Ground truth: 6
# Predicted label: 12, Ground truth: 11
# Predicted label: 1, Ground truth: 0
# Predicted label: 6, Ground truth: 10
# Predicted label: 6, Ground truth: 10
# Predicted label: 6, Ground truth: 0
# Predicted label: 6, Ground truth: 0
# Predicted label: 5, Ground truth: 1
# Predicted label: 6, Ground truth: 4
# Predicted label: 2, Ground truth: 6
# Predicted label: 7, Ground truth: 13
# Predicted label: 12, Ground truth: 6
# Predicted label: 10, Ground truth: 11
# Predicted label: 3, Ground truth: 0
# Predicted label: 3, Ground truth: 11
# Predicted label: 3, Ground truth: 12
# Predicted label: 6, Ground truth: 0
# Predicted label: 8, Ground truth: 6
# Predicted label: 9, Ground truth: 7
# Predicted label: 2, Ground truth: 12
# Predicted label: 12, Ground truth: 10
# Predicted label: 6, Ground truth: 9
# Predicted label: 6, Ground truth: 12
# Predicted label: 12, Ground truth: 13
# Predicted label: 13, Ground truth: 9
# Predicted label: 4, Ground truth: 6
# Predicted label: 4, Ground truth: 6
# Predicted label: 10, Ground truth: 2
# Predicted label: 3, Ground truth: 13
# Predicted label: 13, Ground truth: 11
# Predicted label: 3, Ground truth: 1
# Predicted label: 12, Ground truth: 6
# Predicted label: 6, Ground truth: 8
# Predicted label: 12, Ground truth: 13
# Predicted label: 10, Ground truth: 2
# Predicted label: 9, Ground truth: 13
# Predicted label: 4, Ground truth: 0
# Predicted label: 4, Ground truth: 0
# Predicted label: 12, Ground truth: 6
# Predicted label: 9, Ground truth: 13
# Predicted label: 12, Ground truth: 13
# Predicted label: 5, Ground truth: 1
# Predicted label: 5, Ground truth: 7
# Predicted label: 7, Ground truth: 5
# Predicted label: 3, Ground truth: 2
# Predicted label: 12, Ground truth: 10
# Predicted label: 7, Ground truth: 13
# Predicted label: 9, Ground truth: 7
# Predicted label: 4, Ground truth: 10
# Predicted label: 11, Ground truth: 3
# Predicted label: 4, Ground truth: 0
# Predicted label: 2, Ground truth: 10
# Predicted label: 8, Ground truth: 12
# Predicted label: 13, Ground truth: 9
# Predicted label: 11, Ground truth: 1
# Predicted label: 8, Ground truth: 6
# Predicted label: 6, Ground truth: 12
# Predicted label: 10, Ground truth: 2
# Predicted label: 8, Ground truth: 10
# Predicted label: 5, Ground truth: 1
# Predicted label: 3, Ground truth: 5
# Predicted label: 8, Ground truth: 12
# Predicted label: 9, Ground truth: 13
# Predicted label: 12, Ground truth: 4
# Predicted label: 6, Ground truth: 8
# Predicted label: 13, Ground truth: 7
# Predicted label: 2, Ground truth: 3
# Predicted label: 1, Ground truth: 5
# Predicted label: 2, Ground truth: 4
# Predicted label: 5, Ground truth: 4
# Predicted label: 0, Ground truth: 1
# Predicted label: 9, Ground truth: 7
# Predicted label: 12, Ground truth: 6
# Predicted label: 12, Ground truth: 6
# Predicted label: 4, Ground truth: 6
# Predicted label: 0, Ground truth: 1
# Predicted label: 0, Ground truth: 6
# Predicted label: 4, Ground truth: 0
# Predicted label: 13, Ground truth: 9
# Predicted label: 10, Ground truth: 2
# Predicted label: 7, Ground truth: 5
# Predicted label: 13, Ground truth: 8
# Predicted label: 12, Ground truth: 6
# Predicted label: 8, Ground truth: 6
# Predicted label: 12, Ground truth: 6
# Predicted label: 4, Ground truth: 1
# Predicted label: 10, Ground truth: 4
# Predicted label: 10, Ground truth: 12
# Predicted label: 7, Ground truth: 5
# Predicted label: 12, Ground truth: 8
# Predicted label: 13, Ground truth: 7
# Predicted label: 2, Ground truth: 10
# Predicted label: 1, Ground truth: 0
# Predicted label: 7, Ground truth: 9
# Predicted label: 6, Ground truth: 4
# Predicted label: 10, Ground truth: 2
# Predicted label: 5, Ground truth: 7
# Predicted label: 7, Ground truth: 6
# Predicted label: 13, Ground truth: 7
# Predicted label: 3, Ground truth: 2
# Predicted label: 3, Ground truth: 13
# Predicted label: 12, Ground truth: 6
# Predicted label: 7, Ground truth: 0
# Predicted label: 5, Ground truth: 1
# Predicted label: 12, Ground truth: 8
# Predicted label: 9, Ground truth: 5
# Predicted label: 9, Ground truth: 7
# Predicted label: 6, Ground truth: 12
# Predicted label: 9, Ground truth: 13
# Predicted label: 2, Ground truth: 10
# Predicted label: 9, Ground truth: 13
# Predicted label: 7, Ground truth: 1
# Predicted label: 3, Ground truth: 11
# Predicted label: 9, Ground truth: 5
# Predicted label: 2, Ground truth: 10
# Predicted label: 0, Ground truth: 1
# Predicted label: 4, Ground truth: 5
# Predicted label: 0, Ground truth: 1
# Predicted label: 10, Ground truth: 11
# Predicted label: 1, Ground truth: 5
# Predicted label: 2, Ground truth: 10
# Predicted label: 2, Ground truth: 10
# Predicted label: 3, Ground truth: 11
# Predicted label: 13, Ground truth: 7
# Predicted label: 0, Ground truth: 10
# Predicted label: 12, Ground truth: 8
# Predicted label: 2, Ground truth: 10
# Predicted label: 10, Ground truth: 2
# Predicted label: 13, Ground truth: 7
# Predicted label: 8, Ground truth: 4
# Predicted label: 3, Ground truth: 10
# Predicted label: 9, Ground truth: 1
# Predicted label: 10, Ground truth: 3
# Predicted label: 1, Ground truth: 4
# Predicted label: 12, Ground truth: 6
# Predicted label: 7, Ground truth: 9
# Predicted label: 12, Ground truth: 6
# Predicted label: 13, Ground truth: 7
# Predicted label: 5, Ground truth: 7
# Predicted label: 10, Ground truth: 11
# Predicted label: 4, Ground truth: 6
# Predicted label: 6, Ground truth: 7
# Predicted label: 2, Ground truth: 10
# Predicted label: 8, Ground truth: 6
# Predicted label: 7, Ground truth: 1
# Predicted label: 2, Ground truth: 11
# Predicted label: 4, Ground truth: 6
# Predicted label: 13, Ground truth: 9
# Predicted label: 3, Ground truth: 13
# Predicted label: 13, Ground truth: 3
# Predicted label: 10, Ground truth: 2
# Predicted label: 13, Ground truth: 9
# Predicted label: 9, Ground truth: 13
# Predicted label: 5, Ground truth: 1
# Predicted label: 12, Ground truth: 13
# Predicted label: 10, Ground truth: 6
# Predicted label: 12, Ground truth: 7
# Predicted label: 11, Ground truth: 5
# Predicted label: 12, Ground truth: 10
# Predicted label: 9, Ground truth: 7
# Predicted label: 2, Ground truth: 10
# Predicted label: 2, Ground truth: 10
# Predicted label: 8, Ground truth: 6
# Predicted label: 2, Ground truth: 12
# Predicted label: 6, Ground truth: 10
# Predicted label: 11, Ground truth: 3
# Predicted label: 13, Ground truth: 5
# Predicted label: 12, Ground truth: 6
# Predicted label: 4, Ground truth: 0
# Predicted label: 2, Ground truth: 4
# Predicted label: 9, Ground truth: 13
# Predicted label: 9, Ground truth: 11
# Predicted label: 13, Ground truth: 9
# Predicted label: 7, Ground truth: 1
# Predicted label: 6, Ground truth: 4
# Predicted label: 3, Ground truth: 11
# Predicted label: 11, Ground truth: 7
# Predicted label: 4, Ground truth: 5
# Predicted label: 8, Ground truth: 4
# Predicted label: 3, Ground truth: 7
# Predicted label: 12, Ground truth: 10
# Predicted label: 2, Ground truth: 12
# Predicted label: 12, Ground truth: 6
# Predicted label: 12, Ground truth: 2
# Predicted label: 13, Ground truth: 7
# Predicted label: 6, Ground truth: 10
# Predicted label: 2, Ground truth: 3
# Predicted label: 10, Ground truth: 6
# Predicted label: 12, Ground truth: 2
# Predicted label: 9, Ground truth: 1
# Predicted label: 6, Ground truth: 12
# Predicted label: 11, Ground truth: 13
# Predicted label: 12, Ground truth: 10
# Predicted label: 0, Ground truth: 1
# Predicted label: 5, Ground truth: 1
# Predicted label: 12, Ground truth: 8
# Predicted label: 7, Ground truth: 5
# Predicted label: 9, Ground truth: 7
# Predicted label: 8, Ground truth: 4
# Predicted label: 3, Ground truth: 7
# Predicted label: 9, Ground truth: 5
# Predicted label: 13, Ground truth: 7
# Predicted label: 2, Ground truth: 3
# Predicted label: 5, Ground truth: 7
# Predicted label: 11, Ground truth: 1
# Predicted label: 2, Ground truth: 10
# Predicted label: 13, Ground truth: 9
# Predicted label: 2, Ground truth: 10
# Predicted label: 11, Ground truth: 3
# Predicted label: 9, Ground truth: 5
# Predicted label: 9, Ground truth: 7
# Predicted label: 13, Ground truth: 12
# Predicted label: 5, Ground truth: 1
# Predicted label: 9, Ground truth: 1
# Predicted label: 9, Ground truth: 12
# Predicted label: 9, Ground truth: 7
# Predicted label: 13, Ground truth: 7
# Predicted label: 5, Ground truth: 7
# Predicted label: 2, Ground truth: 10
# Predicted label: 0, Ground truth: 1
# Predicted label: 1, Ground truth: 0
# Predicted label: 7, Ground truth: 1
# Predicted label: 8, Ground truth: 4
# Predicted label: 4, Ground truth: 6
# Predicted label: 13, Ground truth: 9
# Predicted label: 0, Ground truth: 1
# Predicted label: 11, Ground truth: 7
# Predicted label: 4, Ground truth: 2
# Predicted label: 6, Ground truth: 8
# Predicted label: 1, Ground truth: 11
# Predicted label: 13, Ground truth: 1
# Predicted label: 7, Ground truth: 5
# Predicted label: 6, Ground truth: 12
# Predicted label: 5, Ground truth: 11
# Predicted label: 13, Ground truth: 9
# Predicted label: 7, Ground truth: 9
# Predicted label: 10, Ground truth: 2
# Predicted label: 8, Ground truth: 4
# Predicted label: 3, Ground truth: 11
# Predicted label: 7, Ground truth: 1
# Predicted label: 12, Ground truth: 6
# Predicted label: 3, Ground truth: 1
# Predicted label: 9, Ground truth: 7
# Predicted label: 0, Ground truth: 1
# Predicted label: 2, Ground truth: 3
# Predicted label: 8, Ground truth: 12
# Predicted label: 12, Ground truth: 6
# Predicted label: 6, Ground truth: 4
# Predicted label: 4, Ground truth: 1
# Predicted label: 2, Ground truth: 3
# Predicted label: 13, Ground truth: 7
# Predicted label: 2, Ground truth: 10
# Predicted label: 13, Ground truth: 9
# Predicted label: 2, Ground truth: 3
# Predicted label: 6, Ground truth: 0
# Predicted label: 6, Ground truth: 11
# Predicted label: 2, Ground truth: 10
# Predicted label: 5, Ground truth: 7
# Predicted label: 11, Ground truth: 7
# Predicted label: 13, Ground truth: 3
# Predicted label: 2, Ground truth: 10
# Predicted label: 9, Ground truth: 1
# Predicted label: 10, Ground truth: 2
# Predicted label: 13, Ground truth: 9
# Predicted label: 3, Ground truth: 11
# Predicted label: 12, Ground truth: 7
# Predicted label: 9, Ground truth: 13
# Predicted label: 12, Ground truth: 6
# Predicted label: 13, Ground truth: 9
# Predicted label: 12, Ground truth: 8
# Predicted label: 12, Ground truth: 6
# Predicted label: 2, Ground truth: 10
# Predicted label: 7, Ground truth: 5
# Predicted label: 2, Ground truth: 3
# Predicting... 3000/10954
# Predicted label: 10, Ground truth: 5
# Predicted label: 12, Ground truth: 10
# Predicted label: 11, Ground truth: 1
# Predicted label: 9, Ground truth: 13
# Predicted label: 5, Ground truth: 4
# Predicted label: 5, Ground truth: 1
# Predicted label: 9, Ground truth: 13
# Predicted label: 9, Ground truth: 5
# Predicted label: 10, Ground truth: 2
# Predicted label: 2, Ground truth: 12
# Predicted label: 12, Ground truth: 8
# Predicted label: 10, Ground truth: 13
# Predicted label: 7, Ground truth: 5
# Predicted label: 12, Ground truth: 8
# Predicted label: 12, Ground truth: 13
# Predicted label: 3, Ground truth: 7
# Predicted label: 7, Ground truth: 5
# Predicted label: 9, Ground truth: 7
# Predicted label: 11, Ground truth: 7
# Predicted label: 9, Ground truth: 7
# Predicted label: 7, Ground truth: 5
# Predicted label: 10, Ground truth: 2
# Predicted label: 12, Ground truth: 13
# Predicted label: 2, Ground truth: 10
# Predicted label: 13, Ground truth: 9
# Predicted label: 12, Ground truth: 13
# Predicted label: 12, Ground truth: 2
# Predicted label: 11, Ground truth: 3
# Predicted label: 12, Ground truth: 0
# Predicted label: 11, Ground truth: 7
# Predicted label: 2, Ground truth: 7
# Predicted label: 7, Ground truth: 1
# Predicted label: 3, Ground truth: 11
# Predicted label: 2, Ground truth: 10
# Predicted label: 13, Ground truth: 8
# Predicted label: 11, Ground truth: 2
# Predicted label: 3, Ground truth: 11
# Predicted label: 3, Ground truth: 7
# Predicted label: 2, Ground truth: 6
# Predicted label: 8, Ground truth: 4
# Predicted label: 7, Ground truth: 13
# Predicted label: 2, Ground truth: 4
# Predicted label: 9, Ground truth: 5
# Predicted label: 7, Ground truth: 4
# Predicted label: 9, Ground truth: 5
# Predicted label: 3, Ground truth: 7
# Predicted label: 12, Ground truth: 8
# Predicted label: 9, Ground truth: 7
# Predicted label: 12, Ground truth: 6
# Predicted label: 6, Ground truth: 0
# Predicted label: 2, Ground truth: 10
# Predicted label: 11, Ground truth: 3
# Predicted label: 2, Ground truth: 3
# Predicted label: 3, Ground truth: 11
# Predicted label: 4, Ground truth: 0
# Predicted label: 13, Ground truth: 12
# Predicted label: 6, Ground truth: 0
# Predicted label: 7, Ground truth: 0
# Predicted label: 9, Ground truth: 13
# Predicted label: 7, Ground truth: 1
# Predicted label: 9, Ground truth: 13
# Predicted label: 2, Ground truth: 10
# ...
# Predicted label: 9, Ground truth: 13
# Predicted label: 12, Ground truth: 8
# Predicted label: 3, Ground truth: 11
# Predicted label: 7, Ground truth: 6
# Predicted label: 5, Ground truth: 1
# Predicted label: 4, Ground truth: 6
# Predicted label: 9, Ground truth: 5
# Predicted label: 2, Ground truth: 12
# Predicted label: 10, Ground truth: 6
# Predicted label: 3, Ground truth: 7
# Predicted label: 11, Ground truth: 9
# Predicted label: 5, Ground truth: 7
# Predicted label: 5, Ground truth: 4
# Predicted label: 7, Ground truth: 1
# Predicted label: 3, Ground truth: 11
# Predicted label: 6, Ground truth: 2
# Predicted label: 6, Ground truth: 0
# Predicted label: 6, Ground truth: 12
# Predicting... 10000/10954
# Predicted label: 3, Ground truth: 11
# Predicted label: 8, Ground truth: 12
# Predicted label: 4, Ground truth: 0
# Predicted label: 12, Ground truth: 13
# Predicted label: 10, Ground truth: 6
# Predicted label: 1, Ground truth: 0
# Predicted label: 3, Ground truth: 11
# Predicted label: 6, Ground truth: 12
# Predicted label: 13, Ground truth: 7
# Predicted label: 10, Ground truth: 13
# Predicted label: 3, Ground truth: 11
# Predicted label: 2, Ground truth: 10
# Predicted label: 9, Ground truth: 13
# Predicted label: 5, Ground truth: 7
# Predicted label: 9, Ground truth: 7
# Predicted label: 11, Ground truth: 7
# Predicted label: 3, Ground truth: 11
# Predicted label: 3, Ground truth: 11
# Predicted label: 8, Ground truth: 12
# Predicted label: 11, Ground truth: 3
# Predicted label: 12, Ground truth: 8
# Predicted label: 4, Ground truth: 5
# Predicted label: 13, Ground truth: 12
# Predicted label: 11, Ground truth: 5
# Predicted label: 12, Ground truth: 7
# Predicted label: 3, Ground truth: 2
# Predicted label: 13, Ground truth: 5
# Predicted label: 0, Ground truth: 1
# Predicted label: 8, Ground truth: 6
# Predicted label: 8, Ground truth: 2
# Predicted label: 1, Ground truth: 11
# Predicted label: 13, Ground truth: 5
# Predicted label: 11, Ground truth: 7
# Predicted label: 5, Ground truth: 1
# Predicted label: 13, Ground truth: 9
# Predicted label: 6, Ground truth: 1
# Predicted label: 13, Ground truth: 12
# Predicted label: 12, Ground truth: 6
# Predicted label: 6, Ground truth: 12
# Predicted label: 6, Ground truth: 12
# Predicted label: 9, Ground truth: 8
# Predicted label: 6, Ground truth: 10
# Predicted label: 5, Ground truth: 1
# Predicted label: 6, Ground truth: 0
# Predicted label: 5, Ground truth: 1
# Predicted label: 7, Ground truth: 5
# Predicted label: 13, Ground truth: 7
# Predicted label: 6, Ground truth: 4
# Predicted label: 3, Ground truth: 11
# Predicted label: 11, Ground truth: 3
# Predicted label: 10, Ground truth: 2
# Predicted label: 13, Ground truth: 9
# Predicted label: 2, Ground truth: 10
# Predicted label: 7, Ground truth: 13
# Predicted label: 12, Ground truth: 4
# Predicted label: 6, Ground truth: 0
# Predicted label: 13, Ground truth: 1
# Predicted label: 4, Ground truth: 6
# Predicted label: 13, Ground truth: 7
# Predicted label: 10, Ground truth: 2
# Predicted label: 13, Ground truth: 9
# Predicted label: 7, Ground truth: 13
# Predicted label: 13, Ground truth: 3
# Predicted label: 6, Ground truth: 4
# Predicted label: 4, Ground truth: 10
# Predicted label: 4, Ground truth: 6
# Predicted label: 12, Ground truth: 11
# Predicted label: 9, Ground truth: 7
# Predicted label: 8, Ground truth: 9
# Predicted label: 10, Ground truth: 11
# Predicted label: 10, Ground truth: 5
# Predicted label: 5, Ground truth: 1
# Predicted label: 10, Ground truth: 4
# Predicted label: 4, Ground truth: 12
# Predicted label: 6, Ground truth: 12
# Predicted label: 13, Ground truth: 7
# Predicted label: 4, Ground truth: 12
# Predicted label: 6, Ground truth: 12
# Predicted label: 13, Ground truth: 7
# Predicted label: 10, Ground truth: 0
# Predicted label: 13, Ground truth: 7
# Predicted label: 4, Ground truth: 6
# Predicted label: 3, Ground truth: 11
# Predicted label: 12, Ground truth: 6
# Predicted label: 2, Ground truth: 6
# Predicted label: 5, Ground truth: 7
# Predicted label: 4, Ground truth: 7
# Predicted label: 9, Ground truth: 13
# Predicted label: 13, Ground truth: 9
# Predicted label: 3, Ground truth: 11
# Predicted label: 12, Ground truth: 0
# Predicted label: 3, Ground truth: 11
# Predicted label: 3, Ground truth: 11
# Predicted label: 7, Ground truth: 3
# Predicted label: 12, Ground truth: 6
# Predicted label: 7, Ground truth: 5
# Predicted label: 12, Ground truth: 8
# Predicted label: 7, Ground truth: 13
# Predicted label: 10, Ground truth: 2
# Predicted label: 7, Ground truth: 11
# Predicted label: 7, Ground truth: 6
# Predicted label: 3, Ground truth: 11
# Predicted label: 10, Ground truth: 6
# Predicted label: 3, Ground truth: 11
# Predicted label: 7, Ground truth: 1
# Predicted label: 11, Ground truth: 3
# Predicted label: 12, Ground truth: 6
# Predicted label: 4, Ground truth: 6
# Predicted label: 12, Ground truth: 7
# Predicted label: 10, Ground truth: 3
# Predicted label: 12, Ground truth: 6
# Predicted label: 11, Ground truth: 3
# Predicted label: 7, Ground truth: 1
# Predicted label: 12, Ground truth: 8
# Predicted label: 2, Ground truth: 10
# Predicted label: 7, Ground truth: 5
# Predicted label: 4, Ground truth: 2
# Predicted label: 3, Ground truth: 11
# Predicted label: 3, Ground truth: 11
# Predicted label: 2, Ground truth: 10
# Predicted label: 12, Ground truth: 8
# Predicted label: 9, Ground truth: 7
# Predicted label: 4, Ground truth: 6
# Predicted label: 13, Ground truth: 3
# Predicted label: 11, Ground truth: 3
# Predicted label: 12, Ground truth: 6
# Predicted label: 13, Ground truth: 5
# Predicted label: 6, Ground truth: 4
# Predicted label: 10, Ground truth: 11
# Predicted label: 7, Ground truth: 5
# Predicted label: 10, Ground truth: 0
# Predicted label: 10, Ground truth: 2
# Predicted label: 9, Ground truth: 7
# Predicted label: 3, Ground truth: 11
# Predicted label: 10, Ground truth: 2
# Predicted label: 1, Ground truth: 0
# Predicted label: 12, Ground truth: 4
# Predicted label: 2, Ground truth: 10
# Predicted label: 3, Ground truth: 5
# Predicted label: 3, Ground truth: 11
# Predicted label: 13, Ground truth: 6
# Predicted label: 5, Ground truth: 4
# Predicted label: 13, Ground truth: 9
# Predicted label: 5, Ground truth: 1
# Predicted label: 2, Ground truth: 3
# Predicted label: 5, Ground truth: 7
# Predicted label: 9, Ground truth: 13
# Predicted label: 13, Ground truth: 3
# Predicted label: 12, Ground truth: 6
# Predicted label: 3, Ground truth: 11
# Predicted label: 12, Ground truth: 6
# Predicted label: 12, Ground truth: 8
# Predicted label: 10, Ground truth: 0
# Predicted label: 1, Ground truth: 0
# Predicted label: 4, Ground truth: 5
# Predicted label: 9, Ground truth: 7
# Predicted label: 9, Ground truth: 7
# Predicted label: 8, Ground truth: 10
# Predicted label: 7, Ground truth: 13
# Predicted label: 6, Ground truth: 8
# Predicted label: 10, Ground truth: 11
# Predicted label: 2, Ground truth: 12
# Predicted label: 0, Ground truth: 1
# Predicted label: 8, Ground truth: 10
# Predicted label: 2, Ground truth: 3
# Predicted label: 7, Ground truth: 6
# Predicted label: 8, Ground truth: 6
# Predicted label: 4, Ground truth: 6
# Predicted label: 3, Ground truth: 11
# Predicted label: 9, Ground truth: 5
# Predicted label: 4, Ground truth: 6
# Predicted label: 11, Ground truth: 7
# Predicted label: 13, Ground truth: 7
# Predicted label: 11, Ground truth: 5
# Predicted label: 4, Ground truth: 6
# Predicted label: 9, Ground truth: 13
# Predicted label: 11, Ground truth: 3
# Predicted label: 8, Ground truth: 12
# Predicted label: 12, Ground truth: 13
# Predicted label: 4, Ground truth: 10
# Predicted label: 6, Ground truth: 12
# Predicted label: 12, Ground truth: 6
# Predicted label: 9, Ground truth: 6
# Predicted label: 13, Ground truth: 6
# Predicted label: 9, Ground truth: 7
# Predicted label: 4, Ground truth: 5
# Predicted label: 13, Ground truth: 9
# Predicted label: 13, Ground truth: 7
# Predicted label: 9, Ground truth: 1
# Predicted label: 12, Ground truth: 8
# Predicted label: 2, Ground truth: 10
# Predicted label: 6, Ground truth: 10
# Predicted label: 2, Ground truth: 12
# Predicted label: 9, Ground truth: 13
# Predicted label: 5, Ground truth: 11
# Predicted label: 3, Ground truth: 11
# Predicted label: 4, Ground truth: 6
# Predicted label: 8, Ground truth: 6
# Predicted label: 2, Ground truth: 10
# Predicted label: 2, Ground truth: 10
# Predicted label: 2, Ground truth: 10
# Predicted label: 7, Ground truth: 9
# Predicted label: 13, Ground truth: 12
# Predicted label: 7, Ground truth: 1
# Predicted label: 12, Ground truth: 8
# Predicted label: 9, Ground truth: 13
# Predicted label: 8, Ground truth: 4
# Predicted label: 6, Ground truth: 10
# Predicted label: 0, Ground truth: 1
# Predicted label: 4, Ground truth: 0
# Predicted label: 3, Ground truth: 11
# Predicted label: 6, Ground truth: 2
# Predicted label: 4, Ground truth: 6
# Predicted label: 3, Ground truth: 11
# Predicted label: 12, Ground truth: 6
# Predicted label: 12, Ground truth: 3
# Predicted label: 13, Ground truth: 7
# Predicted label: 10, Ground truth: 4
# Predicted label: 9, Ground truth: 1
# Predicted label: 0, Ground truth: 1
# Predicted label: 7, Ground truth: 11
# Predicted label: 10, Ground truth: 0
# Predicted label: 8, Ground truth: 10
# Predicted label: 9, Ground truth: 13
# Predicted label: 3, Ground truth: 11
# Predicted label: 4, Ground truth: 0
# Predicted label: 11, Ground truth: 3
# Predicted label: 11, Ground truth: 10
# Predicted label: 6, Ground truth: 4
# Predicted label: 6, Ground truth: 4
# Predicted label: 10, Ground truth: 3
# Predicted label: 3, Ground truth: 5
# Predicted label: 5, Ground truth: 7
# Predicted label: 6, Ground truth: 8
# Predicted label: 3, Ground truth: 11
# Predicted label: 8, Ground truth: 4
# Predicted label: 9, Ground truth: 5
# Predicted label: 13, Ground truth: 12
# Predicted label: 11, Ground truth: 7
# Predicted label: 10, Ground truth: 2
# Predicted label: 12, Ground truth: 6
# Predicted label: 8, Ground truth: 6
# Predicted label: 2, Ground truth: 5
# Predicted label: 9, Ground truth: 13
# Predicted label: 7, Ground truth: 13
# Predicted label: 9, Ground truth: 5
# Predicted label: 11, Ground truth: 7
# Predicted label: 6, Ground truth: 0
# Predicted label: 10, Ground truth: 11
# Predicted label: 12, Ground truth: 6
# Predicted label: 3, Ground truth: 11
# Predicted label: 9, Ground truth: 7
# Predicted label: 6, Ground truth: 0
# Predicted label: 13, Ground truth: 7
# Predicted label: 0, Ground truth: 1
# Predicted label: 6, Ground truth: 2
# Predicted label: 7, Ground truth: 9
# Predicted label: 9, Ground truth: 7
# Predicted label: 9, Ground truth: 7
# Predicted label: 12, Ground truth: 6
# Predicted label: 9, Ground truth: 13
# Predicted label: 8, Ground truth: 6
# Predicted label: 1, Ground truth: 0
# Predicted label: 8, Ground truth: 9
# Predicted label: 8, Ground truth: 12
# Predicted label: 2, Ground truth: 6
# Predicted label: 9, Ground truth: 7
# Predicted label: 12, Ground truth: 4
# Predicted label: 9, Ground truth: 0
# Predicted label: 5, Ground truth: 7
# Predicted label: 8, Ground truth: 6
# Predicted label: 10, Ground truth: 2
# Predicted label: 7, Ground truth: 5
# Predicted label: 4, Ground truth: 6
# Predicted label: 5, Ground truth: 1
# Predicted label: 8, Ground truth: 12
# Predicted label: 2, Ground truth: 10
# Predicted label: 1, Ground truth: 0
# Predicted label: 9, Ground truth: 5
# Predicted label: 12, Ground truth: 8
# Predicted label: 9, Ground truth: 1
# Predicted label: 7, Ground truth: 8
# Predicted label: 3, Ground truth: 11
# Predicted label: 9, Ground truth: 13
# Predicted label: 2, Ground truth: 7
# Predicted label: 7, Ground truth: 6
# Predicted label: 4, Ground truth: 0
# Predicted label: 3, Ground truth: 13
# Predicted label: 0, Ground truth: 1
# Predicted label: 6, Ground truth: 12
# Predicted label: 6, Ground truth: 1
# Predicted label: 9, Ground truth: 5
# Predicted label: 3, Ground truth: 11
# Predicted label: 8, Ground truth: 0
# Predicted label: 7, Ground truth: 9
# Predicted label: 0, Ground truth: 1
# Predicted label: 7, Ground truth: 5
# Predicted label: 3, Ground truth: 11
# Predicted label: 10, Ground truth: 6
# Predicted label: 7, Ground truth: 5
# Predicted label: 11, Ground truth: 7
# Predicted label: 11, Ground truth: 3
# Predicted label: 9, Ground truth: 1
# Predicted label: 10, Ground truth: 1
# Predicted label: 3, Ground truth: 11
# Predicted label: 12, Ground truth: 8
# Predicted label: 12, Ground truth: 6
# Predicted label: 9, Ground truth: 4
# Predicted label: 7, Ground truth: 5
# Predicted label: 7, Ground truth: 9
# Predicted label: 11, Ground truth: 3
# Predicted label: 0, Ground truth: 1
# Predicted label: 6, Ground truth: 2
# Predicted label: 10, Ground truth: 7
# Predicted label: 5, Ground truth: 7
# Predicted label: 2, Ground truth: 12
# Predicted label: 4, Ground truth: 0
# Predicted label: 5, Ground truth: 11
# Predicted label: 9, Ground truth: 13
# Predicted label: 9, Ground truth: 7
# Predicted label: 3, Ground truth: 11
# Predicted label: 9, Ground truth: 5
# Predicted label: 3, Ground truth: 11
# Predicted label: 3, Ground truth: 11
# Predicted label: 2, Ground truth: 3
# Predicted label: 13, Ground truth: 7
# Predicted label: 13, Ground truth: 7
# Predicted label: 12, Ground truth: 8
# Predicted label: 12, Ground truth: 13
# Predicted label: 10, Ground truth: 6
# Predicted label: 7, Ground truth: 13
# Predicted label: 7, Ground truth: 5
# Predicted label: 12, Ground truth: 6
# Predicted label: 5, Ground truth: 11
# Predicted label: 7, Ground truth: 11
# Predicted label: 6, Ground truth: 4
# Predicted label: 10, Ground truth: 2
# Predicted label: 10, Ground truth: 6
# Predicted label: 7, Ground truth: 1
# Predicted label: 9, Ground truth: 2
# Predicted label: 7, Ground truth: 13
# Predicted label: 11, Ground truth: 3
# Predicted label: 0, Ground truth: 1
# Predicted label: 12, Ground truth: 13
# Predicted label: 10, Ground truth: 2
# Predicted label: 6, Ground truth: 0
# Predicted label: 2, Ground truth: 0
# Predicted label: 13, Ground truth: 9
# Predicted label: 5, Ground truth: 10
# Predicted label: 7, Ground truth: 11
# Predicted label: 4, Ground truth: 8
# Predicted label: 2, Ground truth: 10
# Predicted label: 10, Ground truth: 2
# Predicted label: 10, Ground truth: 6
# Predicted label: 11, Ground truth: 3
# Predicted label: 11, Ground truth: 3
# Predicted label: 7, Ground truth: 1
# Predicted label: 11, Ground truth: 13
# Predicted label: 1, Ground truth: 0
# Predicted label: 0, Ground truth: 11
# Predicted label: 2, Ground truth: 6
# Predicted label: 11, Ground truth: 10
# Predicted label: 12, Ground truth: 6
# Predicted label: 2, Ground truth: 5
# Predicted label: 12, Ground truth: 2
# Predicted label: 10, Ground truth: 8
# Predicted label: 13, Ground truth: 7
# Predicted label: 12, Ground truth: 6
# Predicted label: 7, Ground truth: 13
# Predicted label: 13, Ground truth: 5
# Predicted label: 0, Ground truth: 6
# Predicted label: 11, Ground truth: 5
# Predicted label: 12, Ground truth: 13
# Predicted label: 2, Ground truth: 10
# Predicted label: 3, Ground truth: 0
# Predicted label: 9, Ground truth: 7
# Predicted label: 2, Ground truth: 3
# Predicted label: 1, Ground truth: 7
# Predicted label: 13, Ground truth: 7
# Predicted label: 9, Ground truth: 11
# Predicted label: 9, Ground truth: 13
# Predicted label: 7, Ground truth: 13
# Predicted label: 2, Ground truth: 0
# Predicted label: 13, Ground truth: 5
# Predicted label: 12, Ground truth: 13
# Predicted label: 13, Ground truth: 9
# Predicted label: 4, Ground truth: 0
# Predicted label: 10, Ground truth: 2
# Predicted label: 0, Ground truth: 1
# Predicted label: 3, Ground truth: 11
# Predicted label: 0, Ground truth: 1
# Predicted label: 8, Ground truth: 4
# Predicted label: 11, Ground truth: 3
# Predicted label: 2, Ground truth: 13
# Predicted label: 9, Ground truth: 7
# Predicted label: 2, Ground truth: 10
# Predicted label: 1, Ground truth: 7
# Predicted label: 3, Ground truth: 11
# Predicted label: 1, Ground truth: 0
# Predicted label: 2, Ground truth: 13
# Predicted label: 3, Ground truth: 11
# Predicted label: 2, Ground truth: 10
# Predicted label: 1, Ground truth: 12
# Predicted label: 9, Ground truth: 7
# Predicted label: 2, Ground truth: 6
# Predicted label: 3, Ground truth: 13
# Predicted label: 11, Ground truth: 3
# Predicted label: 12, Ground truth: 8
# Predicted label: 0, Ground truth: 1
# Predicted label: 5, Ground truth: 1
# Predicted label: 2, Ground truth: 12
# Predicted label: 6, Ground truth: 4
# Predicted label: 12, Ground truth: 8
# Predicted label: 9, Ground truth: 3
# Predicted label: 4, Ground truth: 0
# Predicted label: 7, Ground truth: 9
# Predicted label: 13, Ground truth: 9

# %%
# Print the overall accuracy and accuracy for each class
print('size of test set: {}, accuracy of the network on the test set: {:.2f}%'.format(total, 100 * correct / total))
for i in range(14):
    print('Accuracy of {} : {:.0f}% of {} images'.format(classes[i], 100 * class_correct[i] / class_total[i], class_total[i]))
print("miss_predicated_images num = {}".format(len(miss_predicated_images)))
# Out:
# size of test set: 10954, accuracy of the network on the test set: 59.38%
# Accuracy of Black+Female : 60% of 757 images
# Accuracy of Black+Male : 54% of 799 images
# Accuracy of East Asian+Female : 73% of 773 images
# Accuracy of East Asian+Male : 73% of 777 images
# Accuracy of Indian+Female : 71% of 763 images
# Accuracy of Indian+Male : 54% of 753 images
# Accuracy of Latino_Hispanic+Female : 44% of 830 images
# Accuracy of Latino_Hispanic+Male : 38% of 793 images
# Accuracy of Middle Eastern+Female : 51% of 396 images
# Accuracy of Middle Eastern+Male : 69% of 813 images
# Accuracy of Southeast Asian+Female : 53% of 680 images
# Accuracy of Southeast Asian+Male : 40% of 735 images
# Accuracy of White+Female : 72% of 963 images
# Accuracy of White+Male : 68% of 1122 images
# miss_predicated_images num = 4449

# %%
print(len(activation_all_images))
# print(len(activation_all_images[0]))
# print(len(activation_all_images[0]["features.22"][0]))
hooked_layer_names = list(activation.keys())
print(hooked_layer_names)
print(len(filtersum_all_images[0]))
print((filtersum_all_images[0]))
# Out:
# 0
# ['relu', 'layer1.0.relu', 'layer1.1.relu', 'layer1.2.relu', 'layer2.0.relu', 'layer2.1.relu', 'layer2.2.relu', 'layer2.3.relu', 'layer3.0.relu', 'layer3.1.relu', 'layer3.2.relu', 'layer3.3.relu', 'layer3.4.relu', 'layer3.5.relu', 'layer4.0.relu', 'layer4.1.relu', 'layer4.2.relu']
# 17
# {'relu': [6902.42333984375, 2055.44384765625, 3193.74609375, 4554.61669921875, 2075.437744140625, 3282.76806640625, 2260.494140625, 12588.0166015625, 6679.41796875, 392.167236328125, 3840.67041015625, 4153.439453125, 1049.033203125, 2715.30810546875, 3239.101318359375, 0.0, 0.0, 2818.8515625, 2271.50830078125, 151.23858642578125, 4537.07470703125, 3511.21826171875, 2741.09619140625, 660.6498413085938, 4321.2470703125, 2959.79638671875, 7638.47607421875, 8522.2158203125, 4451.451171875, 2973.71435546875, 6282.3154296875, 0.0, 3167.60302734375, 5770.0576171875, 258.6809997558594, 0.0, 5115.1357421875, 3565.72802734375, 9445.8720703125, 2063.2041015625, 4025.4951171875, 0.0, 3077.183349609375, 656.4389038085938, 2696.92041015625, 24.65072250366211, 0.0, 0.0, 318.1614990234375, 0.0, 1150.361572265625, 3026.62841796875, 4543.16357421875, 6871.47509765625, 3293.295166015625, 7154.2421875, 3098.2626953125, 0.0, 6636.7119140625, 3725.82958984375, 45.735084533691406, 2198.47021484375, 7727.01904296875, 0.0], 'layer1.0.relu': [1435.367431640625, 1443.998779296875, 1948.789306640625, 1533.620849609375, 986.9879760742188, 1418.5562744140625, 873.824462890625, 3451.1328125, 1398.3875732421875, 774.6201171875, 1137.918212890625, 1728.863037109375, 815.6395874023438, 1892.6220703125, 1734.8701171875, 676.7574462890625, 279.642578125, 764.2142333984375, 1872.42724609375, 76.72885131835938, 1678.5125732421875, 2432.325439453125, 1234.611328125, 63.452598571777344, 1347.876220703125, 616.157470703125, 2432.15380859375, 2040.760009765625, 1842.8546142578125, 1105.936279296875, 1441.07373046875, 1476.169921875, 871.337890625, 1002.4070434570312, 886.5947265625, 446.75408935546875, 1433.947021484375, 1767.244384765625, 2385.44189453125, 464.02264404296875, 1675.950439453125, 419.9134216308594, 1615.919677734375, 586.2423095703125, 2253.23046875, 9.61633586883545, 619.4046630859375, 576.8307495117188, 106.24706268310547, 1011.9794921875, 374.7452392578125, 1521.033447265625, 2254.923095703125, 2021.9888916015625, 1162.1824951171875, 2128.56787109375, 1906.339111328125, 283.9865417480469, 1967.07177734375, 1208.8045654296875, 970.830810546875, 844.9845581054688, 3632.316650390625, 1140.8431396484375], 'layer1.1.relu': [1843.2578125, 825.7351684570312, 2236.565185546875, 1312.94921875, 1684.7034912109375, 1094.39990234375, 1076.641357421875, 2988.4658203125, 499.9189758300781, 664.2060546875, 873.8441162109375, 1409.303955078125, 956.2314453125, 2360.64990234375, 1415.34619140625, 1075.873779296875, 946.9895629882812, 509.6318359375, 2109.060546875, 348.02142333984375, 1510.950439453125, 2975.2333984375, 2071.568359375, 960.127197265625, 1515.443603515625, 1178.13671875, 2722.847900390625, 2029.747802734375, 1915.88232421875, 342.402099609375, 1325.885986328125, 1574.029296875, 777.9683227539062, 993.46142578125, 1332.609619140625, 432.99609375, 1646.6966552734375, 1618.23583984375, 2472.4287109375, 237.232666015625, 1923.3831787109375, 1133.3336181640625, 1830.650146484375, 785.31884765625, 2880.721923828125, 953.3590698242188, 1414.569091796875, 1068.9610595703125, 67.62015533447266, 1693.4658203125, 660.01123046875, 975.72998046875, 3318.18701171875, 1838.802001953125, 1008.8690185546875, 2620.37060546875, 2319.879150390625, 536.0523681640625, 1626.572509765625, 851.1512451171875, 1885.7509765625, 681.5855102539062, 4811.5546875, 1619.194091796875], 'layer1.2.relu': [2088.25, 296.6631164550781, 2750.97412109375, 1613.62646484375, 2095.21875, 1651.1981201171875, 1275.4052734375, 2814.757568359375, 542.6412353515625, 585.7255859375, 621.3330078125, 1666.393798828125, 1073.28173828125, 2636.42333984375, 1339.5780029296875, 1511.84375, 1445.851318359375, 419.1265869140625, 2000.1278076171875, 412.11962890625, 1711.387451171875, 3086.525634765625, 2414.8720703125, 1632.6318359375, 1527.220703125, 2077.01318359375, 2907.776611328125, 2310.670654296875, 2266.228271484375, 825.9711303710938, 1383.2030029296875, 1908.4775390625, 748.2874145507812, 1873.722 ...

# %%
def save_intermediate_data(data, file_path):
    """
    Save intermediate data to a file using pickle serialization.

    Args:
        data: The data to be saved.
        file_path (str): The path of the file to save the data.
    """
    with open(file_path, 'wb') as file:
        pickle.dump(data, file)
# save intermediate results
save_intermediate_data(activation_all_images, "activation_CIFAR10_VGG16.pkl")
save_intermediate_data(image_predictation_result, "image_predictation_result.pkl")
save_intermediate_data(miss_predicated_images, "miss_predicated_images.pkl")
save_intermediate_data(hooked_layer_names, "hooked_layer_names.pkl")
save_intermediate_data(filtersum_all_images, "filtersum_all_images.pkl")
save_intermediate_data(num_filters, "num_filters.pkl")

# %%
def load_intermediate_data(file_path):
    """
    Load intermediate data from a file.

    Args:
        file_path (str): The path of the file to load the data from.

    Returns:
        The loaded data.
    """
    with open(file_path, 'rb') as file:
        data = pickle.load(file)
    return data


activation_all_images = load_intermediate_data("activation_CIFAR10_VGG16.pkl")
image_predictation_result = load_intermediate_data("image_predictation_result.pkl")
miss_predicated_images = load_intermediate_data("miss_predicated_images.pkl")
hooked_layer_names = load_intermediate_data("hooked_layer_names.pkl")
filtersum_all_images = load_intermediate_data("filtersum_all_images.pkl")
num_filters = load_intermediate_data("num_filters.pkl")

# %%
num_test_images = len(filtersum_all_images)
def find_outliers_zscore(data, threshold=1):
    """
    Find outliers in a list of values using z-score method.

    Args:
        data (list or numpy array): List of numeric values.
        threshold (float, optional): Z-score threshold for identifying outliers. Default is 3.

    Returns:
        list: List of outlier values.
    """
    # Convert data to numpy array
    data = np.array(data)
    if np.std(data) == 0:
        return []
    # Calculate z-scores
    z_scores = (data - np.mean(data)) / np.std(data)
    # Find outliers based on the threshold
    # outliers = data[np.abs(z_scores) > threshold]
    outliers = np.where(z_scores < -threshold)[0]
    return outliers

# %%
# find outlier for all mis_predicated images:
# cat (3)
class_id = 3
all_image_class = image_predictation_result[class_id].keys()
wrong_images = [x for x in all_image_class if image_predictation_result[class_id][x] != class_id]
print("num of wrong images in class {} is {}".format(class_id, len(wrong_images)))
# Out:
# num of wrong images in class 3 is 213

# %%
z_score_threshold = 1.0

for layer_name in hooked_layer_names:
    print("layer {}".format(layer_name))
    for image in wrong_images:
        # print("image # {}".format(image))
        outliers = find_outliers_zscore(filtersum_all_images[image][layer_name], threshold=z_score_threshold)
        if len(outliers) > 0:
            print("image # {}, layer # {} has outliers {}".format(image, layer_name, outliers))
# Out:
# layer relu
# image # 19, layer # relu has outliers [12 15 16 23 31 35 41 46 47 48 49 57 63]
# image # 171, layer # relu has outliers [15 16 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 250, layer # relu has outliers [12 15 16 19 23 31 35 41 45 46 47 48 49 57 60 63]
# image # 280, layer # relu has outliers [12 15 16 19 23 31 34 35 41 45 46 47 48 49 50 57 60 63]
# image # 349, layer # relu has outliers [12 15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 399, layer # relu has outliers [15 16 19 31 34 35 41 43 46 47 49 57 60 63]
# image # 519, layer # relu has outliers [15 16 19 23 31 34 35 41 45 46 47 48 49 50 57 60 63]
# image # 540, layer # relu has outliers [12 15 16 23 31 35 41 46 47 48 49 57 60 63]
# image # 551, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 738, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 739, layer # relu has outliers [12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 780, layer # relu has outliers [12 15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 821, layer # relu has outliers [ 9 15 16 23 31 35 41 45 46 47 48 49 57 60 63]
# image # 878, layer # relu has outliers [ 9 15 16 19 31 34 35 41 43 45 46 47 48 49 57 60 63]
# image # 907, layer # relu has outliers [ 4 12 15 16 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 1017, layer # relu has outliers [12 15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 1042, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 1134, layer # relu has outliers [15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 1250, layer # relu has outliers [15 16 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 1296, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 1365, layer # relu has outliers [12 15 16 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 1382, layer # relu has outliers [12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 1392, layer # relu has outliers [15 16 31 34 35 41 46 47 48 49 57 60 63]
# image # 1451, layer # relu has outliers [15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 1457, layer # relu has outliers [15 16 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 1487, layer # relu has outliers [15 16 19 31 35 41 45 46 47 48 49 57 60 63]
# image # 1520, layer # relu has outliers [15 16 31 34 35 41 46 47 48 49 57 60 63]
# image # 1545, layer # relu has outliers [ 9 15 16 19 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 1724, layer # relu has outliers [12 15 16 23 31 35 41 46 47 48 49 50 57 63]
# image # 1777, layer # relu has outliers [15 16 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 1797, layer # relu has outliers [15 16 31 34 35 41 46 47 48 49 50 57 60 63]
# image # 1906, layer # relu has outliers [12 15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 1969, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 1970, layer # relu has outliers [ 9 12 15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 2006, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 2025, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 2117, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 2279, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 2421, layer # relu has outliers [15 16 19 31 34 35 41 43 45 46 47 48 49 57 60 63]
# image # 2635, layer # relu has outliers [15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 2683, layer # relu has outliers [15 16 19 23 31 34 35 41 45 46 47 48 49 50 57 60 63]
# image # 2727, layer # relu has outliers [15 16 23 31 35 41 46 47 48 49 50 57 63]
# image # 2785, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 2817, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 2831, layer # relu has outliers [ 4 12 15 16 23 31 35 41 46 47 48 49 50 57 63]
# image # 2919, layer # relu has outliers [15 16 19 31 35 41 46 47 48 49 57 60 63]
# image # 2937, layer # relu has outliers [15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 2962, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 2999, layer # relu has outliers [ 4 12 15 16 23 31 35 41 46 47 48 49 57 60 63]
# image # 3065, layer # relu has outliers [12 15 16 23 31 35 41 46 47 48 49 57 63]
# image # 3147, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 3155, layer # relu has outliers [15 16 31 34 35 41 46 47 48 49 57 60 63]
# image # 3285, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 3394, layer # relu has outliers [12 15 16 31 34 35 41 46 47 48 49 57 60 63]
# image # 3643, layer # relu has outliers [12 15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 3652, layer # relu has outliers [ 9 15 16 19 31 34 35 41 43 45 46 47 48 49 57 60 63]
# image # 3811, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 3814, layer # relu has outliers [12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 3846, layer # relu has outliers [ 9 15 16 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 3927, layer # relu has outliers [12 15 16 23 31 35 41 46 47 48 49 50 57 63]
# image # 3930, layer # relu has outliers [ 4 12 15 16 23 31 35 41 46 47 48 49 50 57 63]
# image # 3953, layer # relu has outliers [15 16 19 31 35 41 45 46 47 48 49 57 60 63]
# image # 4002, layer # relu has outliers [ 9 15 16 19 31 34 35 41 43 45 46 47 49 57 60 63]
# image # 4064, layer # relu has outliers [ 9 15 16 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 4078, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 4100, layer # relu has outliers [15 16 19 31 34 35 41 43 45 46 47 48 49 57 60 63]
# image # 4115, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 4199, layer # relu has outliers [15 16 19 23 31 35 41 45 46 47 48 49 57 60 63]
# image # 4256, layer # relu has outliers [15 16 23 31 35 41 46 47 48 49 57 63]
# image # 4342, layer # relu has outliers [ 9 15 16 19 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 4374, layer # relu has outliers [15 16 19 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 4387, layer # relu has outliers [ 9 15 16 23 31 34 35 41 45 46 47 48 49 50 57 60 63]
# image # 4388, layer # relu has outliers [ 9 15 16 19 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 4452, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 4484, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 4509, layer # relu has outliers [12 15 16 23 31 35 41 46 47 48 49 57 63]
# image # 4640, layer # relu has outliers [ 9 12 15 16 19 23 31 35 41 45 46 47 48 49 57 60 63]
# image # 4711, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 4855, layer # relu has outliers [ 9 15 16 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 4913, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 5193, layer # relu has outliers [15 16 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 5217, layer # relu has outliers [12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 5244, layer # relu has outliers [15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 5341, layer # relu has outliers [12 15 16 19 23 31 35 41 45 46 47 48 49 57 60 63]
# image # 5358, layer # relu has outliers [ 9 15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 5434, layer # relu has outliers [15 16 19 31 35 41 45 46 47 48 49 57 60 63]
# image # 5504, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 5518, layer # relu has outliers [15 16 19 31 35 41 45 46 47 49 57 60 63]
# image # 5533, layer # relu has outliers [12 15 16 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 5576, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 5619, layer # relu has outliers [ 4 12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 5633, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 5969, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 5975, layer # relu has outliers [15 16 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 6114, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 6174, layer # relu has outliers [ 9 15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 6225, layer # relu has outliers [ 9 15 16 19 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 6237, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 6285, layer # relu has outliers [ 9 15 16 19 23 31 34 35 41 45 46 47 48 49 50 57 60 63]
# image # 6346, layer # relu has outliers [15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 6426, layer # relu has outliers [12 15 16 19 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 6436, layer # relu has outliers [ 9 15 16 19 31 34 35 41 43 45 46 47 49 57 60 63]
# image # 6499, layer # relu has outliers [15 16 23 31 34 35 41 45 46 47 48 49 50 57 60 63]
# image # 6513, layer # relu has outliers [12 15 16 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 6600, layer # relu has outliers [ 9 12 15 16 19 23 31 35 41 45 46 47 48 49 57 60 63]
# image # 6669, layer # relu has outliers [15 16 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 6747, layer # relu has outliers [15 16 19 23 31 35 41 45 46 47 48 49 57 60 63]
# image # 6908, layer # relu has outliers [15 16 31 35 41 46 47 48 49 57 60 63]
# image # 6974, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 7114, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 7139, layer # relu has outliers [15 16 23 31 34 35 41 45 46 47 48 49 50 57 60 63]
# image # 7310, layer # relu has outliers [12 15 16 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 7357, layer # relu has outliers [15 16 19 31 35 41 46 47 48 49 57 60 63]
# image # 7370, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 7416, layer # relu has outliers [ 9 15 16 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 7462, layer # relu has outliers [12 15 16 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 7481, layer # relu has outliers [15 16 19 31 34 35 41 46 47 49 57 60 63]
# image # 7515, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 7659, layer # relu has outliers [12 15 16 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 7718, layer # relu has outliers [ 9 15 16 19 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 7725, layer # relu has outliers [ 9 15 16 19 31 35 41 43 45 46 47 48 49 57 60 63]
# image # 7735, layer # relu has outliers [ 9 12 15 16 23 31 34 35 41 45 46 47 48 49 50 57 60 63]
# image # 7781, layer # relu has outliers [15 16 31 35 41 46 47 48 49 57 63]
# image # 7828, layer # relu has outliers [15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 7847, layer # relu has outliers [15 16 19 31 34 35 41 46 47 48 49 57 60 63]
# image # 7969, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 7972, layer # relu has outliers [15 16 19 31 34 35 41 43 45 46 47 49 57 60 63]
# image # 8011, layer # relu has outliers [15 16 31 34 35 41 46 47 48 49 57 60 63]
# image # 8014, layer # relu has outliers [15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 8047, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 8081, layer # relu has outliers [12 15 16 19 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 8101, layer # relu has outliers [12 15 16 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 8135, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 8138, layer # relu has outliers [15 16 31 35 41 46 47 48 49 57 60 63]
# image # 8161, layer # relu has outliers [ 9 15 16 19 31 34 35 41 43 45 46 47 49 57 60 63]
# image # 8166, layer # relu has outliers [12 15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 8174, layer # relu has outliers [12 15 16 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 8197, layer # relu has outliers [ 9 15 16 19 31 34 35 41 43 45 46 47 48 49 57 60 63]
# image # 8253, layer # relu has outliers [12 15 16 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 8273, layer # relu has outliers [15 16 19 31 35 41 46 47 48 49 57 60 63]
# image # 8353, layer # relu has outliers [15 16 31 35 41 46 47 48 49 57 60 63]
# image # 8358, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 8372, layer # relu has outliers [ 9 15 16 19 31 34 35 41 43 45 46 47 48 49 57 60 63]
# image # 8378, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 8414, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 8474, layer # relu has outliers [15 16 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 8493, layer # relu has outliers [ 9 12 15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 8535, layer # relu has outliers [12 15 16 23 31 35 41 46 47 48 49 57 60 63]
# image # 8608, layer # relu has outliers [12 15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 8612, layer # relu has outliers [15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 8717, layer # relu has outliers [ 9 12 15 16 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 8742, layer # relu has outliers [ 4 12 15 16 23 31 35 41 46 47 48 49 50 57 63]
# image # 8800, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 8867, layer # relu has outliers [15 16 19 31 35 41 46 47 48 49 57 60 63]
# image # 8882, layer # relu has outliers [15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 8909, layer # relu has outliers [ 9 15 16 19 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 8916, layer # relu has outliers [12 15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 8933, layer # relu has outliers [15 16 19 23 31 35 41 45 46 47 48 49 57 60 63]
# image # 8947, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 8985, layer # relu has outliers [12 15 16 23 31 35 41 46 47 48 49 50 57 63]
# image # 8996, layer # relu has outliers [15 16 23 31 34 35 41 45 46 47 48 49 50 57 60 63]
# image # 9126, layer # relu has outliers [ 9 15 16 19 31 35 41 45 46 47 49 57 60 63]
# image # 9208, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 9287, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 9320, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 9333, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 9388, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 9398, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 9544, layer # relu has outliers [12 15 16 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 9585, layer # relu has outliers [12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 9597, layer # relu has outliers [15 16 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 9716, layer # relu has outliers [15 16 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 9774, layer # relu has outliers [15 16 19 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 9870, layer # relu has outliers [12 15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 9914, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 9937, layer # relu has outliers [ 9 12 15 16 19 23 31 35 41 45 46 47 48 49 57 60 63]
# image # 9952, layer # relu has outliers [15 16 31 35 41 46 47 48 49 50 57 60 63]
# image # 10053, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 10129, layer # relu has outliers [15 16 19 31 35 41 45 46 47 48 49 57 60 63]
# image # 10156, layer # relu has outliers [15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 10225, layer # relu has outliers [ 9 15 16 19 31 34 35 41 43 45 46 47 49 57 60 63]
# image # 10263, layer # relu has outliers [ 4 12 15 16 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 10269, layer # relu has outliers [ 9 15 16 19 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 10274, layer # relu has outliers [12 15 16 23 31 35 41 45 46 47 48 49 57 60 63]
# image # 10296, layer # relu has outliers [12 15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 10297, layer # relu has outliers [15 16 23 31 35 41 46 47 48 49 50 57 63]
# image # 10338, layer # relu has outliers [15 16 31 35 41 45 46 47 48 49 57 60 63]
# image # 10343, layer # relu has outliers [12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 10385, layer # relu has outliers [15 16 19 24 31 35 41 46 47 48 49 57 60 63]
# image # 10418, layer # relu has outliers [ 9 15 16 19 31 34 35 41 43 45 46 47 49 57 60 63]
# image # 10496, layer # relu has outliers [12 15 16 23 31 35 41 46 47 48 49 50 57 63]
# image # 10513, layer # relu has outliers [15 16 31 35 41 46 47 48 49 57 60 63]
# image # 10524, layer # relu has outliers [12 15 16 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 10705, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 10739, layer # relu has outliers [15 16 19 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 10794, layer # relu has outliers [ 9 15 16 19 31 34 35 41 43 45 46 47 49 57 60 63]
# image # 10817, layer # relu has outliers [15 16 19 31 34 35 41 46 47 49 57 60 63]
# image # 10821, layer # relu has outliers [ 9 15 16 19 31 34 35 41 43 45 46 47 49 57 60 63]
# image # 10866, layer # relu has outliers [12 15 16 23 31 35 41 45 46 47 48 49 57 60 63]
# image # 10898, layer # relu has outliers [12 15 16 23 31 35 41 45 46 47 48 49 50 57 63]
# image # 10927, layer # relu has outliers [ 9 12 15 16 19 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 10946, layer # relu has outliers [15 16 31 34 35 41 45 46 47 49 57 60 63]
# layer layer1.0.relu
# image # 19, layer # layer1.0.relu has outliers [12 16 19 23 25 41 46 47 48 50 57]
# image # 171, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 48 50]
# image # 250, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 47 48 50 57]
# image # 280, layer # layer1.0.relu has outliers [15 16 19 23 25 34 41 45 46 47 48 50 57]
# image # 349, layer # layer1.0.relu has outliers [12 16 19 23 35 41 45 46 47 48 50]
# image # 384, layer # layer1.0.relu has outliers [16 17 19 23 35 39 41 45 48 57]
# image # 399, layer # layer1.0.relu has outliers [15 16 17 19 23 24 35 39 41 45 48 49 57]
# image # 519, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 46 48 50 57]
# image # 540, layer # layer1.0.relu has outliers [12 16 23 25 34 35 41 46 47 48 50 57]
# image # 551, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 46 47 48 57]
# image # 738, layer # layer1.0.relu has outliers [16 19 23 25 35 39 41 43 45 46 47 48 57]
# image # 739, layer # layer1.0.relu has outliers [12 16 19 23 41 45 46 47 48 50]
# image # 780, layer # layer1.0.relu has outliers [12 16 19 23 35 41 45 46 47 48 50]
# image # 821, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 47 48 50 57]
# image # 878, layer # layer1.0.relu has outliers [15 16 19 23 24 25 35 41 45 47 48 50 57]
# image # 907, layer # layer1.0.relu has outliers [12 16 23 25 41 45 46 47 48 50]
# image # 1017, layer # layer1.0.relu has outliers [12 16 19 23 41 45 46 48 50]
# image # 1042, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 48 50 57]
# image # 1134, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 47 48 50 57]
# image # 1250, layer # layer1.0.relu has outliers [15 16 23 25 34 35 41 45 46 47 48 57]
# image # 1296, layer # layer1.0.relu has outliers [16 19 23 34 35 36 41 45 46 47 48 57]
# image # 1365, layer # layer1.0.relu has outliers [12 16 19 23 41 45 46 48 50 57]
# image # 1382, layer # layer1.0.relu has outliers [12 16 19 23 34 41 45 46 47 48 50 57]
# image # 1392, layer # layer1.0.relu has outliers [15 16 19 23 24 34 35 41 45 46 47 48 50 57]
# image # 1451, layer # layer1.0.relu has outliers [12 16 19 23 41 45 46 48 50]
# image # 1457, layer # layer1.0.relu has outliers [15 16 19 23 25 34 41 45 46 47 48 50 57]
# image # 1487, layer # layer1.0.relu has outliers [16 19 23 24 35 41 45 46 47 48 50 57]
# image # 1520, layer # layer1.0.relu has outliers [15 16 19 23 25 34 41 45 46 47 48 50 57]
# image # 1545, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 48 50 57]
# image # 1724, layer # layer1.0.relu has outliers [12 16 19 23 25 41 45 46 47 48 50]
# image # 1777, layer # layer1.0.relu has outliers [15 16 19 23 34 41 45 46 47 48 50 57]
# image # 1797, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 47 48 50 57]
# image # 1906, layer # layer1.0.relu has outliers [12 16 19 23 35 41 45 46 47 48 50]
# image # 1969, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 48 57]
# image # 1970, layer # layer1.0.relu has outliers [15 16 19 23 25 34 36 41 45 46 47 48 57]
# image # 2006, layer # layer1.0.relu has outliers [16 19 23 25 35 41 45 46 47 48 57]
# image # 2025, layer # layer1.0.relu has outliers [16 19 23 35 36 39 41 45 48 57]
# image # 2117, layer # layer1.0.relu has outliers [16 17 19 23 35 39 41 45 48 57]
# image # 2269, layer # layer1.0.relu has outliers [15 16 19 23 35 41 45 47 48 55 57]
# image # 2279, layer # layer1.0.relu has outliers [16 19 23 35 36 39 41 45 46 48 57]
# image # 2421, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 48 50 57]
# image # 2464, layer # layer1.0.relu has outliers [15 16 17 19 23 35 39 41 45 48 49 57 63]
# image # 2635, layer # layer1.0.relu has outliers [16 19 23 35 41 46 47 48 50]
# image # 2683, layer # layer1.0.relu has outliers [16 19 23 25 34 35 41 45 46 47 48 50 57]
# image # 2727, layer # layer1.0.relu has outliers [12 15 16 23 25 31 34 41 46 47 48 50]
# image # 2785, layer # layer1.0.relu has outliers [16 19 23 35 39 41 43 45 47 48 57]
# image # 2817, layer # layer1.0.relu has outliers [16 19 23 25 35 41 45 48 50 57]
# image # 2831, layer # layer1.0.relu has outliers [12 16 23 41 45 46 48 50]
# image # 2919, layer # layer1.0.relu has outliers [15 16 19 23 24 25 35 41 45 46 47 48 50 57]
# image # 2937, layer # layer1.0.relu has outliers [12 16 19 23 35 41 45 46 47 48 50 57]
# image # 2942, layer # layer1.0.relu has outliers [15 19 24 41 43 45 47 48 50 57]
# image # 2962, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 46 48 50 57]
# image # 2999, layer # layer1.0.relu has outliers [12 16 19 23 34 35 41 45 46 47 48 50]
# image # 3065, layer # layer1.0.relu has outliers [12 15 16 23 35 41 45 46 47 48 50]
# image # 3147, layer # layer1.0.relu has outliers [15 16 19 23 25 31 34 36 41 45 46 47 48 57]
# image # 3155, layer # layer1.0.relu has outliers [15 16 19 23 35 41 45 46 47 48 50 57]
# image # 3285, layer # layer1.0.relu has outliers [15 16 19 23 34 35 39 41 45 46 47 48 57]
# image # 3394, layer # layer1.0.relu has outliers [16 19 23 25 35 41 45 46 47 48 50 57]
# image # 3643, layer # layer1.0.relu has outliers [12 16 19 23 25 34 35 41 45 46 47 48 50 57]
# image # 3652, layer # layer1.0.relu has outliers [16 19 23 35 39 41 43 45 48 50 57]
# image # 3811, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 48 57]
# image # 3814, layer # layer1.0.relu has outliers [12 15 16 23 25 31 34 41 45 46 47 48 50 57]
# image # 3846, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 48 50 57]
# image # 3927, layer # layer1.0.relu has outliers [12 16 23 41 45 46 48 50]
# image # 3930, layer # layer1.0.relu has outliers [12 16 19 23 41 46 47 48 50]
# image # 3953, layer # layer1.0.relu has outliers [16 19 23 24 35 41 45 46 47 48 50 57]
# image # 4002, layer # layer1.0.relu has outliers [15 16 19 23 35 41 43 45 46 47 48 57]
# image # 4014, layer # layer1.0.relu has outliers [12 15 16 23 31 46 48 50 51]
# image # 4064, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 47 48 50 57]
# image # 4078, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 46 47 48 50 57]
# image # 4100, layer # layer1.0.relu has outliers [15 16 19 23 24 35 41 43 45 47 48 57]
# image # 4115, layer # layer1.0.relu has outliers [16 17 19 23 35 39 41 45 48 57]
# image # 4199, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 47 48 50 57]
# image # 4256, layer # layer1.0.relu has outliers [16 23 41 46 47 48 50 57]
# image # 4342, layer # layer1.0.relu has outliers [16 19 23 34 35 41 45 46 47 48 50 57]
# image # 4374, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 47 48 50 57]
# image # 4387, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 47 48 50]
# image # 4388, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 46 48 50 57]
# image # 4452, layer # layer1.0.relu has outliers [16 17 19 23 35 39 41 45 48 57]
# image # 4484, layer # layer1.0.relu has outliers [15 16 19 23 35 41 45 46 47 48 57]
# image # 4509, layer # layer1.0.relu has outliers [12 15 16 23 41 45 46 47 48 50]
# image # 4640, layer # layer1.0.relu has outliers [ 9 12 16 19 23 35 41 45 46 48 50]
# image # 4711, layer # layer1.0.relu has outliers [15 16 19 23 35 39 41 43 45 46 47 48 57]
# image # 4855, layer # layer1.0.relu has outliers [15 16 17 19 25 35 41 45 47 48 50 57]
# image # 4856, layer # layer1.0.relu has outliers [16 19 23 35 36 39 45 46 48 50 57]
# image # 4913, layer # layer1.0.relu has outliers [16 19 23 25 34 41 43 45 46 47 48 57]
# image # 4933, layer # layer1.0.relu has outliers [16 17 19 23 35 39 41 45 48 57]
# image # 5193, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 48 50 57]
# image # 5217, layer # layer1.0.relu has outliers [12 16 23 35 41 45 46 47 48 50]
# image # 5244, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 47 48 50 57]
# image # 5341, layer # layer1.0.relu has outliers [12 16 19 23 34 35 41 45 46 47 48 50 57]
# image # 5358, layer # layer1.0.relu has outliers [16 19 23 25 35 41 45 46 47 48 50 57]
# image # 5434, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 47 48 50 57]
# image # 5504, layer # layer1.0.relu has outliers [16 19 23 25 34 35 41 45 46 47 48 57]
# image # 5518, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 46 47 48 50 57]
# image # 5533, layer # layer1.0.relu has outliers [12 16 23 31 34 36 41 45 46 47 48 50]
# image # 5576, layer # layer1.0.relu has outliers [16 19 23 25 34 35 41 45 46 47 48 50 57]
# image # 5619, layer # layer1.0.relu has outliers [12 16 19 23 41 45 46 48 50]
# image # 5633, layer # layer1.0.relu has outliers [16 19 23 35 41 45 48 50 57]
# image # 5969, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 47 48 50 57]
# image # 5975, layer # layer1.0.relu has outliers [15 16 19 23 34 35 41 45 46 47 48 50 57]
# image # 6046, layer # layer1.0.relu has outliers [15 16 17 19 24 35 39 41 43 45 47 49 57 63]
# image # 6114, layer # layer1.0.relu has outliers [16 19 23 35 36 39 43 45 47 57]
# image # 6174, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 48 50 57]
# image # 6225, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 46 48 50 57]
# image # 6237, layer # layer1.0.relu has outliers [16 19 23 34 35 39 41 45 46 47 48 50 57]
# image # 6285, layer # layer1.0.relu has outliers [16 19 23 34 35 41 45 46 47 48 50 57]
# image # 6346, layer # layer1.0.relu has outliers [12 16 19 23 41 45 46 47 48 50]
# image # 6426, layer # layer1.0.relu has outliers [16 19 23 34 35 41 45 46 47 48 50 57]
# image # 6436, layer # layer1.0.relu has outliers [16 17 19 23 35 39 41 45 48 57]
# image # 6499, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 47 48 50 57]
# image # 6513, layer # layer1.0.relu has outliers [12 16 19 23 41 45 46 48 50]
# image # 6600, layer # layer1.0.relu has outliers [12 16 19 23 35 39 41 45 46 48 50 57]
# image # 6669, layer # layer1.0.relu has outliers [16 19 23 25 35 41 45 46 47 48 50 57]
# image # 6747, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 47 48 50 57]
# image # 6908, layer # layer1.0.relu has outliers [15 16 19 23 34 41 45 46 47 48 50 57]
# image # 6974, layer # layer1.0.relu has outliers [16 19 23 35 39 41 43 45 47 48 57]
# image # 7114, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 46 48 57]
# image # 7139, layer # layer1.0.relu has outliers [15 16 19 23 25 34 41 45 46 47 48 50 57]
# image # 7310, layer # layer1.0.relu has outliers [12 16 19 23 35 41 45 46 47 48 50]
# image # 7357, layer # layer1.0.relu has outliers [15 16 19 23 41 45 46 47 48 50 57]
# image # 7370, layer # layer1.0.relu has outliers [16 19 23 25 35 41 43 45 46 47 48 50 57]
# image # 7416, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 48 50 57]
# image # 7462, layer # layer1.0.relu has outliers [12 15 16 23 25 41 45 46 47 48 50 57]
# image # 7481, layer # layer1.0.relu has outliers [16 19 23 25 35 41 45 46 47 48 50 57]
# image # 7515, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 46 48 50 57]
# image # 7659, layer # layer1.0.relu has outliers [12 16 19 23 41 45 46 48 50]
# image # 7718, layer # layer1.0.relu has outliers [16 19 23 25 34 35 39 41 45 46 47 48 50 57]
# image # 7725, layer # layer1.0.relu has outliers [16 19 23 24 35 41 45 48 50 57]
# image # 7735, layer # layer1.0.relu has outliers [12 16 19 23 35 41 45 46 48 50]
# image # 7781, layer # layer1.0.relu has outliers [15 19 23 24 46 47 48 50 57]
# image # 7828, layer # layer1.0.relu has outliers [15 16 23 34 35 41 46 47 48 50]
# image # 7847, layer # layer1.0.relu has outliers [15 16 19 23 35 41 45 46 47 48 50 57]
# image # 7962, layer # layer1.0.relu has outliers [15 16 17 19 35 39 41 45 48 49 57]
# image # 7969, layer # layer1.0.relu has outliers [16 17 19 23 35 39 41 45 48 57]
# image # 7972, layer # layer1.0.relu has outliers [16 19 23 24 35 39 41 43 45 48 50 57]
# image # 8011, layer # layer1.0.relu has outliers [15 16 19 23 34 35 39 41 45 46 47 48 50 57]
# image # 8014, layer # layer1.0.relu has outliers [16 19 23 25 35 41 45 46 47 48 50 57]
# image # 8047, layer # layer1.0.relu has outliers [16 19 23 34 35 41 43 45 46 47 48 57]
# image # 8081, layer # layer1.0.relu has outliers [12 16 19 23 41 45 46 48 50]
# image # 8101, layer # layer1.0.relu has outliers [ 9 12 16 19 23 35 41 45 46 48 50]
# image # 8135, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 48 50 57]
# image # 8138, layer # layer1.0.relu has outliers [15 16 19 23 35 41 45 46 47 48 50 57]
# image # 8161, layer # layer1.0.relu has outliers [16 19 23 25 35 39 41 43 45 47 48 57]
# image # 8166, layer # layer1.0.relu has outliers [12 16 19 23 25 35 41 45 46 47 48 50]
# image # 8174, layer # layer1.0.relu has outliers [12 15 16 19 23 25 34 41 45 46 47 48 50 57]
# image # 8197, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 48 50 57]
# image # 8198, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 47 48 55 57]
# image # 8253, layer # layer1.0.relu has outliers [12 16 23 31 34 41 45 46 47 48 50]
# image # 8273, layer # layer1.0.relu has outliers [16 19 23 24 35 41 45 46 47 48 50 57]
# image # 8353, layer # layer1.0.relu has outliers [15 16 19 23 35 41 45 46 47 48 50 57]
# image # 8358, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 48 50 57]
# image # 8372, layer # layer1.0.relu has outliers [15 16 19 23 35 39 41 43 45 47 48 57]
# image # 8378, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 48 50 57]
# image # 8414, layer # layer1.0.relu has outliers [16 19 23 35 39 41 43 45 47 48 57]
# image # 8474, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 48 50 57]
# image # 8493, layer # layer1.0.relu has outliers [12 16 19 23 25 35 41 45 46 47 48 50 57]
# image # 8535, layer # layer1.0.relu has outliers [15 16 19 23 41 45 46 47 48 57]
# image # 8608, layer # layer1.0.relu has outliers [12 16 19 23 35 41 45 46 47 48 50 57]
# image # 8612, layer # layer1.0.relu has outliers [12 16 19 23 35 41 45 46 47 48 50]
# image # 8717, layer # layer1.0.relu has outliers [ 9 12 16 19 23 35 41 45 46 48 50]
# image # 8742, layer # layer1.0.relu has outliers [12 16 23 41 45 46 47 48 50]
# image # 8800, layer # layer1.0.relu has outliers [15 16 19 23 25 35 39 41 43 45 46 47 48 57]
# image # 8867, layer # layer1.0.relu has outliers [16 19 23 24 25 41 43 45 46 47 48 50 57]
# image # 8882, layer # layer1.0.relu has outliers [12 16 19 23 35 41 45 46 48 50]
# image # 8909, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 48 50 57]
# image # 8916, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 47 48 50 57]
# image # 8933, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 47 48 50 57]
# image # 8947, layer # layer1.0.relu has outliers [15 16 17 19 23 35 39 41 45 48 49 57]
# image # 8985, layer # layer1.0.relu has outliers [12 16 23 25 41 45 46 47 48 50]
# image # 8996, layer # layer1.0.relu has outliers [16 19 23 34 35 41 45 46 47 48 50 57]
# image # 9126, layer # layer1.0.relu has outliers [16 17 19 23 35 39 41 43 45 47 48 49 57 63]
# image # 9208, layer # layer1.0.relu has outliers [16 19 23 24 25 35 41 43 45 47 48 50 57]
# image # 9287, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 48 50 57]
# image # 9320, layer # layer1.0.relu has outliers [15 16 19 23 24 35 41 45 46 47 48 50 57]
# image # 9333, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 46 48 50 57]
# image # 9388, layer # layer1.0.relu has outliers [15 16 19 23 25 35 39 41 45 46 47 48 50 57]
# image # 9398, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 48 50 57]
# image # 9544, layer # layer1.0.relu has outliers [12 16 23 41 45 46 48 50]
# image # 9585, layer # layer1.0.relu has outliers [12 16 23 25 35 41 46 47 48 50]
# image # 9597, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 48 50]
# image # 9716, layer # layer1.0.relu has outliers [15 16 19 23 35 39 41 45 47 48 50 57]
# image # 9774, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 47 48 50 57]
# image # 9870, layer # layer1.0.relu has outliers [12 16 19 23 35 41 45 46 48 50 57]
# image # 9914, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 46 47 48 57]
# image # 9937, layer # layer1.0.relu has outliers [ 9 12 16 19 23 35 41 45 46 48 50 57]
# image # 9952, layer # layer1.0.relu has outliers [15 16 19 23 25 34 35 41 45 46 47 48 50 57]
# image # 10053, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 46 47 48 49 57 63]
# image # 10129, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 47 48 50 57]
# image # 10156, layer # layer1.0.relu has outliers [12 16 19 23 25 41 45 46 47 48 50 57]
# image # 10225, layer # layer1.0.relu has outliers [16 17 19 23 35 39 41 45 47 48 57]
# image # 10263, layer # layer1.0.relu has outliers [12 16 19 23 41 45 46 48 50]
# image # 10269, layer # layer1.0.relu has outliers [16 19 23 25 35 41 45 46 47 48 50 57]
# image # 10274, layer # layer1.0.relu has outliers [12 16 19 23 35 41 45 46 47 48 50 57]
# image # 10296, layer # layer1.0.relu has outliers [12 16 19 23 35 41 45 46 48 50]
# image # 10297, layer # layer1.0.relu has outliers [12 16 23 41 46 47 48 50]
# image # 10338, layer # layer1.0.relu has outliers [16 19 23 25 41 45 46 47 48 50 57]
# image # 10343, layer # layer1.0.relu has outliers [12 16 19 23 41 45 46 47 48 50 57]
# image # 10385, layer # layer1.0.relu has outliers [16 19 23 24 41 43 45 46 47 48 50 57]
# image # 10418, layer # layer1.0.relu has outliers [15 16 19 23 25 35 41 43 45 47 48 49 57]
# image # 10496, layer # layer1.0.relu has outliers [12 16 23 41 45 46 48 50]
# image # 10513, layer # layer1.0.relu has outliers [16 19 23 24 25 35 41 45 47 48 50 57]
# image # 10524, layer # layer1.0.relu has outliers [12 16 19 23 36 41 45 46 48 50]
# image # 10686, layer # layer1.0.relu has outliers [16 19 23 35 36 41 45 48 57]
# image # 10705, layer # layer1.0.relu has outliers [15 16 19 23 35 39 41 45 46 47 48 57]
# image # 10739, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 48 50 57]
# image # 10794, layer # layer1.0.relu has outliers [16 17 19 23 35 39 41 45 48 49 57]
# image # 10817, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 47 48 50 57]
# image # 10821, layer # layer1.0.relu has outliers [15 16 19 23 34 35 41 43 45 47 48 49 57]
# image # 10866, layer # layer1.0.relu has outliers [12 16 19 23 35 41 45 46 47 48 50]
# image # 10898, layer # layer1.0.relu has outliers [12 16 23 35 41 45 46 47 48 50]
# image # 10927, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 46 48 50 57]
# image # 10946, layer # layer1.0.relu has outliers [15 16 17 19 35 39 43 45 47 49 57 63]
# layer layer1.1.relu
# image # 19, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50 57]
# image # 171, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50]
# image # 250, layer # layer1.1.relu has outliers [ 8 17 19 29 35 39 48 57]
# image # 280, layer # layer1.1.relu has outliers [19 23 34 35 47 48 50 57]
# image # 349, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50 57 61]
# image # 384, layer # layer1.1.relu has outliers [17 19 35 39 48 51]
# image # 399, layer # layer1.1.relu has outliers [17 19 29 35 39 48]
# image # 519, layer # layer1.1.relu has outliers [17 19 29 32 35 39 48 50 57]
# image # 540, layer # layer1.1.relu has outliers [19 29 32 35 39 47 48 57]
# image # 551, layer # layer1.1.relu has outliers [17 19 29 35 39 48 61]
# image # 738, layer # layer1.1.relu has outliers [ 9 17 19 29 35 39 48]
# image # 739, layer # layer1.1.relu has outliers [ 8 17 19 29 35 39 48 50 57 61]
# image # 780, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50 57 61]
# image # 821, layer # layer1.1.relu has outliers [ 9 17 19 29 35 39 48 50 57]
# image # 878, layer # layer1.1.relu has outliers [17 19 24 29 35 39 48 57]
# image # 907, layer # layer1.1.relu has outliers [17 19 29 32 35 39 45 48 50 57 59]
# image # 1017, layer # layer1.1.relu has outliers [ 8 17 19 29 35 39 48 50 57 59 61]
# image # 1042, layer # layer1.1.relu has outliers [ 9 19 29 35 39 48]
# image # 1134, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50 57]
# image # 1250, layer # layer1.1.relu has outliers [19 34 35 39 48 57]
# image # 1296, layer # layer1.1.relu has outliers [ 9 19 32 35 39 48 51 59]
# image # 1365, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50 57 61]
# image # 1382, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50 57]
# image # 1392, layer # layer1.1.relu has outliers [17 19 24 29 35 39 48 57]
# image # 1451, layer # layer1.1.relu has outliers [ 8 17 19 29 32 35 39 48 50 57 61]
# image # 1457, layer # layer1.1.relu has outliers [ 9 19 35 39 48 50 57]
# image # 1487, layer # layer1.1.relu has outliers [17 19 24 29 35 39 48 50 57]
# image # 1520, layer # layer1.1.relu has outliers [15 16 19 32 35 39 47 48 50 57]
# image # 1545, layer # layer1.1.relu has outliers [ 8  9 17 19 29 35 39 48 57]
# image # 1724, layer # layer1.1.relu has outliers [ 8 17 19 29 32 35 39 45 48 50 57 59 61]
# image # 1777, layer # layer1.1.relu has outliers [17 19 29 32 35 39 48 50 57]
# image # 1797, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50 57 61]
# image # 1906, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50 57 61]
# image # 1969, layer # layer1.1.relu has outliers [ 9 17 19 29 35 39 48]
# image # 1970, layer # layer1.1.relu has outliers [15 19 32 34 45 48 51 59]
# image # 2006, layer # layer1.1.relu has outliers [ 9 17 19 29 35 39 48 57]
# image # 2025, layer # layer1.1.relu has outliers [19 32 35 39 48 51 59]
# image # 2117, layer # layer1.1.relu has outliers [17 19 29 35 39 48]
# image # 2269, layer # layer1.1.relu has outliers [19 29 35 39 48]
# image # 2279, layer # layer1.1.relu has outliers [19 29 32 35 39 48 51 59]
# image # 2421, layer # layer1.1.relu has outliers [ 8 17 19 24 29 35 39 48 50 57]
# image # 2464, layer # layer1.1.relu has outliers [15 17 19 29 32 35 39 48 51]
# image # 2635, layer # layer1.1.relu has outliers [ 8 10 17 19 29 35 39 48 50 57 61]
# image # 2683, layer # layer1.1.relu has outliers [ 8 17 19 35 48 50 57]
# image # 2727, layer # layer1.1.relu has outliers [32 39 43 47 48 50 57 59]
# image # 2785, layer # layer1.1.relu has outliers [ 9 19 32 35 39 48 51]
# image # 2817, layer # layer1.1.relu has outliers [ 9 17 19 29 32 35 39 48]
# image # 2831, layer # layer1.1.relu has outliers [17 29 32 39 48 50 59 61]
# image # 2919, layer # layer1.1.relu has outliers [ 8 19 24 29 32 35 39 48 50 57]
# image # 2937, layer # layer1.1.relu has outliers [ 8 17 19 29 35 39 48 50 57]
# image # 2942, layer # layer1.1.relu has outliers [17 24 29 48 50]
# image # 2962, layer # layer1.1.relu has outliers [17 19 29 35 39 48 61]
# image # 2999, layer # layer1.1.relu has outliers [17 19 29 35 39 48 57 59]
# image # 3065, layer # layer1.1.relu has outliers [15 17 29 32 39 48 51 59]
# image # 3147, layer # layer1.1.relu has outliers [15 19 31 32 34 36 45 47 48 51 59]
# image # 3155, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50 57 61]
# image # 3285, layer # layer1.1.relu has outliers [ 8 17 19 29 35 39 48 57]
# image # 3394, layer # layer1.1.relu has outliers [17 19 29 35 39 43 45 47 48 50 57]
# image # 3643, layer # layer1.1.relu has outliers [19 29 35 39 48 57]
# image # 3652, layer # layer1.1.relu has outliers [ 8  9 17 19 29 35 39 48 57]
# image # 3811, layer # layer1.1.relu has outliers [ 8  9 17 19 29 35 39 48]
# image # 3814, layer # layer1.1.relu has outliers [19 32 34 39 45 47 48 50 57 59]
# image # 3846, layer # layer1.1.relu has outliers [17 19 29 32 35 39 48]
# image # 3927, layer # layer1.1.relu has outliers [17 29 32 35 39 48 50 57 59 61]
# image # 3930, layer # layer1.1.relu has outliers [17 19 29 35 39 47 48 50 57]
# image # 3953, layer # layer1.1.relu has outliers [17 19 24 29 35 39 48 57]
# image # 4002, layer # layer1.1.relu has outliers [ 9 17 19 35 39 48 57]
# image # 4014, layer # layer1.1.relu has outliers [15 17 29 32 43 48 50 59]
# image # 4064, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50 57]
# image # 4078, layer # layer1.1.relu has outliers [17 19 29 35 39 48 57]
# image # 4100, layer # layer1.1.relu has outliers [17 19 24 29 35 39 48 57]
# image # 4115, layer # layer1.1.relu has outliers [ 8 17 19 29 32 35 39 48 51]
# image # 4199, layer # layer1.1.relu has outliers [17 19 29 35 39 43 48 57]
# image # 4256, layer # layer1.1.relu has outliers [17 29 32 35 39 48 50 57 61]
# image # 4342, layer # layer1.1.relu has outliers [ 8 19 35 39 48 57]
# image # 4374, layer # layer1.1.relu has outliers [ 8 17 19 29 35 39 48 57]
# image # 4387, layer # layer1.1.relu has outliers [ 8 17 19 29 35 39 48 50 57]
# image # 4388, layer # layer1.1.relu has outliers [ 8  9 17 19 29 35 39 48 50 57 61]
# image # 4452, layer # layer1.1.relu has outliers [ 8 17 19 29 32 35 39 48]
# image # 4484, layer # layer1.1.relu has outliers [17 19 29 35 39 48 51]
# image # 4509, layer # layer1.1.relu has outliers [17 29 32 39 48 50 59 61]
# image # 4640, layer # layer1.1.relu has outliers [ 9 17 19 29 35 39 48 50 57 61]
# image # 4711, layer # layer1.1.relu has outliers [17 19 29 35 39 48]
# image # 4855, layer # layer1.1.relu has outliers [15 17 19 29 35 39 48 50 51]
# image # 4856, layer # layer1.1.relu has outliers [ 8 17 19 29 35 36 39 48 57 61]
# image # 4913, layer # layer1.1.relu has outliers [ 9 19 34 39 43 45 47 48 57]
# image # 4933, layer # layer1.1.relu has outliers [ 8 17 19 29 32 35 39 48 51]
# image # 5193, layer # layer1.1.relu has outliers [ 8 17 19 29 35 39 48 50 57 61]
# image # 5217, layer # layer1.1.relu has outliers [17 29 35 39 48 50 57 61]
# image # 5244, layer # layer1.1.relu has outliers [ 8 17 19 29 35 39 48 50 57]
# image # 5341, layer # layer1.1.relu has outliers [17 19 29 35 39 48 57]
# image # 5358, layer # layer1.1.relu has outliers [ 8  9 17 19 29 35 39 48 50 57]
# image # 5434, layer # layer1.1.relu has outliers [ 8 17 19 29 35 39 48 57]
# image # 5504, layer # layer1.1.relu has outliers [ 9 19 35 39 48 57]
# image # 5518, layer # layer1.1.relu has outliers [ 8 17 19 29 35 39 43 48]
# image # 5533, layer # layer1.1.relu has outliers [19 34 35 36 39 45 48 50 51 59]
# image # 5576, layer # layer1.1.relu has outliers [19 29 35 39 47 48 57]
# image # 5619, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50 57 59 61]
# image # 5633, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50 57 59]
# image # 5969, layer # layer1.1.relu has outliers [ 9 17 19 29 35 39 48 57]
# image # 5975, layer # layer1.1.relu has outliers [17 19 29 35 39 48 57]
# image # 6046, layer # layer1.1.relu has outliers [15 17 19 35 39 48 51]
# image # 6114, layer # layer1.1.relu has outliers [19 32 35 39 48 51]
# image # 6174, layer # layer1.1.relu has outliers [ 8  9 17 19 29 35 39 48 50 57]
# image # 6225, layer # layer1.1.relu has outliers [ 8 17 19 29 35 39 48 57]
# image # 6237, layer # layer1.1.relu has outliers [19 29 35 39 48 57]
# image # 6285, layer # layer1.1.relu has outliers [ 9 19 29 35 39 48 57]
# image # 6346, layer # layer1.1.relu has outliers [ 8 19 35 39 48 57 61]
# image # 6426, layer # layer1.1.relu has outliers [17 19 29 35 39 48 57]
# image # 6436, layer # layer1.1.relu has outliers [ 8 17 19 29 35 39 48]
# image # 6499, layer # layer1.1.relu has outliers [ 8 17 19 29 35 39 48 50 57 61]
# image # 6513, layer # layer1.1.relu has outliers [ 8 17 19 29 32 35 39 48 50 57 59 61]
# image # 6600, layer # layer1.1.relu has outliers [ 8  9 17 19 29 35 39 48 50 57 61]
# image # 6669, layer # layer1.1.relu has outliers [17 19 29 35 39 43 48 57 61]
# image # 6747, layer # layer1.1.relu has outliers [ 9 17 19 29 35 39 48 57 61]
# image # 6908, layer # layer1.1.relu has outliers [17 19 29 32 35 39 48 50 57 61]
# image # 6974, layer # layer1.1.relu has outliers [17 19 32 39 48]
# image # 7114, layer # layer1.1.relu has outliers [17 19 29 32 35 39 48]
# image # 7139, layer # layer1.1.relu has outliers [ 8 19 35 39 47 48 50 57]
# image # 7310, layer # layer1.1.relu has outliers [17 19 29 32 35 39 48 50 57 61]
# image # 7357, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50 57]
# image # 7370, layer # layer1.1.relu has outliers [ 8 17 19 29 35 39 48 57]
# image # 7416, layer # layer1.1.relu has outliers [ 8 19 29 32 35 39 48 50 57]
# image # 7462, layer # layer1.1.relu has outliers [29 32 39 48 50 57 59]
# image # 7481, layer # layer1.1.relu has outliers [17 19 29 32 35 39 48 50]
# image # 7515, layer # layer1.1.relu has outliers [ 9 17 19 29 35 39 48 51 61]
# image # 7659, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50 57 59 61]
# image # 7718, layer # layer1.1.relu has outliers [19 29 35 39 48 57]
# image # 7725, layer # layer1.1.relu has outliers [17 19 24 29 35 39 48]
# image # 7735, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50 57 59 61]
# image # 7781, layer # layer1.1.relu has outliers [17 24 29 39 48 57]
# image # 7828, layer # layer1.1.relu has outliers [17 29 32 35 39 48 50 57 61]
# image # 7847, layer # layer1.1.relu has outliers [17 19 29 35 39 48 57]
# image # 7962, layer # layer1.1.relu has outliers [15 17 19 29 35 39 48 51]
# image # 7969, layer # layer1.1.relu has outliers [ 8 17 19 29 35 39 48]
# image # 7972, layer # layer1.1.relu has outliers [ 8 17 19 24 29 35 39 48]
# image # 8011, layer # layer1.1.relu has outliers [17 29 32 35 39 48 57 61]
# image # 8014, layer # layer1.1.relu has outliers [ 8 17 19 29 35 39 48 57]
# image # 8047, layer # layer1.1.relu has outliers [19 35 39 48 51]
# image # 8081, layer # layer1.1.relu has outliers [ 8 17 19 29 35 39 48 50 57 61]
# image # 8101, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50 57 59 61]
# image # 8135, layer # layer1.1.relu has outliers [17 19 29 35 39 48]
# image # 8138, layer # layer1.1.relu has outliers [17 19 24 29 35 39 48 50 57]
# image # 8161, layer # layer1.1.relu has outliers [ 8 17 19 29 35 39 48 57]
# image # 8166, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50 57]
# image # 8174, layer # layer1.1.relu has outliers [ 9 19 32 39 45 47 48 50 57]
# image # 8197, layer # layer1.1.relu has outliers [ 8 17 19 29 35 39 48 57]
# image # 8198, layer # layer1.1.relu has outliers [ 9 17 19 35 39 48 57]
# image # 8253, layer # layer1.1.relu has outliers [45 48 50 57 59]
# image # 8273, layer # layer1.1.relu has outliers [17 19 24 29 35 39 48 57]
# image # 8353, layer # layer1.1.relu has outliers [17 19 24 29 35 39 48 57]
# image # 8358, layer # layer1.1.relu has outliers [17 19 29 35 39 48]
# image # 8372, layer # layer1.1.relu has outliers [17 19 29 35 39 48 57]
# image # 8378, layer # layer1.1.relu has outliers [17 19 29 32 35 39 48]
# image # 8414, layer # layer1.1.relu has outliers [19 35 39 48 51]
# image # 8474, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50 57]
# image # 8493, layer # layer1.1.relu has outliers [ 9 19 35 39 48 50 57]
# image # 8535, layer # layer1.1.relu has outliers [16 19 35 39 48 50]
# image # 8608, layer # layer1.1.relu has outliers [19 29 35 39 48 50 57]
# image # 8612, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50 57 61]
# image # 8717, layer # layer1.1.relu has outliers [ 9 17 19 29 32 35 39 48 50 51 59 61]
# ...
#  133 138 140 144 147 169 170 174 184 186 189 196 202 203 208 219 222 223
#  224 226 237 243 258 263 274 281 288 291 296 297 306 310 315 332 333 343
#  349 353 354 356 359 360 364 374 376 377 385 396 399 400 425 427 432 434
#  437 439 440 441 448 452 453 468 470 472 473 475 478 480 492 507 509]
# image # 9287, layer # layer4.2.relu has outliers [ 15  16  17  18  25  27  32  34  50  67  70  74  89  91  99 100 106 123
#  124 128 133 137 140 144 145 156 161 166 169 171 174 176 184 186 194 200
#  203 208 212 219 222 224 226 243 256 263 265 268 274 275 287 291 295 296
#  306 307 310 315 333 334 343 349 353 354 356 374 375 377 378 385 387 394
#  396 399 400 408 410 418 429 434 439 443 446 447 448 450 453 468 471 472
#  473 475 477 481 483 485 486 488 489 505 506 509]
# image # 9320, layer # layer4.2.relu has outliers [  1   7   9  19  22  26  31  33  39  40  43  45  54  59  60  64  65  70
#   79  88  89  95 100 105 109 114 122 126 128 130 136 146 152 161 168 173
#  180 193 199 209 212 224 230 238 244 245 248 249 256 283 301 305 308 312
#  314 325 329 337 340 350 355 366 368 369 372 378 379 381 382 389 390 393
#  394 395 399 402 406 414 418 432 442 450 455 456 458 461 462 477 487 501]
# image # 9333, layer # layer4.2.relu has outliers [  4   6  21  28  36  37  59  64  74  76  87  93  95  99 101 102 103 108
#  113 121 125 128 134 140 143 151 166 185 191 192 194 195 197 199 214 232
#  233 238 244 253 267 268 269 275 282 293 294 299 307 322 325 337 342 349
#  378 380 390 391 394 404 407 408 410 413 414 416 418 437 438 450 451 470
#  471 479 481 482 485 486 490 495 498 502 504 505]
# image # 9388, layer # layer4.2.relu has outliers [  0   4  10  17  22  25  28  29  34  37  41  44  57  59  61  68  71  96
#  106 109 112 120 123 124 129 132 151 158 172 182 184 186 188 194 196 203
#  219 222 226 235 238 243 264 272 274 287 288 305 306 308 310 313 322 323
#  328 334 338 343 349 353 367 377 386 391 393 400 415 420 425 436 448 453
#  457 461 466 473 479 483 493 501 509]
# image # 9398, layer # layer4.2.relu has outliers [  6   9  17  18  24  25  27  30  34  54  58  62  67  70  80  87  89  91
#   99 100 101 102 108 123 128 129 133 137 140 144 161 162 166 171 174 176
#  184 186 194 199 208 212 222 223 224 239 244 256 263 265 268 274 275 282
#  291 293 295 296 304 307 341 353 377 378 382 385 389 394 396 399 408 410
#  418 428 429 432 434 444 450 468 470 480 483 485 486 489 490 497 502 505
#  506 509]
# image # 9544, layer # layer4.2.relu has outliers [  4  17  22  25  28  41  61  62  67  70  72  83  88 101 108 109 115 132
#  133 162 180 182 202 209 234 235 241 254 263 274 288 293 308 312 313 315
#  322 334 338 340 348 351 353 378 381 394 413 415 479 485 505]
# image # 9585, layer # layer4.2.relu has outliers [  3   7  10  21  24  40  43  57  59  60  66  76  78  87  96  98  99 102
#  103 107 110 111 117 125 134 139 143 145 151 175 181 183 191 199 201 206
#  211 216 217 218 228 232 233 236 239 245 250 251 252 268 269 275 278 282
#  284 290 297 298 300 309 311 324 325 337 339 357 362 390 404 405 410 414
#  416 426 427 430 431 433 436 437 450 451 454 467 470 471 484 490 492 496
#  497 500 508]
# image # 9597, layer # layer4.2.relu has outliers [  3   9  13  17  28  29  37  44  68  69  71  79  91 133 144 174 184 186
#  190 196 198 202 203 208 223 226 243 274 281 291 296 300 310 322 328 338
#  339 341 353 354 360 362 364 374 385 390 393 400 421 425 427 434 436 439
#  473 475 479 480 482 492 507 510]
# image # 9716, layer # layer4.2.relu has outliers [  9  18  22  25  27  41  54  55  58  62  67  70  72  82  88  89  91 100
#  108 109 115 120 123 124 128 129 133 137 144 146 153 159 162 169 171 174
#  180 184 186 189 196 198 200 202 208 222 223 224 234 244 248 256 263 274
#  281 288 291 296 302 304 307 310 315 329 331 334 341 348 353 354 358 374
#  376 378 382 383 385 394 413 418 428 432 434 439 443 450 456 458 468 473
#  475 477 480 481 485 488 489 499 506 509]
# image # 9774, layer # layer4.2.relu has outliers [  3   9  13  15  16  21  25  30  37  46  63  66  69  71  77  87  91 102
#  107 123 129 133 138 139 144 153 157 159 164 165 169 170 171 174 178 183
#  184 186 196 198 202 205 208 211 219 223 226 237 274 277 281 285 290 291
#  296 297 300 315 320 324 328 332 339 352 354 358 362 365 373 374 376 377
#  385 392 396 400 401 409 411 412 420 421 425 427 428 434 439 440 441 449
#  470 472 474 475 478 480 482 488 492 503 507 509 510]
# image # 9870, layer # layer4.2.relu has outliers [ 13  15  16  17  25  27  41  71  80  81  87  91  99 102 123 125 129 133
#  144 145 156 169 171 174 176 184 186 189 191 196 199 202 203 208 212 219
#  224 226 239 243 253 258 263 268 274 281 288 291 293 296 297 306 310 315
#  330 333 334 349 353 354 356 358 360 364 374 375 377 384 385 387 396 397
#  400 420 434 437 439 448 452 453 468 470 471 472 473 475 480 482 483 486
#  489 492 502]
# image # 9914, layer # layer4.2.relu has outliers [ 16  17  25  27  34  62  67  70  80  85  89  91  99 100 106 109 123 124
#  133 140 145 156 161 162 168 169 171 184 189 196 199 203 208 212 219 222
#  224 226 243 244 256 263 265 268 274 275 285 287 288 295 306 307 315 316
#  330 333 343 349 353 356 358 364 375 377 384 385 387 394 418 429 439 447
#  448 450 453 468 473 475 477 483 485 486 489 506 509]
# image # 9937, layer # layer4.2.relu has outliers [ 13  15  16  17  18  25  27  30  50  54  55  58  67  77  80  81  87  89
#   91  99 100 102 106 108 123 129 133 138 140 144 145 156 162 169 171 174
#  184 186 189 194 203 208 212 219 222 223 224 226 239 243 256 263 268 274
#  281 282 285 291 296 306 307 334 343 353 354 356 358 364 374 376 377 385
#  387 394 396 400 408 418 434 439 443 446 447 448 449 453 468 470 471 472
#  473 475 477 480 483 486 488 489 502 509]
# image # 9952, layer # layer4.2.relu has outliers [ 17  25  27  28  41  44  62  63  67  68  69  71  72  91 115 120 129 132
#  133 147 159 162 165 169 170 171 174 176 184 186 189 196 198 200 202 208
#  215 219 223 226 244 253 268 270 274 281 288 291 295 296 306 307 310 315
#  322 328 334 348 353 354 358 364 374 375 383 385 394 400 413 418 434 439
#  448 452 453 468 471 473 475 480 482 486 492 502 506 511]
# image # 10053, layer # layer4.2.relu has outliers [ 13  15  16  17  24  25  27  44  50  55  58  62  67  70  74  80  87  91
#   99 102 121 125 129 133 138 140 144 162 169 171 174 184 185 186 187 189
#  196 198 200 202 203 208 212 215 219 222 224 226 243 244 253 263 268 270
#  274 281 282 288 291 295 296 299 304 306 307 310 315 353 354 358 375 377
#  385 387 394 396 413 429 434 437 439 447 448 468 470 471 472 475 480 481
#  483 486 488 489 499 502 505 509]
# image # 10129, layer # layer4.2.relu has outliers [ 13  15  17  25  27  29  30  41  44  70  77  79  81  83  89  91 104 130
#  133 138 140 146 150 159 165 166 169 170 177 184 198 202 222 223 244 248
#  256 258 260 271 272 274 285 288 291 296 306 307 310 328 352 353 354 355
#  358 359 374 376 382 385 389 396 399 415 417 425 428 432 434 443 444 456
#  474 475 477 478 480 499 506 507 509]
# image # 10156, layer # layer4.2.relu has outliers [  6   7  10  16  18  32  34  57  59  64  78  80  81  99 101 103 116 124
#  128 140 145 151 154 161 166 176 192 199 203 206 219 220 222 226 236 239
#  243 244 248 251 256 258 263 268 275 284 285 287 297 306 307 316 318 326
#  333 342 355 356 375 378 382 391 395 396 405 407 418 429 437 444 450 456
#  459 486 490 506]
# image # 10225, layer # layer4.2.relu has outliers [ 19  22  25  30  41  48  55  61  64  72  77  83 108 118 124 128 129 130
#  135 138 146 150 159 162 163 179 180 192 193 194 202 210 217 223 234 235
#  241 246 248 254 256 259 260 263 271 272 274 288 303 310 312 314 323 328
#  329 331 348 350 353 370 376 378 382 389 394 398 399 408 415 417 428 432
#  443 444 447 458 474 485 487 490 499 503 509]
# image # 10263, layer # layer4.2.relu has outliers [ 13  15  19  25  27  30  33  69  71  77  81  87  90  91  99 102 104 123
#  125 133 138 144 150 159 162 163 166 169 170 174 184 186 202 203 208 219
#  222 223 256 258 263 271 274 281 285 288 291 296 306 310 315 328 343 353
#  354 356 374 376 377 385 387 396 399 400 417 422 428 429 432 434 439 443
#  444 468 470 472 473 475 480 488 492 507 509]
# image # 10269, layer # layer4.2.relu has outliers [ 10  17  37  44  50  68  71 106 109 112 120 123 132 133 157 158 186 203
#  219 226 243 270 274 288 291 306 315 334 349 364 377 383 386 390 392 393
#  400 413 420 425 427 439 448 468 472 480 482 492]
# image # 10274, layer # layer4.2.relu has outliers [ 13  15  16  17  25  30  44  50  62  67  69  71  77  81  91  99 102 106
#  109 123 133 138 144 159 162 166 169 171 174 176 184 186 189 196 202 203
#  208 219 222 223 224 226 243 244 253 263 268 274 281 288 291 293 296 306
#  307 310 315 334 349 353 354 358 374 375 377 385 387 396 400 401 413 420
#  425 428 434 437 439 444 448 468 470 471 472 475 480 482 486 488 502 506
#  509]
# image # 10296, layer # layer4.2.relu has outliers [ 36  55  59  68  76  93 102 103 113 117 127 129 132 133 151 181 192 197
#  216 217 241 247 275 282 296 322 338 402 404 470 471 479 482 495 498 502
#  504]
# image # 10297, layer # layer4.2.relu has outliers [ 14  18  22  25  30  32  41  48  55  56  58  64  67  69  70  77  88 100
#  109 115 123 124 128 130 137 138 142 146 159 162 165 169 170 177 180 189
#  194 200 202 203 220 222 223 229 234 248 256 260 263 274 288 296 303 304
#  307 314 315 329 341 348 353 354 358 374 378 382 385 389 394 413 418 425
#  428 432 443 447 449 450 456 458 475 477 485 490 503 506 509]
# image # 10338, layer # layer4.2.relu has outliers [  9  13  15  25  28  34  36  37  44  63  68  69  71  72  82  87  91  93
#   99 102 103 123 129 132 133 138 143 144 169 171 174 176 184 186 196 198
#  202 208 219 221 223 226 235 242 244 268 274 281 288 291 292 296 300 310
#  315 322 328 334 338 341 353 354 358 377 385 393 396 400 402 420 425 434
#  437 439 471 472 473 475 480 482 488 492 495 499 502 504]
# image # 10343, layer # layer4.2.relu has outliers [  4   6  19  36  37  57  59  64  72  75  76  93  99 103 108 110 117 128
#  131 143 151 160 179 185 192 194 197 216 232 238 242 244 246 257 265 266
#  267 275 287 293 322 338 378 380 391 395 402 416 418 438 450 479 482 487
#  490 498 500 501 504 508]
# image # 10385, layer # layer4.2.relu has outliers [  9  10  13  15  34  37  43  57  59  78  82  91 102 103 123 138 144 150
#  151 184 188 201 203 206 216 219 221 223 233 243 268 275 287 296 298 306
#  318 328 347 356 359 374 377 385 391 395 396 402 416 425 434 437 439 452
#  460 470 472 473 482 488 489 492 508 509]
# image # 10418, layer # layer4.2.relu has outliers [ 13  15  16  17  25  27  55  58  62  67  70  80  81  87  88  89  91  99
#  102 125 129 133 138 140 144 159 162 165 166 169 170 171 174 176 184 186
#  189 196 198 202 208 212 219 222 223 224 226 243 244 263 268 274 281 282
#  285 288 291 295 296 304 306 307 310 315 330 349 353 354 356 358 364 374
#  375 377 385 387 394 396 418 425 434 437 439 443 444 448 450 453 468 470
#  473 475 480 481 482 483 488 489 502 506 509]
# image # 10496, layer # layer4.2.relu has outliers [  7  13  37  59  60  76  78  95  96  98  99 102 103 111 113 117 125 144
#  145 151 181 183 199 206 214 216 228 233 237 239 250 262 268 275 282 287
#  297 300 325 327 337 349 390 391 404 410 416 425 427 431 433 436 437 440
#  445 450 451 470 471 473 479 482 484 495 497 500 502 504]
# image # 10513, layer # layer4.2.relu has outliers [ 13  16  17  22  25  27  28  41  44  50  62  67  69  70  89  91 109 115
#  120 129 130 132 133 138 147 153 159 162 165 169 170 171 174 184 186 189
#  196 198 200 202 203 208 212 219 222 224 226 243 249 253 263 274 281 285
#  288 291 295 296 297 304 306 307 310 315 316 334 343 348 349 353 354 356
#  358 364 375 377 383 385 394 400 413 418 425 434 439 448 452 453 463 468
#  472 475 480 486 488 489 492 503 506 507]
# image # 10524, layer # layer4.2.relu has outliers [ 13  15  17  25  37  41  44  69  71  77  79  91 120 123 129 133 138 144
#  150 159 169 170 171 174 184 186 196 202 203 208 219 222 223 226 237 243
#  274 281 288 291 296 306 310 315 328 334 343 349 353 354 358 364 374 376
#  377 385 387 396 399 400 420 425 427 434 439 443 446 448 452 453 468 472
#  473 474 475 480 488 492 507 509]
# image # 10686, layer # layer4.2.relu has outliers [ 13  15  16  17  18  25  30  54  55  58  62  67  70  74  77  81  88  89
#   91  99 100 102 123 124 128 129 133 137 138 140 144 146 159 161 162 166
#  169 174 184 186 189 202 208 212 222 223 224 244 248 263 268 274 281 282
#  291 295 296 299 304 307 315 348 353 354 358 374 376 377 378 382 385 387
#  394 396 399 408 418 428 429 434 439 443 448 450 468 470 471 473 475 477
#  480 485 486 488 489 490 509]
# image # 10705, layer # layer4.2.relu has outliers [  9  13  15  17  25  27  28  30  41  58  62  69  70  71  72  77  80  82
#   89  91  99 101 108 115 120 123 129 133 144 147 153 159 162 165 169 171
#  174 184 186 189 196 198 200 202 203 208 219 222 223 224 226 244 263 268
#  274 281 282 288 291 293 295 296 304 306 307 310 315 334 348 353 354 356
#  358 374 377 378 383 385 394 399 400 401 413 418 420 425 434 439 443 448
#  450 468 472 473 475 480 482 488 492 502 506 509]
# image # 10739, layer # layer4.2.relu has outliers [  1   9  10  13  15  17  19  25  28  34  37  43  57  59  60  68  71  79
#   82  87  91  96 102 104 106 109 112 120 123 132 133 138 144 150 158 169
#  174 184 186 188 189 196 203 208 216 219 223 233 242 243 271 274 287 288
#  292 296 297 302 310 328 334 341 349 354 360 374 377 385 386 390 393 396
#  399 400 402 410 416 420 422 425 428 432 434 436 437 439 440 443 448 460
#  470 472 473 474 480 482 487 488 492 499 507 508 509]
# image # 10794, layer # layer4.2.relu has outliers [  9  16  18  22  25  27  50  54  55  58  62  64  67  70  72  80  89  91
#   99 100 106 108 109 112 123 124 128 129 133 137 138 140 144 146 153 162
#  166 169 171 174 176 184 186 189 196 200 202 203 208 212 222 226 244 256
#  263 274 281 291 295 299 304 306 307 310 315 341 343 348 353 354 358 364
#  377 378 385 386 387 394 399 418 439 443 450 453 458 468 475 477 480 486
#  489 503 509]
# image # 10817, layer # layer4.2.relu has outliers [ 13  25  27  30  54  55  58  67  70  77  81  89  91  99 102 104 123 133
#  138 142 144 150 153 156 159 162 163 166 169 170 171 174 177 178 184 186
#  202 203 208 220 222 223 248 256 258 263 271 274 281 282 285 291 296 304
#  310 315 331 343 348 352 353 354 355 358 359 374 376 377 385 387 394 396
#  399 400 401 422 428 429 434 439 443 444 468 470 472 473 475 478 480 489
#  492 503 507 509]
# image # 10821, layer # layer4.2.relu has outliers [ 13  16  21  25  30  54  58  62  67  70  80  89  91 102 106 109 123 133
#  144 153 159 162 169 171 174 184 186 189 196 198 202 203 208 222 223 224
#  226 244 263 274 281 291 296 304 310 353 354 358 377 385 387 400 401 418
#  420 434 439 468 470 472 473 475 480 488 499]
# image # 10866, layer # layer4.2.relu has outliers [  9  10  13  19  33  34  36  37  59  60  82  93 103 104 129 134 138 143
#  144 151 169 184 201 208 216 219 222 223 242 287 296 298 338 386 391 396
#  399 402 404 410 422 425 434 439 444 460 468 470 472 479 482 487 488 508]
# image # 10898, layer # layer4.2.relu has outliers [ 14  15  18  25  27  30  32  54  55  58  62  67  77  81  83  89  91  99
#  100 123 124 133 137 138 140 141 142 144 146 150 156 159 162 165 169 171
#  174 176 177 180 184 186 189 200 202 203 208 212 220 222 223 224 226 234
#  248 256 260 263 271 274 285 291 295 296 304 306 307 314 315 331 343 348
#  352 353 354 355 356 358 374 376 377 378 382 385 387 394 396 400 408 418
#  422 429 434 439 443 447 448 449 453 459 468 473 475 477 480 485 488 489
#  499 503 506 509]
# image # 10927, layer # layer4.2.relu has outliers [  9  13  15  16  17  19  25  30  34  37  41  44  63  69  71  72  77  91
#   99 102 106 123 129 132 133 138 144 150 153 159 163 169 170 171 174 176
#  184 186 196 198 202 203 208 219 222 223 226 243 268 274 281 285 287 288
#  291 296 297 300 306 310 315 334 349 353 354 356 358 374 377 385 386 387
#  396 400 401 402 410 416 420 425 428 434 437 439 443 448 453 468 470 471
#  472 473 475 480 482 488 492 502 507 509 511]
# image # 10946, layer # layer4.2.relu has outliers [  4  22  28  59  64  65  67  70  72  76  88  95 109 110 114 122 128 140
#  143 154 162 181 189 192 197 212 215 242 244 269 283 293 294 299 301 308
#  329 335 337 340 342 353 369 372 378 380 381 382 389 391 394 404 414 418
#  419 433 450 458 475 484 485 490 502]

# %% [markdown]
# ## activation level for the whole test set

# %%
print(num_filters)
# Out:
# {'relu': 64, 'layer1.0.relu': 64, 'layer1.1.relu': 64, 'layer1.2.relu': 64, 'layer2.0.relu': 128, 'layer2.1.relu': 128, 'layer2.2.relu': 128, 'layer2.3.relu': 128, 'layer3.0.relu': 256, 'layer3.1.relu': 256, 'layer3.2.relu': 256, 'layer3.3.relu': 256, 'layer3.4.relu': 256, 'layer3.5.relu': 256, 'layer4.0.relu': 512, 'layer4.1.relu': 512, 'layer4.2.relu': 512}

# %%
# outliers for each layer for each image
z_score_threshold = 2
all_outliers_for_image = {x: {} for x in hooked_layer_names}
num_times_being_outlier = {}

for layer_name in hooked_layer_names:
    print("layer {}".format(layer_name))
    num_times_being_outlier[layer_name] = [0] * num_filters[layer_name]
    for image in range(num_test_images):
        all_outliers_for_image[layer_name][image] = find_outliers_zscore(filtersum_all_images[image][layer_name], threshold=z_score_threshold)
        for k in all_outliers_for_image[layer_name][image]:
            num_times_being_outlier[layer_name][k] += 1
# Out:
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu

# %%
non_activation_ratio_whole_data = {}
ratio_threshold = 0.01
for layer_name in hooked_layer_names:
    print("layer {}".format(layer_name))
    s = {x: num_times_being_outlier[layer_name][x] / num_test_images for x in range(num_filters[layer_name]) if num_times_being_outlier[layer_name][x] > 0}
    non_activation_ratio_whole_data[layer_name] = {k: v for k, v in s.items() if v > ratio_threshold}
    # non_activation_ratio_whole_data[layer_name] = [x/num_test_images for x in num_times_being_outlier[layer_name]]
# Out:
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu

# %%
for layer_name in hooked_layer_names:
    print(layer_name, non_activation_ratio_whole_data[layer_name])
# Out:
# relu {}
# layer1.0.relu {}
# layer1.1.relu {}
# layer1.2.relu {39: 0.028391455176191346}
# layer2.0.relu {}
# layer2.1.relu {}
# layer2.2.relu {80: 0.013784918751141136}
# layer2.3.relu {105: 0.01990140587913091}
# layer3.0.relu {7: 0.015519444951615849, 84: 0.011320065729413912, 121: 0.03313857951433266, 122: 0.010681029760817966, 231: 0.023644330838050027, 251: 0.03186050757714077}
# layer3.1.relu {18: 0.0234617491327369, 111: 0.14496987401862332, 118: 0.07905787840058426, 139: 0.022183677195545006, 144: 0.02802629176556509, 146: 0.18732882965126893, 151: 0.1127442030308563, 161: 0.020449150995070293, 162: 0.1258900858134015, 180: 0.18951981011502647, 197: 0.10498448055504839, 213: 0.10334124520723023, 229: 0.0350556874201205, 231: 0.05760452802629176, 236: 0.06043454445864525, 251: 0.29751688880774146}
# layer3.2.relu {15: 0.017162680299433998, 18: 0.01606719006755523, 111: 0.011411356582070476, 118: 0.10105897389081614, 139: 0.01935366076319153, 151: 0.11721745481102794, 162: 0.1329194814679569, 182: 0.04884060617126164, 187: 0.027113383238999453, 205: 0.048201570202665696, 225: 0.012963301077232061, 241: 0.029852108818696366}
# layer3.3.relu {118: 0.036333759357312395, 141: 0.019810115026474347, 156: 0.010681029760817966, 162: 0.07650173452620047, 182: 0.010224575497535146, 187: 0.03249954354573672, 205: 0.02848274602884791, 251: 0.02419207595398941}
# layer3.4.relu {118: 0.03249954354573672, 134: 0.016706226036151177, 205: 0.026565638123060068, 214: 0.012506846813949242, 251: 0.04135475625342341}
# layer3.5.relu {}
# layer4.0.relu {220: 0.01935366076319153}
# layer4.1.relu {}
# layer4.2.relu {}

# %% [markdown]
# ## non-activation times ratio for different classes, for right/wrong

# %%
# outliers for each layer for each image
z_score_threshold = 2
all_outliers_for_miss_predicated_image = {x: {} for x in hooked_layer_names}
num_times_being_outlier_miss_predicated_images = {}

for layer_name in hooked_layer_names:
    print("layer {}".format(layer_name))
    num_times_being_outlier_miss_predicated_images[layer_name] = [0] * num_filters[layer_name]
    for image in wrong_images:
        all_outliers_for_miss_predicated_image[layer_name][image] = find_outliers_zscore(filtersum_all_images[image][layer_name], threshold=z_score_threshold)
        for k in all_outliers_for_miss_predicated_image[layer_name][image]:
            num_times_being_outlier_miss_predicated_images[layer_name][k] += 1
# Out:
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu

# %%
non_activation_ratio_miss_predicated_image = {}
num_miss_predicated_images = len(wrong_images)

for layer_name in hooked_layer_names:
    print("layer {}".format(layer_name))
    s = {x: num_times_being_outlier_miss_predicated_images[layer_name][x] / num_miss_predicated_images for x in range(num_filters[layer_name]) if num_times_being_outlier_miss_predicated_images[layer_name][x] > 0}
    non_activation_ratio_miss_predicated_image[layer_name] = {k: v for k, v in s.items() if v > ratio_threshold}


for layer_name in hooked_layer_names:
    print(layer_name, non_activation_ratio_miss_predicated_image[layer_name])
# Out:
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu
# relu {}
# layer1.0.relu {}
# layer1.1.relu {}
# layer1.2.relu {39: 0.04225352112676056}
# layer2.0.relu {}
# layer2.1.relu {}
# layer2.2.relu {31: 0.014084507042253521}
# layer2.3.relu {76: 0.014084507042253521, 105: 0.018779342723004695}
# layer3.0.relu {7: 0.018779342723004695, 22: 0.014084507042253521, 241: 0.023474178403755867, 251: 0.03286384976525822}
# layer3.1.relu {18: 0.014084507042253521, 111: 0.107981220657277, 118: 0.07042253521126761, 139: 0.018779342723004695, 144: 0.03755868544600939, 146: 0.12206572769953052, 151: 0.056338028169014086, 162: 0.056338028169014086, 180: 0.13615023474178403, 197: 0.12206572769953052, 213: 0.07981220657276995, 229: 0.03286384976525822, 231: 0.03286384976525822, 236: 0.028169014084507043, 251: 0.2347417840375587}
# layer3.2.relu {118: 0.07981220657276995, 151: 0.08450704225352113, 162: 0.056338028169014086, 182: 0.07981220657276995, 187: 0.03755868544600939, 205: 0.03755868544600939, 241: 0.018779342723004695}
# layer3.3.relu {118: 0.018779342723004695, 141: 0.03286384976525822, 161: 0.018779342723004695, 162: 0.03286384976525822, 187: 0.028169014084507043, 205: 0.03286384976525822}
# layer3.4.relu {118: 0.028169014084507043, 205: 0.018779342723004695, 214: 0.014084507042253521, 251: 0.03286384976525822}
# layer3.5.relu {}
# layer4.0.relu {}
# layer4.1.relu {}
# layer4.2.relu {}

# %% [markdown]
# ## non-activation times for different classes

# %%
all_outliers_for_classes = {x: {y: {} for y in range(len(classes))} for x in hooked_layer_names}
num_times_being_outlier_classes = {y: {} for y in range(len(classes))}

for layer_name in hooked_layer_names:
    print("layer {}".format(layer_name))
    for cla in range(len(classes)):
        num_times_being_outlier_classes[cla][layer_name] = [0] * num_filters[layer_name]
        for image in image_predictation_result[cla]:
            all_outliers_for_classes[layer_name][cla][image] = find_outliers_zscore(filtersum_all_images[image][layer_name], threshold=z_score_threshold)
            for k in all_outliers_for_classes[layer_name][cla][image]:
                num_times_being_outlier_classes[cla][layer_name][k] += 1
# Out:
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu

# %%
non_activation_ratio_classes = {y: {} for y in range(len(classes))}
ratio_threshold = 0.01
for cla in range(len(classes)):
    for layer_name in hooked_layer_names:
        print("layer {}".format(layer_name))
        s = {x: num_times_being_outlier_classes[cla][layer_name][x] / len(image_predictation_result[cla]) for x in range(num_filters[layer_name]) if num_times_being_outlier_classes[cla][layer_name][x] > 0}
        non_activation_ratio_classes[cla][layer_name] = {k: v for k, v in s.items() if v > ratio_threshold}
# Out:
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu

# %%
# for cla in range(len(classes)):
#     for layer_name in hooked_layer_names:
#         print(layer_name, non_activation_ratio_classes[cla][layer_name])

# less non-activation classes: 0, 2, 4, 8
# many: 1, 3, 5, 6, 7, 9
cla = 9
print('Accuracy of {} : {:.0f}% of {} images'.format(classes[cla], 100 * class_correct[cla] / class_total[cla], class_total[cla]))
for layer_name in hooked_layer_names:
    print(layer_name, non_activation_ratio_classes[cla][layer_name])
# Out:
# Accuracy of Middle Eastern+Male : 69% of 813 images
# relu {}
# layer1.0.relu {}
# layer1.1.relu {}
# layer1.2.relu {39: 0.033210332103321034}
# layer2.0.relu {}
# layer2.1.relu {1: 0.01968019680196802}
# layer2.2.relu {80: 0.012300123001230012}
# layer2.3.relu {76: 0.017220172201722016, 105: 0.04059040590405904}
# layer3.0.relu {7: 0.03567035670356704, 84: 0.017220172201722016, 121: 0.03690036900369004, 122: 0.02214022140221402, 231: 0.02706027060270603, 241: 0.012300123001230012, 251: 0.03198031980319803}
# layer3.1.relu {18: 0.014760147601476014, 111: 0.14514145141451415, 118: 0.12423124231242312, 122: 0.013530135301353014, 139: 0.017220172201722016, 144: 0.012300123001230012, 146: 0.2607626076260763, 151: 0.0959409594095941, 161: 0.020910209102091022, 162: 0.18450184501845018, 172: 0.015990159901599015, 180: 0.22263222632226323, 197: 0.13038130381303814, 213: 0.13776137761377613, 229: 0.03690036900369004, 231: 0.05043050430504305, 236: 0.08241082410824108, 251: 0.3886838868388684}
# layer3.2.relu {1: 0.014760147601476014, 15: 0.014760147601476014, 91: 0.01107011070110701, 111: 0.01107011070110701, 118: 0.13776137761377613, 139: 0.013530135301353014, 151: 0.12915129151291513, 162: 0.16974169741697417, 166: 0.013530135301353014, 182: 0.05043050430504305, 187: 0.03075030750307503, 205: 0.02706027060270603, 225: 0.014760147601476014, 241: 0.04305043050430504}
# layer3.3.relu {6: 0.014760147601476014, 118: 0.04428044280442804, 141: 0.01968019680196802, 156: 0.01845018450184502, 162: 0.1033210332103321, 182: 0.01107011070110701, 187: 0.05166051660516605, 205: 0.017220172201722016, 251: 0.07872078720787208}
# layer3.4.relu {118: 0.041820418204182044, 134: 0.024600246002460024, 205: 0.017220172201722016, 223: 0.012300123001230012, 251: 0.0996309963099631}
# layer3.5.relu {134: 0.01107011070110701}
# layer4.0.relu {}
# layer4.1.relu {}
# layer4.2.relu {}
