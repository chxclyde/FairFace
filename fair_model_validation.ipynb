# %%
import os.path
import torch
import torch.nn as nn
import torchvision
from torchvision import transforms
import pandas as pd
import dlib
import numpy as np
import copy
import pickle

# %% [markdown]
# Loading mode, get test_img names etc.

# %%
# input labels.
label = pd.read_csv("labels/fairface_label_val.csv")
imgs_path = "fairface-img-margin025-trainval/val"
img_names = [os.path.join(imgs_path, x) for x in os.listdir(imgs_path)]
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")

model_fair_7 = torchvision.models.resnet34(pretrained=True)
model_fair_7.fc = nn.Linear(model_fair_7.fc.in_features, 9)
# if runs on a machine without GPU, should do map_location=torch.device('cpu')
#model_fair_7.load_state_dict(torch.load('fair_face_models/fairface_alldata_20191111.pt')) 
model_fair_7.load_state_dict(torch.load('fair_face_models/my_fairface_model.pt'))
model_fair_7 = model_fair_7.to(device)


# trans

trans = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
# Out:
# /home/clydechx/FairFace/env/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/clydechx/FairFace/env/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %% [markdown]
# Start running the model.

# %%
# # Define a hook for all ReLU layers to compute the sum of activations of each filter
# activation = {}
# def relu_hook(module, input, output, layer_name):
#     activation[layer_name] = output.detach()
# # Register the hook for all ReLU layers
# for layer_name, layer in model.named_modules():
#     if isinstance(layer, torch.nn.ReLU):
#         layer.register_forward_hook(relu_hook, layer_name=layer_name)
num_filters = {}
activation = {}
filter_sums = {}
def get_activation(name):
    def hook(model, input, output):
        # Squeeze the tensor to remove the dimension with size 1
        squeezed_tensor = torch.squeeze(output.detach())
        activation[name] = squeezed_tensor
        # If squeezed_tensor has more than one dimension, flatten it
        if len(squeezed_tensor.shape) > 1:
            flattened_tensor = torch.flatten(squeezed_tensor, start_dim=1)
        else:
            flattened_tensor = squeezed_tensor
        # Sum along the second dimension if it exists, otherwise keep the tensor as is
        if flattened_tensor.dim() > 1:
            summed_tensor = flattened_tensor.sum(dim=1)
        else:
            summed_tensor = flattened_tensor
        # Convert the tensor to a list
        summed_list = summed_tensor.tolist()
        filter_sums[name] = summed_list
        num_filters[name] = len(summed_list)
    return hook

for name, layer in model_fair_7.named_modules():
    if isinstance(layer, torch.nn.ReLU):
        layer.register_forward_hook(get_activation(name))

# %%
# Define class labels for CIFAR-10
classes = ['Black+Female', 'Black+Male', 'East Asian+Female', 'East Asian+Male', 'Indian+Female', 'Indian+Male', 'Latino_Hispanic+Female', 'Latino_Hispanic+Male', 'Middle Eastern+Female', 'Middle Eastern+Male', 'Southeast Asian+Female', 'Southeast Asian+Male', 'White+Female', 'White+Male']
# Define variables to track accuracy and class-wise accuracy
correct = 0
total = 0
class_correct = [0] * 14
class_total = [0] * 14



# in FairFace model we have the following map.
race_dict = {
            0: 'White',
            1: 'Black',
            2: 'Latino_Hispanic',
            3: 'East Asian',
            4: 'Southeast Asian',
            5: 'Indian',
            6: 'Middle Eastern'
        }
gender_dict = { 0:'Male' , 1 :'Female'}
# this is a map from race and gender to class.
my_class_map = {
    (1, 1): 0,
    (1, 0): 1,
    (3, 1): 2,
    (3, 0): 3,
    (5, 1): 4,
    (5, 0): 5,
    (2, 1): 6,
    (2, 0): 7,
    (6, 1): 8,
    (6, 0): 9,
    (4, 1): 10,
    (4, 0): 11,
    (0, 1): 12,
    (0, 0): 13
}

image_predictation_result = {cl: {} for cl in range(len(classes))}
activation_all_images = []
filtersum_all_images = []
miss_predicated_images = []
# Set the model to evaluation mode
model_fair_7.eval()
my_label = pd.read_csv("labels/fairface_label_val.csv")
for index, img_name in enumerate(img_names):
    if index % 1000 == 0:
        print("Predicting... {}/{}".format(index, len(img_names)))
    img_name_in_label =  'val/' +img_name.split('/')[-1]
    label_row = my_label[my_label['file'] == img_name_in_label].iloc[0]
    
    # load image, run model.
    image = dlib.load_rgb_image(img_name)
    image = trans(image)
    image = image.view(1, 3, 224, 224)  # reshape image to match model dimensions (1 batch size)
    image = image.to(device)
    
    outputs = model_fair_7(image)
    outputs = outputs.cpu().detach().numpy()
    outputs = np.squeeze(outputs)
    
    race_outputs = outputs[:7]
    gender_outputs = outputs[7:9]
    
    race_score = np.exp(race_outputs) / np.sum(np.exp(race_outputs))
    gender_score = np.exp(gender_outputs) / np.sum(np.exp(gender_outputs))

    race_pred = np.argmax(race_score)
    gender_pred = np.argmax(gender_score)

    predict_class = my_class_map[(race_pred,gender_pred)]
    label_class_name = label_row['race']+"+" + label_row['gender']
    label_class = classes.index(label_class_name)
    
    
    total +=1
    class_total[label_class] += 1
    image_predictation_result[label_class ][index] = predict_class
    filtersum_all_images.append(copy.deepcopy(filter_sums))
    
    # predict correctly 
    if predict_class == label_class:
        correct+=1
        class_correct[label_class]+=1
    # predict wrongly
    else:
        miss_predicated_images.append(index)
        print("Predicted label: {}, Ground truth: {}".format(predict_class, label_class))
# Out:
# Predicting... 0/10954
# Predicted label: 11, Ground truth: 3
# Predicted label: 2, Ground truth: 10
# Predicted label: 11, Ground truth: 0
# Predicted label: 8, Ground truth: 12
# Predicted label: 3, Ground truth: 11
# Predicted label: 4, Ground truth: 10
# Predicted label: 2, Ground truth: 11
# Predicted label: 8, Ground truth: 12
# Predicted label: 11, Ground truth: 3
# Predicted label: 9, Ground truth: 5
# Predicted label: 11, Ground truth: 7
# Predicted label: 10, Ground truth: 2
# Predicted label: 7, Ground truth: 1
# Predicted label: 12, Ground truth: 4
# Predicted label: 6, Ground truth: 8
# Predicted label: 12, Ground truth: 8
# Predicted label: 7, Ground truth: 11
# Predicted label: 7, Ground truth: 5
# Predicted label: 6, Ground truth: 4
# Predicted label: 12, Ground truth: 6
# Predicted label: 12, Ground truth: 8
# Predicted label: 6, Ground truth: 4
# Predicted label: 12, Ground truth: 8
# Predicted label: 13, Ground truth: 5
# Predicted label: 6, Ground truth: 4
# Predicted label: 8, Ground truth: 6
# Predicted label: 9, Ground truth: 7
# Predicted label: 10, Ground truth: 2
# Predicted label: 8, Ground truth: 12
# Predicted label: 2, Ground truth: 10
# Predicted label: 5, Ground truth: 7
# Predicted label: 9, Ground truth: 13
# Predicted label: 11, Ground truth: 10
# Predicted label: 9, Ground truth: 5
# Predicted label: 4, Ground truth: 12
# Predicted label: 8, Ground truth: 12
# Predicted label: 10, Ground truth: 6
# Predicted label: 9, Ground truth: 7
# Predicted label: 10, Ground truth: 0
# Predicted label: 7, Ground truth: 6
# Predicted label: 5, Ground truth: 11
# Predicted label: 7, Ground truth: 9
# Predicted label: 3, Ground truth: 11
# Predicted label: 6, Ground truth: 4
# Predicted label: 7, Ground truth: 11
# Predicted label: 2, Ground truth: 10
# Predicted label: 9, Ground truth: 5
# Predicted label: 6, Ground truth: 9
# Predicted label: 11, Ground truth: 5
# Predicted label: 6, Ground truth: 8
# Predicted label: 6, Ground truth: 7
# Predicted label: 10, Ground truth: 2
# Predicted label: 1, Ground truth: 5
# Predicted label: 6, Ground truth: 0
# Predicted label: 1, Ground truth: 12
# Predicted label: 8, Ground truth: 12
# Predicted label: 6, Ground truth: 4
# Predicted label: 12, Ground truth: 6
# Predicted label: 11, Ground truth: 1
# Predicted label: 7, Ground truth: 9
# Predicted label: 6, Ground truth: 9
# Predicted label: 10, Ground truth: 11
# Predicted label: 11, Ground truth: 3
# Predicted label: 13, Ground truth: 12
# Predicted label: 3, Ground truth: 11
# Predicted label: 7, Ground truth: 9
# Predicted label: 12, Ground truth: 8
# Predicted label: 6, Ground truth: 4
# Predicted label: 12, Ground truth: 13
# Predicted label: 9, Ground truth: 13
# Predicted label: 13, Ground truth: 7
# Predicted label: 1, Ground truth: 5
# Predicted label: 11, Ground truth: 2
# Predicted label: 12, Ground truth: 8
# Predicted label: 7, Ground truth: 5
# Predicted label: 12, Ground truth: 13
# Predicted label: 2, Ground truth: 6
# Predicted label: 10, Ground truth: 3
# Predicted label: 8, Ground truth: 12
# Predicted label: 3, Ground truth: 11
# Predicted label: 3, Ground truth: 7
# Predicted label: 12, Ground truth: 6
# Predicted label: 5, Ground truth: 13
# Predicted label: 10, Ground truth: 2
# Predicted label: 9, Ground truth: 13
# Predicted label: 3, Ground truth: 11
# Predicted label: 8, Ground truth: 4
# Predicted label: 2, Ground truth: 6
# Predicted label: 4, Ground truth: 10
# Predicted label: 9, Ground truth: 5
# Predicted label: 6, Ground truth: 1
# Predicted label: 3, Ground truth: 11
# Predicted label: 7, Ground truth: 1
# Predicted label: 4, Ground truth: 6
# Predicted label: 5, Ground truth: 11
# Predicted label: 13, Ground truth: 7
# Predicted label: 2, Ground truth: 10
# Predicted label: 5, Ground truth: 3
# Predicted label: 1, Ground truth: 0
# Predicted label: 9, Ground truth: 5
# Predicted label: 7, Ground truth: 4
# Predicted label: 10, Ground truth: 2
# Predicted label: 10, Ground truth: 6
# Predicted label: 0, Ground truth: 4
# Predicted label: 6, Ground truth: 8
# Predicted label: 13, Ground truth: 5
# Predicted label: 11, Ground truth: 7
# Predicted label: 6, Ground truth: 4
# Predicted label: 10, Ground truth: 2
# Predicted label: 7, Ground truth: 5
# Predicted label: 7, Ground truth: 13
# Predicted label: 12, Ground truth: 8
# Predicted label: 5, Ground truth: 1
# Predicted label: 0, Ground truth: 1
# Predicted label: 13, Ground truth: 9
# Predicted label: 7, Ground truth: 9
# Predicted label: 13, Ground truth: 10
# Predicted label: 11, Ground truth: 3
# Predicted label: 3, Ground truth: 7
# Predicted label: 7, Ground truth: 9
# Predicted label: 6, Ground truth: 5
# Predicted label: 7, Ground truth: 9
# Predicted label: 4, Ground truth: 6
# Predicted label: 3, Ground truth: 2
# Predicted label: 6, Ground truth: 12
# Predicted label: 6, Ground truth: 0
# Predicted label: 6, Ground truth: 2
# Predicted label: 9, Ground truth: 13
# Predicted label: 7, Ground truth: 9
# Predicted label: 13, Ground truth: 7
# Predicted label: 11, Ground truth: 1
# Predicted label: 13, Ground truth: 12
# Predicted label: 4, Ground truth: 8
# Predicted label: 4, Ground truth: 12
# Predicted label: 11, Ground truth: 3
# Predicted label: 7, Ground truth: 5
# Predicted label: 9, Ground truth: 1
# Predicted label: 13, Ground truth: 12
# Predicted label: 12, Ground truth: 13
# Predicted label: 5, Ground truth: 13
# Predicted label: 7, Ground truth: 6
# Predicted label: 1, Ground truth: 0
# Predicted label: 3, Ground truth: 11
# Predicted label: 1, Ground truth: 7
# Predicted label: 2, Ground truth: 3
# Predicted label: 11, Ground truth: 6
# Predicted label: 7, Ground truth: 5
# Predicted label: 8, Ground truth: 6
# Predicted label: 5, Ground truth: 13
# Predicted label: 13, Ground truth: 7
# Predicted label: 13, Ground truth: 7
# Predicted label: 4, Ground truth: 12
# Predicted label: 9, Ground truth: 13
# Predicted label: 7, Ground truth: 9
# Predicted label: 7, Ground truth: 11
# Predicted label: 8, Ground truth: 12
# Predicted label: 12, Ground truth: 7
# Predicted label: 5, Ground truth: 7
# Predicted label: 9, Ground truth: 8
# Predicted label: 9, Ground truth: 11
# Predicted label: 6, Ground truth: 12
# Predicted label: 6, Ground truth: 0
# Predicted label: 11, Ground truth: 3
# Predicted label: 6, Ground truth: 2
# Predicted label: 9, Ground truth: 5
# Predicted label: 1, Ground truth: 0
# Predicted label: 11, Ground truth: 3
# Predicted label: 7, Ground truth: 13
# Predicted label: 9, Ground truth: 10
# Predicted label: 12, Ground truth: 8
# Predicted label: 2, Ground truth: 11
# Predicted label: 6, Ground truth: 4
# Predicted label: 7, Ground truth: 13
# Predicted label: 3, Ground truth: 11
# Predicted label: 12, Ground truth: 4
# Predicted label: 12, Ground truth: 8
# Predicted label: 13, Ground truth: 9
# Predicted label: 7, Ground truth: 9
# Predicted label: 3, Ground truth: 2
# Predicted label: 0, Ground truth: 1
# Predicted label: 11, Ground truth: 7
# Predicted label: 6, Ground truth: 8
# Predicted label: 7, Ground truth: 6
# Predicted label: 9, Ground truth: 0
# Predicted label: 2, Ground truth: 6
# Predicted label: 8, Ground truth: 12
# Predicted label: 0, Ground truth: 1
# Predicted label: 2, Ground truth: 10
# Predicted label: 2, Ground truth: 11
# Predicted label: 0, Ground truth: 10
# Predicted label: 3, Ground truth: 11
# Predicted label: 4, Ground truth: 6
# Predicted label: 7, Ground truth: 9
# Predicted label: 7, Ground truth: 3
# Predicted label: 2, Ground truth: 10
# Predicted label: 12, Ground truth: 6
# Predicted label: 6, Ground truth: 9
# Predicted label: 6, Ground truth: 8
# Predicted label: 7, Ground truth: 5
# Predicted label: 8, Ground truth: 12
# Predicted label: 10, Ground truth: 2
# Predicted label: 2, Ground truth: 10
# Predicted label: 2, Ground truth: 10
# Predicted label: 0, Ground truth: 5
# Predicted label: 0, Ground truth: 1
# Predicted label: 2, Ground truth: 10
# Predicted label: 7, Ground truth: 5
# Predicted label: 10, Ground truth: 2
# Predicted label: 13, Ground truth: 9
# Predicted label: 1, Ground truth: 0
# Predicted label: 9, Ground truth: 8
# Predicted label: 12, Ground truth: 8
# Predicted label: 5, Ground truth: 4
# Predicted label: 13, Ground truth: 7
# Predicted label: 2, Ground truth: 10
# Predicted label: 10, Ground truth: 2
# Predicted label: 7, Ground truth: 11
# Predicted label: 2, Ground truth: 10
# Predicted label: 4, Ground truth: 6
# Predicted label: 7, Ground truth: 1
# Predicted label: 6, Ground truth: 12
# Predicted label: 9, Ground truth: 13
# Predicted label: 6, Ground truth: 7
# Predicted label: 3, Ground truth: 11
# Predicted label: 8, Ground truth: 12
# Predicted label: 9, Ground truth: 5
# Predicted label: 12, Ground truth: 6
# Predicted label: 7, Ground truth: 9
# Predicted label: 7, Ground truth: 13
# Predicted label: 7, Ground truth: 5
# Predicted label: 5, Ground truth: 13
# Predicted label: 2, Ground truth: 3
# Predicted label: 3, Ground truth: 11
# Predicted label: 2, Ground truth: 10
# Predicted label: 0, Ground truth: 1
# Predicted label: 6, Ground truth: 8
# Predicted label: 11, Ground truth: 3
# Predicted label: 9, Ground truth: 5
# Predicted label: 5, Ground truth: 1
# Predicted label: 1, Ground truth: 0
# Predicted label: 8, Ground truth: 6
# Predicted label: 12, Ground truth: 13
# Predicted label: 10, Ground truth: 2
# Predicted label: 9, Ground truth: 13
# Predicted label: 6, Ground truth: 12
# Predicted label: 3, Ground truth: 11
# Predicted label: 1, Ground truth: 0
# Predicted label: 11, Ground truth: 3
# Predicted label: 9, Ground truth: 7
# Predicted label: 12, Ground truth: 6
# Predicted label: 2, Ground truth: 3
# Predicted label: 0, Ground truth: 4
# Predicted label: 12, Ground truth: 8
# Predicted label: 6, Ground truth: 4
# Predicted label: 10, Ground truth: 2
# Predicted label: 13, Ground truth: 9
# Predicted label: 7, Ground truth: 5
# Predicted label: 7, Ground truth: 1
# Predicted label: 2, Ground truth: 10
# Predicted label: 3, Ground truth: 11
# Predicted label: 12, Ground truth: 8
# Predicted label: 2, Ground truth: 10
# Predicted label: 1, Ground truth: 0
# Predicted label: 13, Ground truth: 12
# Predicted label: 13, Ground truth: 7
# Predicted label: 10, Ground truth: 4
# Predicted label: 2, Ground truth: 10
# Predicted label: 7, Ground truth: 11
# Predicted label: 13, Ground truth: 9
# Predicted label: 8, Ground truth: 6
# Predicted label: 7, Ground truth: 1
# Predicted label: 12, Ground truth: 6
# Predicted label: 12, Ground truth: 6
# Predicted label: 6, Ground truth: 4
# Predicted label: 9, Ground truth: 7
# Predicted label: 13, Ground truth: 12
# Predicted label: 7, Ground truth: 0
# Predicted label: 11, Ground truth: 13
# Predicted label: 9, Ground truth: 13
# Predicted label: 4, Ground truth: 10
# Predicted label: 12, Ground truth: 4
# Predicted label: 5, Ground truth: 6
# Predicted label: 4, Ground truth: 5
# Predicted label: 2, Ground truth: 10
# Predicted label: 7, Ground truth: 11
# Predicted label: 3, Ground truth: 7
# Predicted label: 5, Ground truth: 7
# Predicted label: 6, Ground truth: 4
# Predicted label: 10, Ground truth: 2
# Predicted label: 6, Ground truth: 12
# Predicted label: 0, Ground truth: 1
# Predicted label: 9, Ground truth: 11
# Predicted label: 6, Ground truth: 12
# Predicted label: 8, Ground truth: 6
# Predicted label: 5, Ground truth: 9
# Predicted label: 5, Ground truth: 7
# Predicted label: 12, Ground truth: 6
# Predicted label: 7, Ground truth: 5
# Predicted label: 1, Ground truth: 0
# Predicted label: 13, Ground truth: 9
# Predicted label: 4, Ground truth: 1
# Predicted label: 3, Ground truth: 11
# Predicted label: 9, Ground truth: 11
# Predicted label: 10, Ground truth: 6
# Predicted label: 10, Ground truth: 2
# Predicted label: 13, Ground truth: 11
# Predicted label: 12, Ground truth: 8
# Predicted label: 3, Ground truth: 12
# Predicted label: 0, Ground truth: 1
# Predicted label: 7, Ground truth: 3
# Predicted label: 11, Ground truth: 3
# Predicted label: 11, Ground truth: 3
# Predicted label: 3, Ground truth: 12
# Predicted label: 12, Ground truth: 8
# Predicted label: 3, Ground truth: 11
# Predicted label: 4, Ground truth: 6
# Predicted label: 12, Ground truth: 8
# Predicted label: 11, Ground truth: 3
# Predicted label: 1, Ground truth: 0
# Predicted label: 6, Ground truth: 2
# Predicted label: 7, Ground truth: 1
# Predicted label: 6, Ground truth: 2
# Predicted label: 7, Ground truth: 13
# Predicted label: 1, Ground truth: 13
# Predicted label: 11, Ground truth: 3
# Predicted label: 1, Ground truth: 0
# Predicted label: 7, Ground truth: 13
# Predicted label: 5, Ground truth: 4
# Predicted label: 10, Ground truth: 12
# Predicted label: 10, Ground truth: 2
# Predicted label: 3, Ground truth: 2
# Predicted label: 2, Ground truth: 11
# Predicted label: 11, Ground truth: 3
# Predicted label: 11, Ground truth: 10
# Predicted label: 11, Ground truth: 4
# Predicted label: 13, Ground truth: 3
# Predicted label: 4, Ground truth: 8
# Predicted label: 9, Ground truth: 8
# Predicted label: 2, Ground truth: 10
# Predicted label: 6, Ground truth: 4
# Predicted label: 7, Ground truth: 11
# Predicted label: 13, Ground truth: 9
# Predicted label: 8, Ground truth: 6
# Predicted label: 7, Ground truth: 5
# Predicted label: 13, Ground truth: 9
# Predicted label: 4, Ground truth: 7
# Predicted label: 7, Ground truth: 6
# Predicted label: 6, Ground truth: 10
# Predicted label: 7, Ground truth: 11
# Predicted label: 10, Ground truth: 2
# Predicted label: 2, Ground truth: 11
# Predicted label: 13, Ground truth: 5
# Predicted label: 7, Ground truth: 13
# Predicted label: 13, Ground truth: 11
# Predicted label: 11, Ground truth: 3
# Predicted label: 11, Ground truth: 3
# Predicted label: 5, Ground truth: 1
# Predicted label: 5, Ground truth: 4
# Predicted label: 1, Ground truth: 5
# Predicted label: 6, Ground truth: 12
# Predicted label: 2, Ground truth: 10
# Predicted label: 9, Ground truth: 8
# Predicted label: 1, Ground truth: 11
# Predicted label: 7, Ground truth: 13
# Predicted label: 7, Ground truth: 13
# Predicted label: 5, Ground truth: 7
# Predicted label: 10, Ground truth: 11
# Predicted label: 1, Ground truth: 0
# Predicted label: 7, Ground truth: 13
# Predicted label: 7, Ground truth: 13
# Predicted label: 9, Ground truth: 7
# Predicted label: 13, Ground truth: 12
# Predicted label: 1, Ground truth: 11
# Predicted label: 13, Ground truth: 9
# Predicted label: 7, Ground truth: 1
# Predicted label: 8, Ground truth: 6
# Predicted label: 13, Ground truth: 7
# Predicted label: 3, Ground truth: 2
# Predicted label: 12, Ground truth: 6
# Predicted label: 1, Ground truth: 7
# Predicted label: 10, Ground truth: 6
# Predicted label: 3, Ground truth: 11
# Predicted label: 13, Ground truth: 5
# Predicted label: 9, Ground truth: 8
# Predicted label: 13, Ground truth: 5
# Predicted label: 7, Ground truth: 9
# Predicted label: 2, Ground truth: 10
# Predicted label: 0, Ground truth: 1
# Predicted label: 8, Ground truth: 13
# Predicted label: 12, Ground truth: 6
# Predicted label: 1, Ground truth: 0
# Predicted label: 7, Ground truth: 5
# Predicted label: 1, Ground truth: 5
# Predicted label: 7, Ground truth: 5
# Predicted label: 2, Ground truth: 12
# Predicted label: 4, Ground truth: 0
# Predicted label: 6, Ground truth: 0
# Predicted label: 5, Ground truth: 7
# Predicted label: 11, Ground truth: 10
# Predicted label: 10, Ground truth: 2
# Predicted label: 7, Ground truth: 5
# Predicted label: 6, Ground truth: 4
# Predicted label: 12, Ground truth: 8
# Predicted label: 7, Ground truth: 4
# Predicted label: 7, Ground truth: 9
# Predicted label: 7, Ground truth: 13
# Predicted label: 1, Ground truth: 5
# Predicted label: 3, Ground truth: 11
# Predicted label: 9, Ground truth: 8
# Predicted label: 7, Ground truth: 13
# Predicted label: 10, Ground truth: 2
# Predicted label: 9, Ground truth: 13
# Predicted label: 7, Ground truth: 5
# Predicted label: 5, Ground truth: 13
# Predicted label: 13, Ground truth: 9
# Predicted label: 9, Ground truth: 13
# Predicted label: 10, Ground truth: 2
# Predicted label: 4, Ground truth: 6
# Predicted label: 12, Ground truth: 6
# Predicted label: 1, Ground truth: 0
# Predicted label: 12, Ground truth: 8
# Predicted label: 0, Ground truth: 1
# Predicted label: 6, Ground truth: 12
# Predicted label: 12, Ground truth: 6
# Predicted label: 11, Ground truth: 5
# Predicting... 1000/10954
# Predicted label: 2, Ground truth: 10
# Predicted label: 1, Ground truth: 0
# Predicted label: 2, Ground truth: 6
# Predicted label: 1, Ground truth: 11
# Predicted label: 7, Ground truth: 6
# Predicted label: 9, Ground truth: 7
# Predicted label: 7, Ground truth: 5
# Predicted label: 13, Ground truth: 12
# Predicted label: 4, Ground truth: 6
# Predicted label: 11, Ground truth: 6
# Predicted label: 0, Ground truth: 6
# Predicted label: 7, Ground truth: 9
# Predicted label: 3, Ground truth: 11
# Predicted label: 5, Ground truth: 1
# Predicted label: 5, Ground truth: 10
# Predicted label: 2, Ground truth: 10
# Predicted label: 13, Ground truth: 9
# Predicted label: 0, Ground truth: 4
# Predicted label: 6, Ground truth: 0
# Predicted label: 13, Ground truth: 7
# Predicted label: 7, Ground truth: 9
# Predicted label: 11, Ground truth: 1
# Predicted label: 11, Ground truth: 7
# Predicted label: 13, Ground truth: 12
# Predicted label: 6, Ground truth: 4
# Predicted label: 9, Ground truth: 7
# Predicted label: 8, Ground truth: 6
# Predicted label: 0, Ground truth: 1
# Predicted label: 4, Ground truth: 8
# Predicted label: 8, Ground truth: 6
# Predicted label: 11, Ground truth: 13
# Predicted label: 3, Ground truth: 11
# Predicted label: 0, Ground truth: 4
# Predicted label: 6, Ground truth: 12
# Predicted label: 0, Ground truth: 1
# Predicted label: 3, Ground truth: 11
# Predicted label: 3, Ground truth: 11
# Predicted label: 5, Ground truth: 1
# Predicted label: 13, Ground truth: 12
# Predicted label: 11, Ground truth: 7
# Predicted label: 5, Ground truth: 7
# Predicted label: 1, Ground truth: 7
# Predicted label: 12, Ground truth: 6
# Predicted label: 10, Ground truth: 6
# Predicted label: 12, Ground truth: 13
# Predicted label: 3, Ground truth: 2
# Predicted label: 12, Ground truth: 6
# Predicted label: 9, Ground truth: 7
# Predicted label: 13, Ground truth: 9
# Predicted label: 3, Ground truth: 2
# Predicted label: 7, Ground truth: 11
# Predicted label: 7, Ground truth: 13
# Predicted label: 13, Ground truth: 1
# Predicted label: 6, Ground truth: 10
# Predicted label: 12, Ground truth: 6
# Predicted label: 12, Ground truth: 6
# Predicted label: 7, Ground truth: 1
# Predicted label: 9, Ground truth: 5
# Predicted label: 11, Ground truth: 3
# Predicted label: 7, Ground truth: 9
# Predicted label: 6, Ground truth: 12
# Predicted label: 9, Ground truth: 13
# Predicted label: 2, Ground truth: 10
# Predicted label: 5, Ground truth: 1
# Predicted label: 3, Ground truth: 11
# Predicted label: 9, Ground truth: 13
# Predicted label: 1, Ground truth: 0
# Predicted label: 8, Ground truth: 12
# Predicted label: 12, Ground truth: 8
# Predicted label: 12, Ground truth: 13
# Predicted label: 3, Ground truth: 11
# Predicted label: 0, Ground truth: 12
# Predicted label: 13, Ground truth: 0
# Predicted label: 9, Ground truth: 5
# Predicted label: 3, Ground truth: 11
# Predicted label: 5, Ground truth: 4
# Predicted label: 6, Ground truth: 0
# Predicted label: 2, Ground truth: 3
# Predicted label: 6, Ground truth: 0
# Predicted label: 11, Ground truth: 3
# Predicted label: 7, Ground truth: 9
# Predicted label: 11, Ground truth: 5
# Predicted label: 11, Ground truth: 3
# Predicted label: 3, Ground truth: 13
# Predicted label: 1, Ground truth: 6
# Predicted label: 6, Ground truth: 11
# Predicted label: 1, Ground truth: 3
# Predicted label: 3, Ground truth: 5
# Predicted label: 4, Ground truth: 5
# Predicted label: 7, Ground truth: 5
# Predicted label: 2, Ground truth: 10
# Predicted label: 13, Ground truth: 9
# Predicted label: 7, Ground truth: 1
# Predicted label: 8, Ground truth: 6
# Predicted label: 7, Ground truth: 9
# Predicted label: 2, Ground truth: 10
# Predicted label: 4, Ground truth: 6
# Predicted label: 13, Ground truth: 7
# Predicted label: 4, Ground truth: 0
# Predicted label: 13, Ground truth: 7
# Predicted label: 10, Ground truth: 6
# Predicted label: 2, Ground truth: 10
# Predicted label: 11, Ground truth: 2
# Predicted label: 10, Ground truth: 6
# Predicted label: 11, Ground truth: 3
# Predicted label: 3, Ground truth: 7
# Predicted label: 9, Ground truth: 13
# Predicted label: 7, Ground truth: 9
# Predicted label: 7, Ground truth: 13
# Predicted label: 10, Ground truth: 2
# Predicted label: 7, Ground truth: 13
# Predicted label: 3, Ground truth: 7
# Predicted label: 6, Ground truth: 8
# Predicted label: 1, Ground truth: 5
# Predicted label: 6, Ground truth: 10
# Predicted label: 1, Ground truth: 0
# Predicted label: 0, Ground truth: 1
# Predicted label: 6, Ground truth: 8
# Predicted label: 11, Ground truth: 3
# Predicted label: 10, Ground truth: 12
# Predicted label: 6, Ground truth: 12
# Predicted label: 9, Ground truth: 13
# Predicted label: 11, Ground truth: 3
# Predicted label: 12, Ground truth: 13
# Predicted label: 5, Ground truth: 11
# Predicted label: 6, Ground truth: 8
# Predicted label: 4, Ground truth: 8
# Predicted label: 2, Ground truth: 12
# Predicted label: 1, Ground truth: 5
# Predicted label: 7, Ground truth: 6
# Predicted label: 0, Ground truth: 4
# Predicted label: 13, Ground truth: 5
# Predicted label: 6, Ground truth: 8
# Predicted label: 10, Ground truth: 7
# Predicted label: 12, Ground truth: 13
# Predicted label: 1, Ground truth: 0
# Predicted label: 0, Ground truth: 6
# Predicted label: 12, Ground truth: 9
# Predicted label: 7, Ground truth: 5
# Predicted label: 5, Ground truth: 7
# Predicted label: 5, Ground truth: 4
# Predicted label: 10, Ground truth: 2
# Predicted label: 6, Ground truth: 8
# Predicted label: 8, Ground truth: 4
# Predicted label: 7, Ground truth: 9
# Predicted label: 2, Ground truth: 10
# Predicted label: 7, Ground truth: 9
# Predicted label: 6, Ground truth: 4
# Predicted label: 6, Ground truth: 4
# Predicted label: 6, Ground truth: 8
# Predicted label: 3, Ground truth: 11
# Predicted label: 2, Ground truth: 11
# Predicted label: 13, Ground truth: 9
# Predicted label: 7, Ground truth: 13
# Predicted label: 11, Ground truth: 3
# Predicted label: 6, Ground truth: 4
# Predicted label: 0, Ground truth: 13
# Predicted label: 12, Ground truth: 4
# Predicted label: 13, Ground truth: 12
# Predicted label: 9, Ground truth: 13
# Predicted label: 8, Ground truth: 10
# Predicted label: 9, Ground truth: 7
# Predicted label: 2, Ground truth: 9
# Predicted label: 13, Ground truth: 7
# Predicted label: 6, Ground truth: 12
# Predicted label: 7, Ground truth: 9
# Predicted label: 1, Ground truth: 7
# Predicted label: 6, Ground truth: 8
# Predicted label: 5, Ground truth: 4
# Predicted label: 10, Ground truth: 13
# Predicted label: 4, Ground truth: 0
# Predicted label: 5, Ground truth: 9
# Predicted label: 6, Ground truth: 0
# Predicted label: 6, Ground truth: 10
# Predicted label: 7, Ground truth: 13
# Predicted label: 2, Ground truth: 10
# Predicted label: 3, Ground truth: 13
# Predicted label: 8, Ground truth: 6
# Predicted label: 2, Ground truth: 10
# Predicted label: 6, Ground truth: 4
# Predicted label: 4, Ground truth: 8
# Predicted label: 0, Ground truth: 5
# Predicted label: 6, Ground truth: 4
# Predicted label: 7, Ground truth: 3
# Predicted label: 1, Ground truth: 4
# Predicted label: 7, Ground truth: 13
# Predicted label: 10, Ground truth: 4
# Predicted label: 13, Ground truth: 5
# Predicted label: 7, Ground truth: 13
# Predicted label: 3, Ground truth: 2
# Predicted label: 10, Ground truth: 11
# Predicted label: 2, Ground truth: 13
# Predicted label: 6, Ground truth: 0
# Predicted label: 12, Ground truth: 6
# Predicted label: 3, Ground truth: 6
# Predicted label: 11, Ground truth: 3
# Predicted label: 10, Ground truth: 2
# Predicted label: 1, Ground truth: 0
# Predicted label: 6, Ground truth: 12
# Predicted label: 9, Ground truth: 13
# Predicted label: 6, Ground truth: 4
# Predicted label: 6, Ground truth: 8
# Predicted label: 12, Ground truth: 4
# Predicted label: 7, Ground truth: 13
# Predicted label: 7, Ground truth: 11
# Predicted label: 10, Ground truth: 2
# Predicted label: 2, Ground truth: 10
# Predicted label: 2, Ground truth: 3
# Predicted label: 7, Ground truth: 9
# Predicted label: 3, Ground truth: 11
# Predicted label: 12, Ground truth: 6
# Predicted label: 6, Ground truth: 8
# Predicted label: 3, Ground truth: 2
# Predicted label: 8, Ground truth: 7
# Predicted label: 11, Ground truth: 7
# Predicted label: 0, Ground truth: 4
# Predicted label: 7, Ground truth: 13
# Predicted label: 11, Ground truth: 3
# Predicted label: 1, Ground truth: 7
# Predicted label: 6, Ground truth: 8
# Predicted label: 6, Ground truth: 12
# Predicted label: 9, Ground truth: 7
# Predicted label: 9, Ground truth: 13
# Predicted label: 7, Ground truth: 9
# Predicted label: 6, Ground truth: 8
# Predicted label: 10, Ground truth: 2
# Predicted label: 6, Ground truth: 0
# Predicted label: 12, Ground truth: 6
# Predicted label: 7, Ground truth: 13
# Predicted label: 7, Ground truth: 9
# Predicted label: 13, Ground truth: 11
# Predicted label: 6, Ground truth: 4
# Predicted label: 10, Ground truth: 6
# Predicted label: 6, Ground truth: 4
# Predicted label: 1, Ground truth: 0
# Predicted label: 2, Ground truth: 10
# Predicted label: 11, Ground truth: 10
# Predicted label: 8, Ground truth: 12
# Predicted label: 6, Ground truth: 0
# Predicted label: 13, Ground truth: 4
# Predicted label: 13, Ground truth: 9
# Predicted label: 5, Ground truth: 4
# Predicted label: 6, Ground truth: 4
# Predicted label: 2, Ground truth: 10
# Predicted label: 1, Ground truth: 5
# Predicted label: 9, Ground truth: 13
# Predicted label: 8, Ground truth: 6
# Predicted label: 2, Ground truth: 6
# Predicted label: 7, Ground truth: 1
# Predicted label: 9, Ground truth: 7
# Predicted label: 3, Ground truth: 11
# Predicted label: 5, Ground truth: 11
# Predicted label: 9, Ground truth: 5
# Predicted label: 7, Ground truth: 13
# Predicted label: 4, Ground truth: 0
# Predicted label: 9, Ground truth: 13
# Predicted label: 0, Ground truth: 1
# Predicted label: 7, Ground truth: 5
# Predicted label: 6, Ground truth: 7
# Predicted label: 7, Ground truth: 13
# Predicted label: 13, Ground truth: 8
# Predicted label: 0, Ground truth: 1
# Predicted label: 6, Ground truth: 4
# Predicted label: 7, Ground truth: 5
# Predicted label: 2, Ground truth: 10
# Predicted label: 1, Ground truth: 0
# Predicted label: 9, Ground truth: 13
# Predicted label: 3, Ground truth: 11
# Predicted label: 8, Ground truth: 6
# Predicted label: 10, Ground truth: 2
# Predicted label: 6, Ground truth: 12
# Predicted label: 10, Ground truth: 8
# Predicted label: 10, Ground truth: 2
# Predicted label: 13, Ground truth: 7
# Predicted label: 9, Ground truth: 7
# Predicted label: 10, Ground truth: 2
# Predicted label: 7, Ground truth: 9
# Predicted label: 3, Ground truth: 11
# Predicted label: 6, Ground truth: 8
# Predicted label: 0, Ground truth: 1
# Predicted label: 12, Ground truth: 6
# Predicted label: 2, Ground truth: 10
# Predicted label: 7, Ground truth: 8
# Predicted label: 4, Ground truth: 1
# Predicted label: 8, Ground truth: 6
# Predicted label: 9, Ground truth: 13
# Predicted label: 12, Ground truth: 3
# Predicted label: 12, Ground truth: 6
# Predicted label: 4, Ground truth: 5
# Predicted label: 7, Ground truth: 1
# Predicted label: 6, Ground truth: 8
# Predicted label: 10, Ground truth: 2
# Predicted label: 7, Ground truth: 13
# Predicted label: 13, Ground truth: 12
# Predicted label: 2, Ground truth: 10
# Predicted label: 2, Ground truth: 11
# Predicted label: 7, Ground truth: 13
# Predicted label: 7, Ground truth: 9
# Predicted label: 13, Ground truth: 12
# Predicted label: 8, Ground truth: 7
# Predicted label: 13, Ground truth: 5
# Predicted label: 7, Ground truth: 9
# Predicted label: 9, Ground truth: 0
# Predicted label: 10, Ground truth: 6
# Predicted label: 6, Ground truth: 12
# Predicted label: 13, Ground truth: 9
# Predicted label: 6, Ground truth: 9
# Predicted label: 7, Ground truth: 1
# Predicted label: 3, Ground truth: 11
# Predicted label: 6, Ground truth: 8
# Predicted label: 5, Ground truth: 7
# Predicted label: 6, Ground truth: 4
# Predicted label: 13, Ground truth: 7
# Predicted label: 7, Ground truth: 13
# Predicted label: 7, Ground truth: 13
# Predicted label: 11, Ground truth: 3
# Predicted label: 2, Ground truth: 10
# Predicted label: 10, Ground truth: 2
# Predicted label: 8, Ground truth: 2
# Predicted label: 9, Ground truth: 7
# Predicted label: 9, Ground truth: 13
# Predicted label: 5, Ground truth: 13
# Predicted label: 8, Ground truth: 6
# Predicted label: 12, Ground truth: 8
# Predicted label: 2, Ground truth: 3
# Predicted label: 7, Ground truth: 9
# Predicted label: 7, Ground truth: 0
# Predicted label: 6, Ground truth: 12
# Predicted label: 9, Ground truth: 5
# Predicted label: 7, Ground truth: 9
# Predicted label: 6, Ground truth: 12
# Predicted label: 4, Ground truth: 10
# Predicted label: 6, Ground truth: 4
# Predicted label: 9, Ground truth: 7
# Predicted label: 6, Ground truth: 12
# Predicted label: 7, Ground truth: 9
# Predicted label: 2, Ground truth: 10
# Predicted label: 2, Ground truth: 10
# Predicted label: 1, Ground truth: 8
# Predicted label: 13, Ground truth: 1
# Predicted label: 9, Ground truth: 7
# Predicted label: 6, Ground truth: 10
# Predicted label: 9, Ground truth: 7
# Predicted label: 11, Ground truth: 5
# Predicted label: 6, Ground truth: 4
# Predicted label: 9, Ground truth: 13
# Predicted label: 0, Ground truth: 4
# Predicted label: 6, Ground truth: 10
# Predicted label: 2, Ground truth: 11
# Predicted label: 7, Ground truth: 9
# Predicted label: 9, Ground truth: 7
# Predicted label: 6, Ground truth: 0
# Predicted label: 6, Ground truth: 4
# Predicted label: 4, Ground truth: 6
# Predicted label: 9, Ground truth: 8
# Predicted label: 10, Ground truth: 2
# Predicted label: 11, Ground truth: 3
# Predicted label: 13, Ground truth: 7
# Predicted label: 10, Ground truth: 2
# Predicted label: 6, Ground truth: 4
# Predicted label: 0, Ground truth: 6
# Predicted label: 12, Ground truth: 6
# Predicted label: 4, Ground truth: 6
# Predicted label: 5, Ground truth: 9
# Predicted label: 6, Ground truth: 4
# Predicted label: 3, Ground truth: 11
# Predicted label: 13, Ground truth: 9
# Predicted label: 6, Ground truth: 4
# Predicted label: 7, Ground truth: 11
# Predicted label: 8, Ground truth: 12
# Predicted label: 9, Ground truth: 13
# Predicted label: 12, Ground truth: 6
# Predicted label: 8, Ground truth: 12
# Predicted label: 7, Ground truth: 3
# Predicted label: 4, Ground truth: 0
# Predicted label: 7, Ground truth: 13
# Predicted label: 7, Ground truth: 5
# Predicted label: 6, Ground truth: 8
# Predicted label: 4, Ground truth: 0
# Predicted label: 11, Ground truth: 0
# Predicted label: 13, Ground truth: 1
# Predicted label: 11, Ground truth: 1
# Predicted label: 4, Ground truth: 5
# Predicted label: 13, Ground truth: 7
# Predicted label: 3, Ground truth: 1
# Predicted label: 6, Ground truth: 12
# Predicted label: 12, Ground truth: 8
# Predicted label: 6, Ground truth: 10
# Predicted label: 5, Ground truth: 6
# Predicted label: 7, Ground truth: 9
# Predicted label: 13, Ground truth: 3
# Predicted label: 11, Ground truth: 3
# Predicted label: 9, Ground truth: 7
# Predicted label: 1, Ground truth: 0
# Predicted label: 12, Ground truth: 6
# Predicted label: 6, Ground truth: 12
# Predicted label: 10, Ground truth: 2
# Predicted label: 13, Ground truth: 5
# Predicted label: 5, Ground truth: 9
# Predicted label: 13, Ground truth: 12
# Predicted label: 11, Ground truth: 3
# Predicted label: 6, Ground truth: 12
# Predicted label: 6, Ground truth: 10
# Predicted label: 9, Ground truth: 5
# Predicted label: 13, Ground truth: 1
# Predicted label: 2, Ground truth: 10
# Predicted label: 6, Ground truth: 8
# Predicted label: 8, Ground truth: 6
# Predicting... 2000/10954
# Predicted label: 13, Ground truth: 3
# Predicted label: 13, Ground truth: 5
# Predicted label: 6, Ground truth: 12
# Predicted label: 6, Ground truth: 10
# Predicted label: 7, Ground truth: 3
# Predicted label: 7, Ground truth: 11
# Predicted label: 6, Ground truth: 12
# Predicted label: 11, Ground truth: 0
# Predicted label: 5, Ground truth: 11
# Predicted label: 5, Ground truth: 7
# Predicted label: 4, Ground truth: 7
# Predicted label: 5, Ground truth: 1
# Predicted label: 5, Ground truth: 9
# Predicted label: 9, Ground truth: 5
# Predicted label: 8, Ground truth: 6
# Predicted label: 7, Ground truth: 5
# Predicted label: 8, Ground truth: 4
# Predicted label: 5, Ground truth: 1
# Predicted label: 9, Ground truth: 4
# Predicted label: 13, Ground truth: 9
# Predicted label: 7, Ground truth: 5
# Predicted label: 6, Ground truth: 4
# Predicted label: 5, Ground truth: 4
# Predicted label: 13, Ground truth: 9
# Predicted label: 11, Ground truth: 2
# Predicted label: 9, Ground truth: 7
# Predicted label: 3, Ground truth: 2
# Predicted label: 1, Ground truth: 11
# Predicted label: 4, Ground truth: 0
# Predicted label: 10, Ground truth: 2
# Predicted label: 5, Ground truth: 7
# Predicted label: 9, Ground truth: 7
# Predicted label: 0, Ground truth: 1
# Predicted label: 6, Ground truth: 0
# Predicted label: 0, Ground truth: 12
# Predicted label: 6, Ground truth: 0
# Predicted label: 6, Ground truth: 12
# Predicted label: 4, Ground truth: 10
# Predicted label: 3, Ground truth: 2
# Predicted label: 7, Ground truth: 1
# Predicted label: 5, Ground truth: 7
# Predicted label: 10, Ground truth: 6
# Predicted label: 7, Ground truth: 0
# Predicted label: 11, Ground truth: 7
# Predicted label: 3, Ground truth: 11
# Predicted label: 12, Ground truth: 9
# Predicted label: 13, Ground truth: 12
# Predicted label: 11, Ground truth: 7
# Predicted label: 7, Ground truth: 1
# Predicted label: 10, Ground truth: 11
# Predicted label: 12, Ground truth: 6
# Predicted label: 0, Ground truth: 1
# Predicted label: 5, Ground truth: 3
# Predicted label: 6, Ground truth: 8
# Predicted label: 7, Ground truth: 13
# Predicted label: 2, Ground truth: 10
# Predicted label: 7, Ground truth: 1
# Predicted label: 2, Ground truth: 10
# Predicted label: 5, Ground truth: 7
# Predicted label: 13, Ground truth: 6
# Predicted label: 3, Ground truth: 13
# Predicted label: 1, Ground truth: 5
# Predicted label: 0, Ground truth: 1
# Predicted label: 9, Ground truth: 7
# Predicted label: 8, Ground truth: 6
# Predicted label: 6, Ground truth: 12
# Predicted label: 2, Ground truth: 10
# Predicted label: 5, Ground truth: 1
# Predicted label: 12, Ground truth: 6
# Predicted label: 0, Ground truth: 4
# Predicted label: 9, Ground truth: 13
# Predicted label: 7, Ground truth: 5
# Predicted label: 2, Ground truth: 11
# Predicted label: 9, Ground truth: 7
# Predicted label: 0, Ground truth: 1
# Predicted label: 0, Ground truth: 6
# Predicted label: 11, Ground truth: 7
# Predicted label: 6, Ground truth: 8
# Predicted label: 1, Ground truth: 0
# Predicted label: 7, Ground truth: 13
# Predicted label: 0, Ground truth: 1
# Predicted label: 11, Ground truth: 3
# Predicted label: 7, Ground truth: 11
# Predicted label: 6, Ground truth: 12
# Predicted label: 9, Ground truth: 7
# Predicted label: 7, Ground truth: 9
# Predicted label: 10, Ground truth: 5
# Predicted label: 2, Ground truth: 10
# Predicted label: 6, Ground truth: 12
# Predicted label: 7, Ground truth: 9
# Predicted label: 8, Ground truth: 6
# Predicted label: 7, Ground truth: 1
# Predicted label: 5, Ground truth: 0
# Predicted label: 7, Ground truth: 1
# Predicted label: 6, Ground truth: 2
# Predicted label: 12, Ground truth: 6
# Predicted label: 6, Ground truth: 8
# Predicted label: 1, Ground truth: 11
# Predicted label: 13, Ground truth: 2
# Predicted label: 7, Ground truth: 11
# Predicted label: 11, Ground truth: 7
# Predicted label: 10, Ground truth: 2
# Predicted label: 6, Ground truth: 4
# Predicted label: 5, Ground truth: 4
# Predicted label: 11, Ground truth: 3
# Predicted label: 6, Ground truth: 12
# Predicted label: 8, Ground truth: 6
# Predicted label: 6, Ground truth: 12
# Predicted label: 11, Ground truth: 1
# Predicted label: 5, Ground truth: 11
# Predicted label: 11, Ground truth: 4
# Predicted label: 7, Ground truth: 13
# Predicted label: 6, Ground truth: 10
# Predicted label: 6, Ground truth: 12
# Predicted label: 13, Ground truth: 12
# Predicted label: 12, Ground truth: 13
# Predicted label: 0, Ground truth: 12
# Predicted label: 9, Ground truth: 6
# Predicted label: 13, Ground truth: 9
# Predicted label: 12, Ground truth: 11
# Predicted label: 1, Ground truth: 0
# Predicted label: 2, Ground truth: 10
# Predicted label: 6, Ground truth: 10
# Predicted label: 6, Ground truth: 0
# Predicted label: 6, Ground truth: 4
# Predicted label: 6, Ground truth: 4
# Predicted label: 11, Ground truth: 3
# Predicted label: 0, Ground truth: 10
# Predicted label: 7, Ground truth: 13
# Predicted label: 4, Ground truth: 6
# Predicted label: 4, Ground truth: 0
# Predicted label: 3, Ground truth: 11
# Predicted label: 7, Ground truth: 9
# Predicted label: 9, Ground truth: 7
# Predicted label: 2, Ground truth: 12
# Predicted label: 6, Ground truth: 10
# Predicted label: 6, Ground truth: 9
# Predicted label: 6, Ground truth: 12
# Predicted label: 4, Ground truth: 6
# Predicted label: 3, Ground truth: 2
# Predicted label: 3, Ground truth: 13
# Predicted label: 7, Ground truth: 11
# Predicted label: 0, Ground truth: 1
# Predicted label: 6, Ground truth: 8
# Predicted label: 6, Ground truth: 2
# Predicted label: 9, Ground truth: 13
# Predicted label: 6, Ground truth: 4
# Predicted label: 2, Ground truth: 10
# Predicted label: 4, Ground truth: 0
# Predicted label: 12, Ground truth: 6
# Predicted label: 0, Ground truth: 6
# Predicted label: 6, Ground truth: 10
# Predicted label: 7, Ground truth: 13
# Predicted label: 12, Ground truth: 13
# Predicted label: 5, Ground truth: 1
# Predicted label: 5, Ground truth: 7
# Predicted label: 7, Ground truth: 5
# Predicted label: 3, Ground truth: 2
# Predicted label: 6, Ground truth: 10
# Predicted label: 7, Ground truth: 13
# Predicted label: 11, Ground truth: 1
# Predicted label: 9, Ground truth: 7
# Predicted label: 4, Ground truth: 10
# Predicted label: 13, Ground truth: 12
# Predicted label: 7, Ground truth: 10
# Predicted label: 4, Ground truth: 0
# Predicted label: 1, Ground truth: 7
# Predicted label: 2, Ground truth: 10
# Predicted label: 5, Ground truth: 7
# Predicted label: 6, Ground truth: 12
# Predicted label: 10, Ground truth: 2
# Predicted label: 2, Ground truth: 10
# Predicted label: 5, Ground truth: 1
# Predicted label: 7, Ground truth: 5
# Predicted label: 6, Ground truth: 12
# Predicted label: 11, Ground truth: 3
# Predicted label: 8, Ground truth: 12
# Predicted label: 6, Ground truth: 4
# Predicted label: 6, Ground truth: 8
# Predicted label: 13, Ground truth: 7
# Predicted label: 10, Ground truth: 2
# Predicted label: 1, Ground truth: 5
# Predicted label: 2, Ground truth: 4
# Predicted label: 0, Ground truth: 1
# Predicted label: 6, Ground truth: 12
# Predicted label: 12, Ground truth: 6
# Predicted label: 3, Ground truth: 13
# Predicted label: 12, Ground truth: 6
# Predicted label: 0, Ground truth: 1
# Predicted label: 7, Ground truth: 3
# Predicted label: 0, Ground truth: 6
# Predicted label: 13, Ground truth: 12
# Predicted label: 11, Ground truth: 3
# Predicted label: 4, Ground truth: 0
# Predicted label: 12, Ground truth: 8
# Predicted label: 7, Ground truth: 9
# Predicted label: 7, Ground truth: 5
# Predicted label: 6, Ground truth: 8
# Predicted label: 12, Ground truth: 6
# Predicted label: 0, Ground truth: 4
# Predicted label: 6, Ground truth: 12
# Predicted label: 9, Ground truth: 5
# Predicted label: 7, Ground truth: 3
# Predicted label: 1, Ground truth: 5
# Predicted label: 9, Ground truth: 8
# Predicted label: 13, Ground truth: 7
# Predicted label: 11, Ground truth: 3
# Predicted label: 1, Ground truth: 0
# Predicted label: 0, Ground truth: 6
# Predicted label: 2, Ground truth: 12
# Predicted label: 9, Ground truth: 13
# Predicted label: 7, Ground truth: 9
# Predicted label: 6, Ground truth: 4
# Predicted label: 12, Ground truth: 13
# Predicted label: 4, Ground truth: 2
# Predicted label: 5, Ground truth: 7
# Predicted label: 11, Ground truth: 2
# Predicted label: 11, Ground truth: 13
# Predicted label: 12, Ground truth: 6
# Predicted label: 1, Ground truth: 0
# Predicted label: 7, Ground truth: 9
# Predicted label: 4, Ground truth: 10
# Predicted label: 12, Ground truth: 8
# Predicted label: 9, Ground truth: 5
# Predicted label: 5, Ground truth: 7
# Predicted label: 6, Ground truth: 12
# Predicted label: 9, Ground truth: 13
# Predicted label: 2, Ground truth: 10
# Predicted label: 3, Ground truth: 11
# Predicted label: 12, Ground truth: 4
# Predicted label: 2, Ground truth: 10
# Predicted label: 6, Ground truth: 5
# Predicted label: 13, Ground truth: 9
# Predicted label: 7, Ground truth: 11
# Predicted label: 3, Ground truth: 2
# Predicted label: 11, Ground truth: 10
# Predicted label: 2, Ground truth: 10
# Predicted label: 7, Ground truth: 1
# Predicted label: 10, Ground truth: 2
# Predicted label: 3, Ground truth: 11
# Predicted label: 13, Ground truth: 7
# Predicted label: 12, Ground truth: 8
# Predicted label: 2, Ground truth: 8
# Predicted label: 8, Ground truth: 4
# Predicted label: 3, Ground truth: 10
# Predicted label: 9, Ground truth: 1
# Predicted label: 7, Ground truth: 3
# Predicted label: 1, Ground truth: 4
# Predicted label: 12, Ground truth: 6
# Predicted label: 11, Ground truth: 3
# Predicted label: 13, Ground truth: 9
# Predicted label: 12, Ground truth: 6
# Predicted label: 13, Ground truth: 7
# Predicted label: 11, Ground truth: 3
# Predicted label: 4, Ground truth: 6
# Predicted label: 3, Ground truth: 11
# Predicted label: 6, Ground truth: 7
# Predicted label: 6, Ground truth: 10
# Predicted label: 4, Ground truth: 6
# Predicted label: 8, Ground truth: 12
# Predicted label: 2, Ground truth: 11
# Predicted label: 7, Ground truth: 13
# Predicted label: 13, Ground truth: 3
# Predicted label: 13, Ground truth: 9
# Predicted label: 9, Ground truth: 13
# Predicted label: 12, Ground truth: 13
# Predicted label: 13, Ground truth: 7
# Predicted label: 7, Ground truth: 5
# Predicted label: 6, Ground truth: 10
# Predicted label: 9, Ground truth: 13
# Predicted label: 7, Ground truth: 11
# Predicted label: 2, Ground truth: 10
# Predicted label: 8, Ground truth: 6
# Predicted label: 8, Ground truth: 12
# Predicted label: 7, Ground truth: 10
# Predicted label: 13, Ground truth: 9
# Predicted label: 11, Ground truth: 3
# Predicted label: 13, Ground truth: 5
# Predicted label: 6, Ground truth: 0
# Predicted label: 6, Ground truth: 12
# Predicted label: 2, Ground truth: 10
# Predicted label: 12, Ground truth: 6
# Predicted label: 2, Ground truth: 4
# Predicted label: 3, Ground truth: 13
# Predicted label: 7, Ground truth: 11
# Predicted label: 7, Ground truth: 9
# Predicted label: 0, Ground truth: 4
# Predicted label: 6, Ground truth: 8
# Predicted label: 11, Ground truth: 7
# Predicted label: 6, Ground truth: 8
# Predicted label: 13, Ground truth: 5
# Predicted label: 8, Ground truth: 4
# Predicted label: 6, Ground truth: 2
# Predicted label: 12, Ground truth: 10
# Predicted label: 6, Ground truth: 12
# Predicted label: 8, Ground truth: 6
# Predicted label: 5, Ground truth: 4
# Predicted label: 13, Ground truth: 2
# Predicted label: 0, Ground truth: 6
# Predicted label: 6, Ground truth: 10
# Predicted label: 10, Ground truth: 6
# Predicted label: 6, Ground truth: 2
# Predicted label: 11, Ground truth: 13
# Predicted label: 12, Ground truth: 10
# Predicted label: 7, Ground truth: 5
# Predicted label: 13, Ground truth: 5
# Predicted label: 9, Ground truth: 8
# Predicted label: 6, Ground truth: 12
# Predicted label: 2, Ground truth: 3
# Predicted label: 9, Ground truth: 5
# Predicted label: 2, Ground truth: 10
# Predicted label: 13, Ground truth: 9
# Predicted label: 2, Ground truth: 10
# Predicted label: 7, Ground truth: 5
# Predicted label: 5, Ground truth: 1
# Predicted label: 6, Ground truth: 13
# Predicted label: 9, Ground truth: 12
# Predicted label: 5, Ground truth: 1
# Predicted label: 11, Ground truth: 1
# Predicted label: 12, Ground truth: 8
# Predicted label: 9, Ground truth: 12
# Predicted label: 2, Ground truth: 6
# Predicted label: 9, Ground truth: 13
# Predicted label: 5, Ground truth: 7
# Predicted label: 2, Ground truth: 10
# Predicted label: 1, Ground truth: 0
# Predicted label: 7, Ground truth: 1
# Predicted label: 9, Ground truth: 4
# Predicted label: 4, Ground truth: 6
# Predicted label: 13, Ground truth: 9
# Predicted label: 8, Ground truth: 6
# Predicted label: 7, Ground truth: 0
# Predicted label: 0, Ground truth: 1
# Predicted label: 1, Ground truth: 7
# Predicted label: 4, Ground truth: 2
# Predicted label: 7, Ground truth: 8
# Predicted label: 10, Ground truth: 11
# Predicted label: 5, Ground truth: 1
# Predicted label: 7, Ground truth: 5
# Predicted label: 6, Ground truth: 12
# Predicted label: 5, Ground truth: 11
# Predicted label: 12, Ground truth: 9
# Predicted label: 5, Ground truth: 7
# Predicted label: 7, Ground truth: 9
# Predicted label: 11, Ground truth: 10
# Predicted label: 7, Ground truth: 13
# Predicted label: 12, Ground truth: 4
# Predicted label: 1, Ground truth: 11
# Predicted label: 0, Ground truth: 10
# Predicted label: 11, Ground truth: 1
# Predicted label: 0, Ground truth: 1
# Predicted label: 11, Ground truth: 3
# Predicted label: 12, Ground truth: 6
# Predicted label: 8, Ground truth: 12
# Predicted label: 13, Ground truth: 12
# Predicted label: 12, Ground truth: 6
# Predicted label: 6, Ground truth: 12
# Predicted label: 11, Ground truth: 13
# Predicted label: 11, Ground truth: 3
# Predicted label: 6, Ground truth: 4
# Predicted label: 10, Ground truth: 3
# Predicted label: 13, Ground truth: 7
# Predicted label: 2, Ground truth: 10
# Predicted label: 7, Ground truth: 9
# Predicted label: 10, Ground truth: 3
# Predicted label: 6, Ground truth: 0
# Predicted label: 3, Ground truth: 11
# Predicted label: 12, Ground truth: 10
# Predicted label: 1, Ground truth: 11
# Predicted label: 6, Ground truth: 4
# Predicted label: 4, Ground truth: 8
# Predicted label: 12, Ground truth: 2
# Predicted label: 9, Ground truth: 3
# Predicted label: 6, Ground truth: 4
# Predicted label: 7, Ground truth: 1
# Predicted label: 10, Ground truth: 2
# Predicted label: 11, Ground truth: 3
# Predicted label: 1, Ground truth: 7
# Predicted label: 9, Ground truth: 13
# Predicted label: 5, Ground truth: 1
# Predicted label: 7, Ground truth: 9
# Predicted label: 12, Ground truth: 8
# Predicted label: 13, Ground truth: 12
# Predicted label: 7, Ground truth: 13
# Predicted label: 10, Ground truth: 3
# Predicting... 3000/10954
# Predicted label: 7, Ground truth: 5
# Predicted label: 2, Ground truth: 10
# Predicted label: 9, Ground truth: 13
# Predicted label: 9, Ground truth: 13
# Predicted label: 5, Ground truth: 4
# Predicted label: 6, Ground truth: 12
# Predicted label: 9, Ground truth: 13
# Predicted label: 6, Ground truth: 12
# Predicted label: 12, Ground truth: 8
# Predicted label: 6, Ground truth: 13
# Predicted label: 5, Ground truth: 4
# Predicted label: 7, Ground truth: 5
# Predicted label: 1, Ground truth: 5
# Predicted label: 12, Ground truth: 13
# Predicted label: 2, Ground truth: 3
# Predicted label: 3, Ground truth: 7
# Predicted label: 9, Ground truth: 7
# Predicted label: 7, Ground truth: 5
# Predicted label: 7, Ground truth: 11
# Predicted label: 10, Ground truth: 2
# Predicted label: 2, Ground truth: 10
# Predicted label: 13, Ground truth: 9
# Predicted label: 7, Ground truth: 5
# Predicted label: 6, Ground truth: 2
# Predicted label: 7, Ground truth: 11
# Predicted label: 5, Ground truth: 3
# Predicted label: 6, Ground truth: 0
# Predicted label: 11, Ground truth: 7
# Predicted label: 10, Ground truth: 7
# Predicted label: 7, Ground truth: 1
# Predicted label: 7, Ground truth: 1
# Predicted label: 13, Ground truth: 12
# Predicted label: 10, Ground truth: 12
# Predicted label: 3, Ground truth: 11
# Predicted label: 2, Ground truth: 10
# Predicted label: 0, Ground truth: 8
# Predicted label: 3, Ground truth: 2
# Predicted label: 9, Ground truth: 11
# Predicted label: 11, Ground truth: 7
# Predicted label: 6, Ground truth: 4
# Predicted label: 5, Ground truth: 13
# Predicted label: 4, Ground truth: 6
# Predicted label: 10, Ground truth: 4
# Predicted label: 1, Ground truth: 5
# Predicted label: 11, Ground truth: 5
# Predicted label: 7, Ground truth: 4
# Predicted label: 7, Ground truth: 5
# Predicted label: 12, Ground truth: 8
# Predicted label: 13, Ground truth: 6
# Predicted label: 1, Ground truth: 5
# Predicted label: 11, Ground truth: 7
# Predicted label: 7, Ground truth: 13
# Predicted label: 2, Ground truth: 10
# Predicted label: 9, Ground truth: 13
# Predicted label: 6, Ground truth: 4
# Predicted label: 11, Ground truth: 3
# Predicted label: 7, Ground truth: 3
# Predicted label: 12, Ground truth: 13
# Predicted label: 2, Ground truth: 3
# Predicted label: 2, Ground truth: 10
# Predicted label: 0, Ground truth: 1
# Predicted label: 3, Ground truth: 11
# Predicted label: 12, Ground truth: 13
# Predicted label: 6, Ground truth: 0
# Predicted label: 13, Ground truth: 12
# Predicted label: 6, Ground truth: 0
# Predicted label: 7, Ground truth: 0
# Predicted label: 9, Ground truth: 13
# Predicted label: 7, Ground truth: 1
# Predicted label: 12, Ground truth: 8
# Predicted label: 6, Ground truth: 4
# Predicted label: 9, Ground truth: 13
# Predicted label: 2, Ground truth: 10
# Predicted label: 2, Ground truth: 10
# Predicted label: 12, Ground truth: 6
# Predicted label: 6, Ground truth: 8
# Predicted label: 11, Ground truth: 3
# Predicted label: 11, Ground truth: 3
# Predicted label: 9, Ground truth: 13
# Predicted label: 4, Ground truth: 6
# Predicted label: 1, Ground truth: 5
# Predicted label: 3, Ground truth: 11
# Predicted label: 6, Ground truth: 4
# Predicted label: 11, Ground truth: 7
# Predicted label: 13, Ground truth: 9
# Predicted label: 2, Ground truth: 10
# Predicted label: 2, Ground truth: 10
# Predicted label: 6, Ground truth: 0
# Predicted label: 6, Ground truth: 12
# Predicted label: 7, Ground truth: 11
# ...
# Predicted label: 6, Ground truth: 0
# Predicted label: 9, Ground truth: 7
# Predicted label: 2, Ground truth: 8
# Predicted label: 11, Ground truth: 3
# Predicted label: 3, Ground truth: 11
# Predicted label: 8, Ground truth: 12
# Predicted label: 13, Ground truth: 9
# Predicted label: 1, Ground truth: 0
# Predicted label: 4, Ground truth: 6
# Predicted label: 5, Ground truth: 7
# Predicted label: 10, Ground truth: 6
# Predicted label: 6, Ground truth: 7
# Predicted label: 9, Ground truth: 13
# Predicted label: 7, Ground truth: 5
# Predicted label: 7, Ground truth: 1
# Predicted label: 7, Ground truth: 13
# Predicted label: 0, Ground truth: 6
# Predicted label: 8, Ground truth: 4
# Predicted label: 8, Ground truth: 12
# Predicted label: 2, Ground truth: 11
# Predicted label: 8, Ground truth: 9
# Predicted label: 7, Ground truth: 13
# Predicted label: 7, Ground truth: 13
# Predicted label: 13, Ground truth: 9
# Predicted label: 11, Ground truth: 3
# Predicted label: 13, Ground truth: 12
# Predicted label: 6, Ground truth: 12
# Predicted label: 3, Ground truth: 11
# Predicted label: 7, Ground truth: 0
# Predicted label: 13, Ground truth: 7
# Predicted label: 12, Ground truth: 6
# Predicted label: 3, Ground truth: 7
# Predicted label: 8, Ground truth: 6
# Predicted label: 9, Ground truth: 7
# Predicted label: 5, Ground truth: 9
# Predicted label: 4, Ground truth: 0
# Predicted label: 13, Ground truth: 7
# Predicted label: 8, Ground truth: 4
# Predicted label: 11, Ground truth: 3
# Predicted label: 6, Ground truth: 12
# Predicted label: 6, Ground truth: 12
# Predicted label: 9, Ground truth: 13
# Predicted label: 1, Ground truth: 0
# Predicted label: 10, Ground truth: 6
# Predicted label: 5, Ground truth: 1
# Predicted label: 9, Ground truth: 4
# Predicted label: 9, Ground truth: 13
# Predicted label: 13, Ground truth: 9
# Predicted label: 2, Ground truth: 10
# Predicted label: 5, Ground truth: 7
# Predicted label: 7, Ground truth: 1
# Predicted label: 0, Ground truth: 1
# Predicted label: 3, Ground truth: 2
# Predicted label: 6, Ground truth: 0
# Predicted label: 6, Ground truth: 12
# Predicting... 10000/10954
# Predicted label: 3, Ground truth: 11
# Predicted label: 6, Ground truth: 12
# Predicted label: 10, Ground truth: 6
# Predicted label: 13, Ground truth: 9
# Predicted label: 1, Ground truth: 0
# Predicted label: 7, Ground truth: 4
# Predicted label: 6, Ground truth: 12
# Predicted label: 13, Ground truth: 7
# Predicted label: 11, Ground truth: 10
# Predicted label: 11, Ground truth: 13
# Predicted label: 12, Ground truth: 6
# Predicted label: 8, Ground truth: 12
# Predicted label: 2, Ground truth: 10
# Predicted label: 7, Ground truth: 13
# Predicted label: 1, Ground truth: 0
# Predicted label: 0, Ground truth: 1
# Predicted label: 13, Ground truth: 7
# Predicted label: 5, Ground truth: 7
# Predicted label: 11, Ground truth: 7
# Predicted label: 3, Ground truth: 11
# Predicted label: 3, Ground truth: 11
# Predicted label: 8, Ground truth: 12
# Predicted label: 11, Ground truth: 3
# Predicted label: 4, Ground truth: 8
# Predicted label: 11, Ground truth: 5
# Predicted label: 13, Ground truth: 12
# Predicted label: 11, Ground truth: 5
# Predicted label: 11, Ground truth: 3
# Predicted label: 3, Ground truth: 2
# Predicted label: 6, Ground truth: 12
# Predicted label: 0, Ground truth: 1
# Predicted label: 6, Ground truth: 12
# Predicted label: 8, Ground truth: 2
# Predicted label: 1, Ground truth: 11
# Predicted label: 1, Ground truth: 5
# Predicted label: 13, Ground truth: 5
# Predicted label: 12, Ground truth: 13
# Predicted label: 12, Ground truth: 6
# Predicted label: 2, Ground truth: 6
# Predicted label: 7, Ground truth: 12
# Predicted label: 6, Ground truth: 12
# Predicted label: 5, Ground truth: 8
# Predicted label: 1, Ground truth: 0
# Predicted label: 10, Ground truth: 2
# Predicted label: 6, Ground truth: 10
# Predicted label: 5, Ground truth: 1
# Predicted label: 6, Ground truth: 8
# Predicted label: 7, Ground truth: 0
# Predicted label: 6, Ground truth: 4
# Predicted label: 9, Ground truth: 7
# Predicted label: 6, Ground truth: 4
# Predicted label: 5, Ground truth: 11
# Predicted label: 5, Ground truth: 9
# Predicted label: 7, Ground truth: 5
# Predicted label: 2, Ground truth: 10
# Predicted label: 7, Ground truth: 13
# Predicted label: 12, Ground truth: 4
# Predicted label: 9, Ground truth: 13
# Predicted label: 11, Ground truth: 3
# Predicted label: 7, Ground truth: 1
# Predicted label: 4, Ground truth: 6
# Predicted label: 10, Ground truth: 2
# Predicted label: 9, Ground truth: 7
# Predicted label: 10, Ground truth: 4
# Predicted label: 6, Ground truth: 10
# Predicted label: 6, Ground truth: 11
# Predicted label: 5, Ground truth: 1
# Predicted label: 2, Ground truth: 10
# Predicted label: 10, Ground truth: 5
# Predicted label: 5, Ground truth: 1
# Predicted label: 8, Ground truth: 4
# Predicted label: 7, Ground truth: 12
# Predicted label: 6, Ground truth: 12
# Predicted label: 6, Ground truth: 8
# Predicted label: 4, Ground truth: 12
# Predicted label: 6, Ground truth: 12
# Predicted label: 13, Ground truth: 7
# Predicted label: 11, Ground truth: 3
# Predicted label: 1, Ground truth: 0
# Predicted label: 3, Ground truth: 0
# Predicted label: 4, Ground truth: 10
# Predicted label: 5, Ground truth: 7
# Predicted label: 3, Ground truth: 2
# Predicted label: 12, Ground truth: 6
# Predicted label: 9, Ground truth: 13
# Predicted label: 13, Ground truth: 9
# Predicted label: 2, Ground truth: 10
# Predicted label: 3, Ground truth: 11
# Predicted label: 1, Ground truth: 0
# Predicted label: 6, Ground truth: 0
# Predicted label: 3, Ground truth: 11
# Predicted label: 3, Ground truth: 11
# Predicted label: 11, Ground truth: 3
# Predicted label: 8, Ground truth: 6
# Predicted label: 7, Ground truth: 5
# Predicted label: 7, Ground truth: 13
# Predicted label: 10, Ground truth: 2
# Predicted label: 7, Ground truth: 9
# Predicted label: 7, Ground truth: 6
# Predicted label: 12, Ground truth: 8
# Predicted label: 3, Ground truth: 11
# Predicted label: 6, Ground truth: 12
# Predicted label: 3, Ground truth: 11
# Predicted label: 2, Ground truth: 3
# Predicted label: 7, Ground truth: 3
# Predicted label: 7, Ground truth: 1
# Predicted label: 2, Ground truth: 6
# Predicted label: 13, Ground truth: 6
# Predicted label: 12, Ground truth: 6
# Predicted label: 12, Ground truth: 7
# Predicted label: 2, Ground truth: 3
# Predicted label: 12, Ground truth: 6
# Predicted label: 11, Ground truth: 3
# Predicted label: 12, Ground truth: 8
# Predicted label: 2, Ground truth: 10
# Predicted label: 6, Ground truth: 2
# Predicted label: 2, Ground truth: 10
# Predicted label: 12, Ground truth: 8
# Predicted label: 6, Ground truth: 7
# Predicted label: 2, Ground truth: 3
# Predicted label: 7, Ground truth: 3
# Predicted label: 7, Ground truth: 9
# Predicted label: 12, Ground truth: 6
# Predicted label: 7, Ground truth: 5
# Predicted label: 6, Ground truth: 4
# Predicted label: 7, Ground truth: 13
# Predicted label: 6, Ground truth: 11
# Predicted label: 6, Ground truth: 12
# Predicted label: 13, Ground truth: 2
# Predicted label: 6, Ground truth: 4
# Predicted label: 1, Ground truth: 0
# Predicted label: 6, Ground truth: 4
# Predicted label: 2, Ground truth: 10
# Predicted label: 11, Ground truth: 5
# Predicted label: 3, Ground truth: 11
# Predicted label: 6, Ground truth: 12
# Predicted label: 8, Ground truth: 12
# Predicted label: 5, Ground truth: 4
# Predicted label: 2, Ground truth: 3
# Predicted label: 5, Ground truth: 7
# Predicted label: 9, Ground truth: 13
# Predicted label: 13, Ground truth: 3
# Predicted label: 5, Ground truth: 4
# Predicted label: 0, Ground truth: 10
# Predicted label: 9, Ground truth: 13
# Predicted label: 12, Ground truth: 6
# Predicted label: 3, Ground truth: 11
# Predicted label: 4, Ground truth: 10
# Predicted label: 7, Ground truth: 13
# Predicted label: 10, Ground truth: 0
# Predicted label: 9, Ground truth: 7
# Predicted label: 6, Ground truth: 10
# Predicted label: 1, Ground truth: 7
# Predicted label: 6, Ground truth: 8
# Predicted label: 2, Ground truth: 10
# Predicted label: 6, Ground truth: 12
# Predicted label: 2, Ground truth: 3
# Predicted label: 9, Ground truth: 6
# Predicted label: 8, Ground truth: 6
# Predicted label: 8, Ground truth: 6
# Predicted label: 3, Ground truth: 11
# Predicted label: 11, Ground truth: 3
# Predicted label: 1, Ground truth: 0
# Predicted label: 11, Ground truth: 7
# Predicted label: 13, Ground truth: 12
# Predicted label: 11, Ground truth: 5
# Predicted label: 7, Ground truth: 6
# Predicted label: 9, Ground truth: 13
# Predicted label: 7, Ground truth: 3
# Predicted label: 11, Ground truth: 3
# Predicted label: 8, Ground truth: 12
# Predicted label: 4, Ground truth: 10
# Predicted label: 7, Ground truth: 12
# Predicted label: 9, Ground truth: 6
# Predicted label: 9, Ground truth: 6
# Predicted label: 5, Ground truth: 7
# Predicted label: 13, Ground truth: 7
# Predicted label: 7, Ground truth: 13
# Predicted label: 4, Ground truth: 5
# Predicted label: 5, Ground truth: 9
# Predicted label: 7, Ground truth: 9
# Predicted label: 12, Ground truth: 8
# Predicted label: 0, Ground truth: 4
# Predicted label: 2, Ground truth: 10
# Predicted label: 12, Ground truth: 10
# Predicted label: 2, Ground truth: 12
# Predicted label: 4, Ground truth: 6
# Predicted label: 2, Ground truth: 10
# Predicted label: 2, Ground truth: 10
# Predicted label: 2, Ground truth: 10
# Predicted label: 5, Ground truth: 9
# Predicted label: 8, Ground truth: 12
# Predicted label: 9, Ground truth: 13
# Predicted label: 6, Ground truth: 4
# Predicted label: 11, Ground truth: 10
# Predicted label: 3, Ground truth: 11
# Predicted label: 3, Ground truth: 2
# Predicted label: 7, Ground truth: 3
# Predicted label: 6, Ground truth: 2
# Predicted label: 12, Ground truth: 6
# Predicted label: 2, Ground truth: 3
# Predicted label: 5, Ground truth: 4
# Predicted label: 7, Ground truth: 1
# Predicted label: 7, Ground truth: 13
# Predicted label: 3, Ground truth: 11
# Predicted label: 9, Ground truth: 11
# Predicted label: 9, Ground truth: 13
# Predicted label: 11, Ground truth: 3
# Predicted label: 11, Ground truth: 10
# Predicted label: 0, Ground truth: 4
# Predicted label: 2, Ground truth: 4
# Predicted label: 1, Ground truth: 0
# Predicted label: 2, Ground truth: 3
# Predicted label: 11, Ground truth: 5
# Predicted label: 5, Ground truth: 7
# Predicted label: 6, Ground truth: 8
# Predicted label: 3, Ground truth: 2
# Predicted label: 7, Ground truth: 5
# Predicted label: 6, Ground truth: 4
# Predicted label: 13, Ground truth: 12
# Predicted label: 9, Ground truth: 8
# Predicted label: 7, Ground truth: 13
# Predicted label: 11, Ground truth: 7
# Predicted label: 0, Ground truth: 2
# Predicted label: 12, Ground truth: 6
# Predicted label: 8, Ground truth: 6
# Predicted label: 11, Ground truth: 5
# Predicted label: 9, Ground truth: 13
# Predicted label: 9, Ground truth: 13
# Predicted label: 1, Ground truth: 5
# Predicted label: 11, Ground truth: 7
# Predicted label: 0, Ground truth: 1
# Predicted label: 6, Ground truth: 0
# Predicted label: 2, Ground truth: 11
# Predicted label: 3, Ground truth: 2
# Predicted label: 3, Ground truth: 11
# Predicted label: 10, Ground truth: 2
# Predicted label: 9, Ground truth: 13
# Predicted label: 13, Ground truth: 7
# Predicted label: 0, Ground truth: 1
# Predicted label: 10, Ground truth: 2
# Predicted label: 7, Ground truth: 9
# Predicted label: 5, Ground truth: 7
# Predicted label: 13, Ground truth: 7
# Predicted label: 5, Ground truth: 11
# Predicted label: 12, Ground truth: 6
# Predicted label: 9, Ground truth: 13
# Predicted label: 9, Ground truth: 7
# Predicted label: 10, Ground truth: 6
# Predicted label: 13, Ground truth: 7
# Predicted label: 8, Ground truth: 4
# Predicted label: 7, Ground truth: 0
# Predicted label: 5, Ground truth: 7
# Predicted label: 8, Ground truth: 6
# Predicted label: 7, Ground truth: 5
# Predicted label: 10, Ground truth: 2
# Predicted label: 7, Ground truth: 5
# Predicted label: 2, Ground truth: 10
# Predicted label: 1, Ground truth: 0
# Predicted label: 9, Ground truth: 5
# Predicted label: 12, Ground truth: 8
# Predicted label: 6, Ground truth: 8
# Predicted label: 7, Ground truth: 13
# Predicted label: 7, Ground truth: 9
# Predicted label: 8, Ground truth: 6
# Predicted label: 4, Ground truth: 0
# Predicted label: 3, Ground truth: 13
# Predicted label: 6, Ground truth: 12
# Predicted label: 2, Ground truth: 3
# Predicted label: 7, Ground truth: 1
# Predicted label: 11, Ground truth: 7
# Predicted label: 7, Ground truth: 5
# Predicted label: 8, Ground truth: 0
# Predicted label: 7, Ground truth: 9
# Predicted label: 7, Ground truth: 11
# Predicted label: 10, Ground truth: 6
# Predicted label: 7, Ground truth: 5
# Predicted label: 11, Ground truth: 7
# Predicted label: 11, Ground truth: 3
# Predicted label: 11, Ground truth: 1
# Predicted label: 12, Ground truth: 8
# Predicted label: 13, Ground truth: 12
# Predicted label: 10, Ground truth: 2
# Predicted label: 6, Ground truth: 4
# Predicted label: 7, Ground truth: 5
# Predicted label: 7, Ground truth: 9
# Predicted label: 0, Ground truth: 1
# Predicted label: 11, Ground truth: 7
# Predicted label: 5, Ground truth: 7
# Predicted label: 5, Ground truth: 11
# Predicted label: 9, Ground truth: 13
# Predicted label: 13, Ground truth: 7
# Predicted label: 3, Ground truth: 11
# Predicted label: 7, Ground truth: 5
# Predicted label: 2, Ground truth: 11
# Predicted label: 13, Ground truth: 7
# Predicted label: 13, Ground truth: 7
# Predicted label: 12, Ground truth: 8
# Predicted label: 12, Ground truth: 13
# Predicted label: 10, Ground truth: 6
# Predicted label: 6, Ground truth: 13
# Predicted label: 7, Ground truth: 5
# Predicted label: 12, Ground truth: 6
# Predicted label: 9, Ground truth: 5
# Predicted label: 6, Ground truth: 4
# Predicted label: 10, Ground truth: 2
# Predicted label: 10, Ground truth: 6
# Predicted label: 6, Ground truth: 4
# Predicted label: 2, Ground truth: 10
# Predicted label: 12, Ground truth: 6
# Predicted label: 11, Ground truth: 3
# Predicted label: 13, Ground truth: 2
# Predicted label: 12, Ground truth: 13
# Predicted label: 0, Ground truth: 1
# Predicted label: 12, Ground truth: 13
# Predicted label: 1, Ground truth: 0
# Predicted label: 10, Ground truth: 0
# Predicted label: 13, Ground truth: 7
# Predicted label: 5, Ground truth: 11
# Predicted label: 6, Ground truth: 8
# Predicted label: 2, Ground truth: 10
# Predicted label: 6, Ground truth: 12
# Predicted label: 6, Ground truth: 2
# Predicted label: 12, Ground truth: 6
# Predicted label: 7, Ground truth: 3
# Predicted label: 11, Ground truth: 3
# Predicted label: 9, Ground truth: 13
# Predicted label: 11, Ground truth: 3
# Predicted label: 7, Ground truth: 1
# Predicted label: 7, Ground truth: 13
# Predicted label: 0, Ground truth: 11
# Predicted label: 9, Ground truth: 5
# Predicted label: 12, Ground truth: 6
# Predicted label: 12, Ground truth: 8
# Predicted label: 3, Ground truth: 10
# Predicted label: 3, Ground truth: 5
# Predicted label: 8, Ground truth: 2
# Predicted label: 6, Ground truth: 8
# Predicted label: 13, Ground truth: 7
# Predicted label: 9, Ground truth: 13
# Predicted label: 9, Ground truth: 13
# Predicted label: 0, Ground truth: 6
# Predicted label: 11, Ground truth: 5
# Predicted label: 12, Ground truth: 13
# Predicted label: 9, Ground truth: 0
# Predicted label: 1, Ground truth: 7
# Predicted label: 13, Ground truth: 7
# Predicted label: 7, Ground truth: 11
# Predicted label: 5, Ground truth: 11
# Predicted label: 9, Ground truth: 13
# Predicted label: 7, Ground truth: 13
# Predicted label: 12, Ground truth: 0
# Predicted label: 13, Ground truth: 5
# Predicted label: 2, Ground truth: 10
# Predicted label: 13, Ground truth: 9
# Predicted label: 7, Ground truth: 13
# Predicted label: 5, Ground truth: 0
# Predicted label: 10, Ground truth: 2
# Predicted label: 0, Ground truth: 1
# Predicted label: 13, Ground truth: 9
# Predicted label: 12, Ground truth: 13
# Predicted label: 5, Ground truth: 7
# Predicted label: 8, Ground truth: 6
# Predicted label: 11, Ground truth: 10
# Predicted label: 1, Ground truth: 7
# Predicted label: 3, Ground truth: 2
# Predicted label: 1, Ground truth: 0
# Predicted label: 7, Ground truth: 6
# Predicted label: 3, Ground truth: 11
# Predicted label: 7, Ground truth: 13
# Predicted label: 2, Ground truth: 10
# Predicted label: 9, Ground truth: 7
# Predicted label: 11, Ground truth: 13
# Predicted label: 10, Ground truth: 8
# Predicted label: 6, Ground truth: 12
# Predicted label: 6, Ground truth: 12
# Predicted label: 6, Ground truth: 4
# Predicted label: 12, Ground truth: 8
# Predicted label: 7, Ground truth: 3
# Predicted label: 8, Ground truth: 6
# Predicted label: 7, Ground truth: 9

# %%
# Print the overall accuracy and accuracy for each class
print('size of test set: {}, accuracy of the network on the test set: {:.2f}%'.format(total, 100 * correct / total))
for i in range(14):
    print('Accuracy of {} : {:.0f}% of {} images'.format(classes[i], 100 * class_correct[i] / class_total[i], class_total[i]))
print("miss_predicated_images num = {}".format(len(miss_predicated_images)))
# Out:
# size of test set: 10954, accuracy of the network on the test set: 60.95%
# Accuracy of Black+Female : 66% of 757 images
# Accuracy of Black+Male : 69% of 799 images
# Accuracy of East Asian+Female : 67% of 773 images
# Accuracy of East Asian+Male : 67% of 777 images
# Accuracy of Indian+Female : 63% of 763 images
# Accuracy of Indian+Male : 60% of 753 images
# Accuracy of Latino_Hispanic+Female : 56% of 830 images
# Accuracy of Latino_Hispanic+Male : 53% of 793 images
# Accuracy of Middle Eastern+Female : 44% of 396 images
# Accuracy of Middle Eastern+Male : 68% of 813 images
# Accuracy of Southeast Asian+Female : 50% of 680 images
# Accuracy of Southeast Asian+Male : 53% of 735 images
# Accuracy of White+Female : 62% of 963 images
# Accuracy of White+Male : 64% of 1122 images
# miss_predicated_images num = 4277

# %%
print(len(activation_all_images))
# print(len(activation_all_images[0]))
# print(len(activation_all_images[0]["features.22"][0]))
hooked_layer_names = list(activation.keys())
print(hooked_layer_names)
print(len(filtersum_all_images[0]))
print((filtersum_all_images[0]))
# Out:
# 0
# ['relu', 'layer1.0.relu', 'layer1.1.relu', 'layer1.2.relu', 'layer2.0.relu', 'layer2.1.relu', 'layer2.2.relu', 'layer2.3.relu', 'layer3.0.relu', 'layer3.1.relu', 'layer3.2.relu', 'layer3.3.relu', 'layer3.4.relu', 'layer3.5.relu', 'layer4.0.relu', 'layer4.1.relu', 'layer4.2.relu']
# 17
# {'relu': [6741.3779296875, 2228.13720703125, 3390.545166015625, 4626.53515625, 1899.7640380859375, 3133.94677734375, 2065.015869140625, 12400.11328125, 6724.4052734375, 431.55633544921875, 3798.7978515625, 4221.84375, 814.5844116210938, 3130.087646484375, 2570.236083984375, 0.0, 0.0, 2575.138916015625, 2477.33349609375, 142.23480224609375, 4471.009765625, 3416.791259765625, 2827.178955078125, 595.7044067382812, 4131.8505859375, 2707.04052734375, 7687.912109375, 8638.619140625, 4686.4140625, 3270.9697265625, 6459.30908203125, 0.0, 2991.602294921875, 5599.169921875, 299.9684753417969, 0.0, 5159.8115234375, 3559.759521484375, 9265.3359375, 2121.8447265625, 3827.17431640625, 0.0, 2857.25439453125, 657.445556640625, 3089.896728515625, 49.850196838378906, 0.0, 0.0, 301.493408203125, 0.0, 1100.2808837890625, 2892.520263671875, 4582.91015625, 6672.9677734375, 3108.13916015625, 7513.0478515625, 3703.95556640625, 0.0, 6540.94287109375, 3221.269287109375, 0.03798429295420647, 2646.63037109375, 7727.08056640625, 0.0], 'layer1.0.relu': [1390.1865234375, 1483.1519775390625, 1932.9609375, 1533.0963134765625, 869.72216796875, 1316.324462890625, 853.5774536132812, 3409.05126953125, 1439.8497314453125, 664.9027709960938, 1273.824462890625, 1675.3677978515625, 679.8177490234375, 2074.68701171875, 1489.409423828125, 630.305908203125, 276.34576416015625, 728.1206665039062, 1855.6259765625, 107.66488647460938, 1608.194091796875, 2166.8701171875, 1275.104248046875, 30.56754493713379, 1344.8896484375, 490.2420654296875, 2569.167236328125, 2167.6875, 1860.064453125, 1194.5216064453125, 1478.64990234375, 1506.24365234375, 820.5455322265625, 973.41455078125, 817.83935546875, 400.93072509765625, 1438.03759765625, 1690.486328125, 2398.000732421875, 468.57720947265625, 1675.766845703125, 348.025146484375, 1670.2515869140625, 566.9802856445312, 2195.77001953125, 29.931886672973633, 542.354736328125, 486.32513427734375, 101.18562316894531, 929.7932739257812, 388.47076416015625, 1432.425048828125, 2210.354248046875, 2011.9912109375, 1094.527099609375, 2245.6337890625, 2036.786865234375, 236.4308319091797, 2028.3758544921875, 1265.28955078125, 865.9992065429688, 905.8609008789062, 3504.891357421875, 1206.1796875], 'layer1.1.relu': [1721.90234375, 1005.008544921875, 2369.781005859375, 1321.8284912109375, 1587.2164306640625, 1017.3236083984375, 1020.5606689453125, 2957.27978515625, 554.3964233398438, 551.419921875, 1065.1319580078125, 1412.394287109375, 886.2724609375, 2692.09619140625, 1290.274169921875, 1110.298828125, 976.8574829101562, 471.221435546875, 2145.622314453125, 341.71563720703125, 1515.005615234375, 2723.31982421875, 2033.1529541015625, 1006.8842163085938, 1441.0672607421875, 1075.829345703125, 2812.802734375, 2077.642578125, 1872.30419921875, 440.51812744140625, 1349.718505859375, 1628.896240234375, 823.3612060546875, 1033.855224609375, 1291.4931640625, 341.708251953125, 1658.186279296875, 1638.98291015625, 2430.518310546875, 219.97817993164062, 1884.162353515625, 1137.17041015625, 1941.5439453125, 732.72119140625, 2810.943603515625, 1043.346435546875, 1414.92626953125, 1062.595947265625, 83.97982788085938, 1557.7978515625, 638.830322265625, 982.1258544921875, 3118.0234375, 1733.0272216796875, 913.1090087890625, 2692.16015625, 2538.909423828125, 468.1690673828125, 1643.8509521484375, 765.133544921875, 1686.3790283203125, 721.3070068359375, 4717.919921875, 1541.6727294921875], 'layer1.2.relu': [1920.917236328125, 377.42230224609375, 2870.4228515625, 1578.385986328125, 1953.34521484375, 1624.266845703125, 1173.740234375, 2735.248779296875, 572.1640014648438, 493.8367919921875, 772.7081909179688, 1692.4744873046875, 1018.6685180664062, 2998.96826171875, 1215.3751220703125, 1637.54248046875, 1420.8089599609375, 425.86395263671875, 2058.326904296875, 435.60009765625, 1745.8370361328125, 2807.96337890625, 2357.115234375, 1741.32763671875, 1446.4461669921875, 2027.439453125, 3002.33056640625, 2367.27783203125, 2051.77978515625, 926.073974609375, 1441.87 ...

# %%
def save_intermediate_data(data, file_path):
    """
    Save intermediate data to a file using pickle serialization.

    Args:
        data: The data to be saved.
        file_path (str): The path of the file to save the data.
    """
    with open(file_path, 'wb') as file:
        pickle.dump(data, file)
# save intermediate results
save_intermediate_data(activation_all_images, "activation_CIFAR10_VGG16.pkl")
save_intermediate_data(image_predictation_result, "image_predictation_result.pkl")
save_intermediate_data(miss_predicated_images, "miss_predicated_images.pkl")
save_intermediate_data(hooked_layer_names, "hooked_layer_names.pkl")
save_intermediate_data(filtersum_all_images, "filtersum_all_images.pkl")
save_intermediate_data(num_filters, "num_filters.pkl")

# %%
def load_intermediate_data(file_path):
    """
    Load intermediate data from a file.

    Args:
        file_path (str): The path of the file to load the data from.

    Returns:
        The loaded data.
    """
    with open(file_path, 'rb') as file:
        data = pickle.load(file)
    return data


activation_all_images = load_intermediate_data("activation_CIFAR10_VGG16.pkl")
image_predictation_result = load_intermediate_data("image_predictation_result.pkl")
miss_predicated_images = load_intermediate_data("miss_predicated_images.pkl")
hooked_layer_names = load_intermediate_data("hooked_layer_names.pkl")
filtersum_all_images = load_intermediate_data("filtersum_all_images.pkl")
num_filters = load_intermediate_data("num_filters.pkl")

# %%
num_test_images = len(filtersum_all_images)
def find_outliers_zscore(data, threshold=1):
    """
    Find outliers in a list of values using z-score method.

    Args:
        data (list or numpy array): List of numeric values.
        threshold (float, optional): Z-score threshold for identifying outliers. Default is 3.

    Returns:
        list: List of outlier values.
    """
    # Convert data to numpy array
    data = np.array(data)
    if np.std(data) == 0:
        return []
    # Calculate z-scores
    z_scores = (data - np.mean(data)) / np.std(data)
    # Find outliers based on the threshold
    # outliers = data[np.abs(z_scores) > threshold]
    outliers = np.where(z_scores < -threshold)[0]
    return outliers

# %%
# find outlier for all mis_predicated images:
# cat (3)
class_id = 3
all_image_class = image_predictation_result[class_id].keys()
wrong_images = [x for x in all_image_class if image_predictation_result[class_id][x] != class_id]
print("num of wrong images in class {} is {}".format(class_id, len(wrong_images)))
# Out:
# num of wrong images in class 3 is 258

# %%
z_score_threshold = 1.0

for layer_name in hooked_layer_names:
    print("layer {}".format(layer_name))
    for image in wrong_images:
        # print("image # {}".format(image))
        outliers = find_outliers_zscore(filtersum_all_images[image][layer_name], threshold=z_score_threshold)
        if len(outliers) > 0:
            print("image # {}, layer # {} has outliers {}".format(image, layer_name, outliers))
# Out:
# layer relu
# image # 3, layer # relu has outliers [ 4 12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 19, layer # relu has outliers [ 4 12 15 16 23 31 35 41 46 47 48 49 57 60 63]
# image # 134, layer # relu has outliers [ 9 12 15 16 23 31 34 35 41 45 46 47 48 49 50 57 60 63]
# image # 171, layer # relu has outliers [15 16 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 224, layer # relu has outliers [ 4 12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 283, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 323, layer # relu has outliers [15 16 19 31 35 41 45 46 47 48 49 57 60 63]
# image # 349, layer # relu has outliers [12 15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 399, layer # relu has outliers [15 16 31 35 41 46 47 49 57 60 63]
# image # 460, layer # relu has outliers [12 15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 540, layer # relu has outliers [12 15 16 23 31 35 41 46 47 48 49 57 60 63]
# image # 551, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 579, layer # relu has outliers [12 15 16 19 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 594, layer # relu has outliers [12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 736, layer # relu has outliers [12 15 16 19 23 31 35 41 45 46 47 48 49 57 60 63]
# image # 738, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 739, layer # relu has outliers [12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 751, layer # relu has outliers [ 9 15 16 19 31 35 41 43 45 46 47 49 57 60 63]
# image # 762, layer # relu has outliers [15 16 23 31 34 35 41 46 47 48 49 50 57 60 63]
# image # 780, layer # relu has outliers [12 15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 786, layer # relu has outliers [15 16 19 31 34 35 41 43 45 46 47 49 57 60 63]
# image # 818, layer # relu has outliers [15 16 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 821, layer # relu has outliers [ 9 12 15 16 19 23 31 35 41 45 46 47 48 49 57 60 63]
# image # 1134, layer # relu has outliers [15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 1176, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 1180, layer # relu has outliers [15 16 19 31 35 41 45 46 47 48 49 57 60 63]
# image # 1195, layer # relu has outliers [12 15 16 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 1207, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 1250, layer # relu has outliers [15 16 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 1285, layer # relu has outliers [15 16 19 31 34 35 41 46 47 48 49 57 60 63]
# image # 1296, layer # relu has outliers [ 9 12 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 1382, layer # relu has outliers [12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 1457, layer # relu has outliers [15 16 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 1487, layer # relu has outliers [15 16 19 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 1520, layer # relu has outliers [15 16 31 34 35 41 46 47 48 49 57 60 63]
# image # 1545, layer # relu has outliers [ 9 15 16 19 23 31 35 41 45 46 47 48 49 57 60 63]
# image # 1724, layer # relu has outliers [ 4 12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 1777, layer # relu has outliers [15 16 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 1797, layer # relu has outliers [15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 1864, layer # relu has outliers [15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 1912, layer # relu has outliers [15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 1969, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 1970, layer # relu has outliers [ 9 12 15 16 19 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 1983, layer # relu has outliers [15 16 19 31 35 41 46 47 48 49 57 60 63]
# image # 2006, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 2012, layer # relu has outliers [15 16 19 31 35 41 45 46 47 49 57 60 63]
# image # 2207, layer # relu has outliers [15 16 23 31 34 35 41 46 47 48 49 50 57 60 63]
# image # 2324, layer # relu has outliers [15 16 19 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 2456, layer # relu has outliers [12 15 16 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 2491, layer # relu has outliers [ 9 15 16 19 31 35 41 45 46 47 49 57 60 63]
# image # 2499, layer # relu has outliers [15 16 19 31 35 41 46 47 48 49 57 60 63]
# image # 2524, layer # relu has outliers [15 16 19 31 35 41 45 46 47 49 57 60 63]
# image # 2530, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 2635, layer # relu has outliers [15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 2638, layer # relu has outliers [ 9 15 16 19 23 31 34 35 41 45 46 47 48 49 50 57 60 63]
# image # 2643, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 2683, layer # relu has outliers [15 16 19 23 31 34 35 41 45 46 47 48 49 50 57 60 63]
# image # 2727, layer # relu has outliers [12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 2817, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 2919, layer # relu has outliers [15 16 19 31 35 41 46 47 48 49 57 60 63]
# image # 2931, layer # relu has outliers [ 4 12 15 16 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 2937, layer # relu has outliers [15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 2962, layer # relu has outliers [15 16 19 31 35 41 45 46 47 48 49 57 60 63]
# image # 2975, layer # relu has outliers [12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 2999, layer # relu has outliers [ 4 12 15 16 23 31 35 41 46 47 48 49 57 60 63]
# image # 3065, layer # relu has outliers [12 15 16 23 31 34 35 41 46 47 48 49 57 60 63]
# image # 3147, layer # relu has outliers [ 9 12 15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 3149, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 3155, layer # relu has outliers [15 16 31 34 35 41 46 47 48 49 57 60 63]
# image # 3187, layer # relu has outliers [15 16 19 23 31 35 41 46 47 48 49 57 60 63]
# image # 3188, layer # relu has outliers [12 15 16 19 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 3278, layer # relu has outliers [15 16 19 31 35 41 46 47 48 49 57 60 63]
# image # 3285, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 3287, layer # relu has outliers [15 16 19 31 35 41 46 47 48 49 57 60 63]
# image # 3394, layer # relu has outliers [12 15 16 31 34 35 41 46 47 48 49 57 60 63]
# image # 3395, layer # relu has outliers [15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 3507, layer # relu has outliers [15 16 19 31 35 41 45 46 47 49 57 60 63]
# image # 3643, layer # relu has outliers [12 15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 3749, layer # relu has outliers [12 15 16 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 3811, layer # relu has outliers [ 9 15 16 19 31 35 41 45 46 47 49 57 60 63]
# image # 3846, layer # relu has outliers [ 9 15 16 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 3953, layer # relu has outliers [15 16 19 31 35 41 45 46 47 48 49 57 60 63]
# image # 4002, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 4064, layer # relu has outliers [ 9 15 16 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 4078, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 4100, layer # relu has outliers [15 16 19 31 35 41 45 46 47 49 57 60 63]
# image # 4155, layer # relu has outliers [15 16 19 31 35 41 45 46 47 49 57 60 63]
# image # 4256, layer # relu has outliers [15 16 23 31 35 41 46 47 48 49 57 60 63]
# image # 4317, layer # relu has outliers [12 15 16 23 31 34 35 41 46 47 48 49 50 57 60 63]
# image # 4342, layer # relu has outliers [ 9 15 16 19 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 4365, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 4374, layer # relu has outliers [15 16 19 23 31 35 41 45 46 47 48 49 57 60 63]
# image # 4388, layer # relu has outliers [ 9 15 16 19 23 31 35 41 45 46 47 48 49 57 60 63]
# image # 4452, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 4484, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 4486, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 4509, layer # relu has outliers [12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 4533, layer # relu has outliers [12 15 16 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 4647, layer # relu has outliers [15 16 19 31 35 41 45 46 47 48 49 57 60 63]
# image # 4785, layer # relu has outliers [15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 4792, layer # relu has outliers [15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 4855, layer # relu has outliers [ 9 15 16 31 35 41 45 46 47 48 49 57 60 63]
# image # 4980, layer # relu has outliers [15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 5018, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 5049, layer # relu has outliers [12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 5193, layer # relu has outliers [15 16 23 31 34 35 41 46 47 48 49 57 60 63]
# image # 5217, layer # relu has outliers [12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 5268, layer # relu has outliers [12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 5341, layer # relu has outliers [12 15 16 19 23 31 35 41 45 46 47 48 49 57 60 63]
# image # 5392, layer # relu has outliers [ 4 12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 5434, layer # relu has outliers [15 16 19 23 31 35 41 45 46 47 48 49 57 60 63]
# image # 5490, layer # relu has outliers [15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 5504, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 5518, layer # relu has outliers [15 16 19 31 35 41 45 46 47 49 57 60 63]
# image # 5533, layer # relu has outliers [ 4 12 15 16 23 31 34 35 41 45 46 47 48 49 50 57 60 63]
# image # 5576, layer # relu has outliers [12 15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 5589, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 5615, layer # relu has outliers [15 16 23 24 31 35 41 46 47 48 49 50 57 60 63]
# image # 5619, layer # relu has outliers [ 4 12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 5633, layer # relu has outliers [15 16 19 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 5682, layer # relu has outliers [15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 5710, layer # relu has outliers [15 16 19 23 31 35 41 46 47 48 49 57 60 63]
# image # 5805, layer # relu has outliers [15 16 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 5958, layer # relu has outliers [ 9 15 16 19 31 34 35 41 43 45 46 47 49 57 60 63]
# image # 5988, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 6114, layer # relu has outliers [ 9 15 16 19 31 35 41 45 46 47 49 57 60 63]
# image # 6124, layer # relu has outliers [ 9 12 15 16 19 23 31 34 35 41 45 46 47 49 57 60 63]
# image # 6237, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 6249, layer # relu has outliers [12 15 16 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 6285, layer # relu has outliers [ 9 12 15 16 19 23 31 34 35 41 45 46 47 48 49 50 57 60 63]
# image # 6346, layer # relu has outliers [15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 6388, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 6395, layer # relu has outliers [ 9 15 16 19 31 35 41 45 46 47 48 49 57 60 63]
# image # 6426, layer # relu has outliers [ 9 12 15 16 19 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 6499, layer # relu has outliers [15 16 19 23 31 34 35 41 45 46 47 48 49 50 57 60 63]
# image # 6513, layer # relu has outliers [12 15 16 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 6600, layer # relu has outliers [ 9 12 15 16 19 23 31 35 41 45 46 47 48 49 57 60 63]
# image # 6614, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 6747, layer # relu has outliers [15 16 19 23 31 35 41 45 46 47 48 49 57 60 63]
# image # 6751, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 6820, layer # relu has outliers [ 9 15 16 19 31 35 41 43 45 46 47 48 49 57 60 63]
# image # 6824, layer # relu has outliers [15 16 19 23 31 34 35 41 45 46 47 48 49 50 57 60 63]
# image # 6908, layer # relu has outliers [15 16 31 35 41 46 47 48 49 57 60 63]
# image # 6931, layer # relu has outliers [12 15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 6964, layer # relu has outliers [15 16 19 23 31 35 41 45 46 47 48 49 57 60 63]
# image # 7055, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 7114, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 7139, layer # relu has outliers [15 16 23 31 34 35 41 45 46 47 48 49 50 57 60 63]
# image # 7164, layer # relu has outliers [15 16 19 31 35 41 46 47 49 57 60 63]
# image # 7189, layer # relu has outliers [15 16 19 31 35 41 45 46 47 48 49 57 60 63]
# image # 7190, layer # relu has outliers [12 15 16 31 35 41 46 47 48 49 57 60 63]
# image # 7232, layer # relu has outliers [15 16 19 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 7310, layer # relu has outliers [12 15 16 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 7385, layer # relu has outliers [ 9 15 16 19 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 7416, layer # relu has outliers [ 9 12 15 16 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 7504, layer # relu has outliers [15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 7515, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 7659, layer # relu has outliers [12 15 16 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 7718, layer # relu has outliers [ 9 15 16 19 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 7725, layer # relu has outliers [15 16 19 31 35 41 45 46 47 49 57 60 63]
# image # 7828, layer # relu has outliers [15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 7847, layer # relu has outliers [15 16 19 31 35 41 46 47 48 49 57 60 63]
# image # 7878, layer # relu has outliers [ 9 12 15 16 19 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 8011, layer # relu has outliers [15 16 31 34 35 41 46 47 48 49 57 60 63]
# image # 8014, layer # relu has outliers [15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 8059, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 8101, layer # relu has outliers [ 9 12 15 16 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 8122, layer # relu has outliers [ 4 12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 8161, layer # relu has outliers [ 9 15 16 19 31 35 41 43 45 46 47 49 57 60 63]
# image # 8166, layer # relu has outliers [12 15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 8174, layer # relu has outliers [12 15 16 19 23 31 34 35 41 45 46 47 48 49 50 57 60 63]
# image # 8342, layer # relu has outliers [ 9 15 16 19 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 8353, layer # relu has outliers [15 16 31 35 41 46 47 48 49 57 60 63]
# image # 8390, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 8414, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 8483, layer # relu has outliers [12 15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 8535, layer # relu has outliers [12 15 16 23 31 35 41 46 47 49 57 60 63]
# image # 8544, layer # relu has outliers [15 16 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 8576, layer # relu has outliers [15 16 19 31 35 41 45 46 47 48 49 57 60 63]
# image # 8612, layer # relu has outliers [12 15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 8670, layer # relu has outliers [12 15 16 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 8690, layer # relu has outliers [12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 8717, layer # relu has outliers [ 9 12 15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 8742, layer # relu has outliers [ 4 12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 8746, layer # relu has outliers [15 16 31 35 41 46 47 48 49 57 60 63]
# image # 8755, layer # relu has outliers [ 9 15 16 19 31 35 41 45 46 47 49 57 60 63]
# image # 8760, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 8800, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 8882, layer # relu has outliers [12 15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 8909, layer # relu has outliers [ 9 15 16 19 23 31 34 35 41 45 46 47 48 49 50 57 60 63]
# image # 8933, layer # relu has outliers [15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 9102, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 9111, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 9173, layer # relu has outliers [15 16 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 9208, layer # relu has outliers [15 16 19 31 35 41 45 46 47 48 49 57 60 63]
# image # 9287, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 9320, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 9334, layer # relu has outliers [ 4 12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 9339, layer # relu has outliers [ 4 12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 9388, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 9398, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 9544, layer # relu has outliers [12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 9585, layer # relu has outliers [12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 9611, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 9655, layer # relu has outliers [15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 9690, layer # relu has outliers [12 15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 9716, layer # relu has outliers [15 16 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 9721, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 9774, layer # relu has outliers [15 16 19 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 9807, layer # relu has outliers [15 16 19 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 9870, layer # relu has outliers [12 15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 9914, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 9952, layer # relu has outliers [15 16 31 35 41 46 47 48 49 50 57 60 63]
# image # 10053, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 10063, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 10144, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 10193, layer # relu has outliers [15 16 19 31 35 41 45 46 47 48 49 57 60 63]
# image # 10225, layer # relu has outliers [ 9 15 16 19 31 35 41 45 46 47 49 57 60 63]
# image # 10257, layer # relu has outliers [ 4 12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 10259, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 10269, layer # relu has outliers [ 9 12 15 16 19 23 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 10274, layer # relu has outliers [12 15 16 23 31 35 41 45 46 47 48 49 57 60 63]
# image # 10296, layer # relu has outliers [12 15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 10297, layer # relu has outliers [15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 10338, layer # relu has outliers [15 16 31 35 41 45 46 47 48 49 57 60 63]
# image # 10343, layer # relu has outliers [12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 10385, layer # relu has outliers [15 16 19 24 31 35 41 46 47 48 49 57 60 63]
# image # 10398, layer # relu has outliers [ 9 15 16 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 10417, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 10418, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 10485, layer # relu has outliers [15 16 31 34 35 41 45 46 47 49 57 60 63]
# image # 10496, layer # relu has outliers [ 4 12 15 16 23 31 35 41 46 47 48 49 50 57 60 63]
# image # 10513, layer # relu has outliers [15 16 24 31 35 41 46 47 48 49 50 57 60 63]
# image # 10524, layer # relu has outliers [ 9 12 15 16 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 10660, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 10781, layer # relu has outliers [15 16 19 31 34 35 41 45 46 47 48 49 57 60 63]
# image # 10817, layer # relu has outliers [15 16 19 31 34 35 41 46 47 49 57 60 63]
# image # 10818, layer # relu has outliers [ 9 12 15 16 19 23 31 35 41 45 46 47 48 49 50 57 60 63]
# image # 10821, layer # relu has outliers [ 9 15 16 19 31 34 35 41 45 46 47 49 57 60 63]
# image # 10946, layer # relu has outliers [15 16 31 35 41 45 46 47 49 57 63]
# layer layer1.0.relu
# image # 3, layer # layer1.0.relu has outliers [ 9 12 16 19 23 25 45 46 47 48 50]
# image # 19, layer # layer1.0.relu has outliers [12 16 19 23 46 47 48 50 57]
# image # 134, layer # layer1.0.relu has outliers [ 9 12 16 19 23 25 35 41 45 46 47 48 50 57]
# image # 171, layer # layer1.0.relu has outliers [15 16 19 23 39 41 45 48 50 57]
# image # 224, layer # layer1.0.relu has outliers [12 16 19 23 25 31 34 41 46 47 48 50 57]
# image # 283, layer # layer1.0.relu has outliers [16 19 23 25 35 39 41 45 47 48 57]
# image # 323, layer # layer1.0.relu has outliers [15 16 19 23 24 35 41 45 47 48 50 57]
# image # 349, layer # layer1.0.relu has outliers [12 16 19 23 41 45 46 48 50]
# image # 384, layer # layer1.0.relu has outliers [17 19 23 25 35 39 41 43 45 48 57]
# image # 399, layer # layer1.0.relu has outliers [16 17 19 23 24 35 39 41 43 45 48 57]
# image # 460, layer # layer1.0.relu has outliers [12 16 19 23 25 41 45 46 47 48 50 57]
# image # 540, layer # layer1.0.relu has outliers [12 16 19 23 25 31 34 35 41 46 47 48 50 57]
# image # 551, layer # layer1.0.relu has outliers [16 19 23 25 35 41 45 46 48 57]
# image # 579, layer # layer1.0.relu has outliers [12 16 19 23 41 45 46 47 48 50 57]
# image # 594, layer # layer1.0.relu has outliers [12 16 19 23 41 45 46 47 48 50]
# image # 736, layer # layer1.0.relu has outliers [12 16 19 23 35 41 45 46 48 50 57]
# image # 738, layer # layer1.0.relu has outliers [16 19 23 25 35 39 41 43 45 47 57]
# image # 739, layer # layer1.0.relu has outliers [12 16 19 23 45 46 47 48 50]
# image # 751, layer # layer1.0.relu has outliers [16 17 19 23 25 35 39 41 43 45 48 57]
# image # 762, layer # layer1.0.relu has outliers [15 16 19 23 25 34 41 46 47 48 50 57 60]
# image # 780, layer # layer1.0.relu has outliers [12 16 19 23 25 35 41 45 46 47 48 50 57]
# image # 786, layer # layer1.0.relu has outliers [15 16 17 19 23 25 35 39 41 43 45 47 48 49 57]
# image # 818, layer # layer1.0.relu has outliers [15 16 19 23 35 41 45 46 47 48 50 57]
# image # 821, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 47 48 50 57]
# image # 1134, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 48 50 57]
# image # 1176, layer # layer1.0.relu has outliers [16 19 23 25 35 39 41 45 47 48 57]
# image # 1180, layer # layer1.0.relu has outliers [16 19 23 25 41 45 46 47 48 50 57]
# image # 1195, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 47 48 50 57]
# image # 1207, layer # layer1.0.relu has outliers [15 16 19 23 25 31 34 35 41 45 46 47 48 57]
# image # 1250, layer # layer1.0.relu has outliers [15 16 19 23 25 34 35 41 45 46 47 48 50 57]
# image # 1285, layer # layer1.0.relu has outliers [15 16 19 23 24 41 43 45 46 47 48 49 50 57]
# image # 1296, layer # layer1.0.relu has outliers [16 19 23 25 34 35 36 41 45 46 47 48 57]
# image # 1382, layer # layer1.0.relu has outliers [12 15 16 19 23 34 41 45 46 47 48 50 57]
# image # 1457, layer # layer1.0.relu has outliers [15 16 19 23 25 34 35 41 45 46 47 48 50 57]
# image # 1487, layer # layer1.0.relu has outliers [16 19 23 24 41 45 46 48 50 57]
# image # 1520, layer # layer1.0.relu has outliers [15 16 19 23 25 34 41 46 47 48 50 57]
# image # 1545, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 48 50 57]
# image # 1724, layer # layer1.0.relu has outliers [12 16 19 23 25 45 46 47 48 50]
# image # 1777, layer # layer1.0.relu has outliers [15 16 19 23 41 45 46 47 48 50 57 60]
# image # 1797, layer # layer1.0.relu has outliers [16 19 23 41 45 46 47 48 50 57]
# image # 1864, layer # layer1.0.relu has outliers [16 19 23 41 45 46 48 50 57]
# image # 1912, layer # layer1.0.relu has outliers [12 16 19 23 31 34 46 47 48 50 57]
# image # 1969, layer # layer1.0.relu has outliers [16 19 23 25 35 39 41 43 45 48 57]
# image # 1970, layer # layer1.0.relu has outliers [15 16 19 23 25 34 36 41 43 45 46 47 48 57]
# image # 1983, layer # layer1.0.relu has outliers [15 16 19 23 24 34 35 41 46 47 48 50 57]
# image # 2006, layer # layer1.0.relu has outliers [16 19 23 25 35 41 45 46 47 48 57]
# image # 2012, layer # layer1.0.relu has outliers [15 16 19 23 24 35 39 41 45 47 48 57]
# image # 2117, layer # layer1.0.relu has outliers [17 19 23 35 39 41 43 45 48 57]
# image # 2207, layer # layer1.0.relu has outliers [15 16 19 23 25 35 41 45 46 47 48 50 57]
# image # 2269, layer # layer1.0.relu has outliers [16 19 23 35 41 45 48 55 57]
# image # 2324, layer # layer1.0.relu has outliers [16 19 23 25 41 45 46 47 48 50 57]
# image # 2456, layer # layer1.0.relu has outliers [12 15 16 23 25 31 34 41 45 46 47 48 50 57]
# image # 2491, layer # layer1.0.relu has outliers [16 17 19 23 25 35 39 41 43 45 48 57]
# image # 2499, layer # layer1.0.relu has outliers [16 19 23 24 41 43 45 46 48 50 57]
# image # 2524, layer # layer1.0.relu has outliers [16 17 19 23 24 35 39 41 43 45 48 57]
# image # 2530, layer # layer1.0.relu has outliers [16 19 23 35 41 45 48 50 57]
# image # 2635, layer # layer1.0.relu has outliers [16 19 23 45 46 47 48 50]
# image # 2638, layer # layer1.0.relu has outliers [ 9 16 19 23 25 35 41 45 46 47 48 50 57]
# image # 2643, layer # layer1.0.relu has outliers [16 17 19 25 32 35 39 41 43 45 47 48 57]
# image # 2683, layer # layer1.0.relu has outliers [16 19 23 34 35 41 45 46 47 48 50 57]
# image # 2727, layer # layer1.0.relu has outliers [12 15 16 23 25 31 34 46 47 48 50 60]
# image # 2817, layer # layer1.0.relu has outliers [16 19 23 25 35 41 45 47 48 50 57]
# image # 2919, layer # layer1.0.relu has outliers [15 16 19 23 24 41 45 46 48 50 57]
# image # 2931, layer # layer1.0.relu has outliers [ 9 12 16 19 23 25 41 45 46 47 48 50 57]
# image # 2937, layer # layer1.0.relu has outliers [12 16 19 23 34 35 41 45 46 47 48 50 57]
# image # 2942, layer # layer1.0.relu has outliers [15 19 24 43 45 48 50 57]
# image # 2962, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 48 50 57]
# image # 2975, layer # layer1.0.relu has outliers [12 15 16 19 23 25 45 46 47 48 50 57 60]
# image # 2999, layer # layer1.0.relu has outliers [12 16 19 23 31 34 35 41 46 47 48 50 57]
# image # 3038, layer # layer1.0.relu has outliers [15 16 17 19 24 25 35 39 41 43 45 47 48 49 57]
# image # 3065, layer # layer1.0.relu has outliers [12 15 16 23 25 36 45 46 47 48 50]
# image # 3147, layer # layer1.0.relu has outliers [15 16 19 23 25 31 34 36 41 45 46 47 48 57]
# image # 3149, layer # layer1.0.relu has outliers [16 19 23 34 35 41 45 47 48 57]
# image # 3155, layer # layer1.0.relu has outliers [15 16 19 23 35 45 46 47 48 50 57]
# image # 3187, layer # layer1.0.relu has outliers [16 19 23 41 45 46 47 48 50 57]
# image # 3188, layer # layer1.0.relu has outliers [15 16 19 23 31 34 41 46 47 48 50 57]
# image # 3278, layer # layer1.0.relu has outliers [16 19 23 34 35 41 45 46 47 48 50 57]
# image # 3285, layer # layer1.0.relu has outliers [15 16 19 23 34 35 41 45 46 47 48 57]
# image # 3287, layer # layer1.0.relu has outliers [16 19 23 24 35 39 41 45 47 48 50 57]
# image # 3394, layer # layer1.0.relu has outliers [12 15 16 19 23 25 41 45 46 47 48 50 57 60]
# image # 3395, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 47 48 50 57]
# image # 3507, layer # layer1.0.relu has outliers [16 17 19 23 35 39 41 43 45 48 57]
# image # 3643, layer # layer1.0.relu has outliers [12 16 19 23 25 34 35 41 45 46 47 48 50 57]
# image # 3749, layer # layer1.0.relu has outliers [ 9 12 16 19 23 35 41 45 46 47 48 50]
# image # 3811, layer # layer1.0.relu has outliers [16 17 19 23 35 39 41 43 45 48 57]
# image # 3846, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 48 57]
# image # 3929, layer # layer1.0.relu has outliers [17 19 23 24 35 39 41 43 45 48 57]
# image # 3953, layer # layer1.0.relu has outliers [16 19 23 24 35 41 45 46 47 48 50 57]
# image # 4002, layer # layer1.0.relu has outliers [16 19 23 35 41 43 45 47 48 57]
# image # 4014, layer # layer1.0.relu has outliers [ 1 12 15 16 23 46 47 48 50 60]
# image # 4064, layer # layer1.0.relu has outliers [16 19 23 25 35 41 45 46 47 48 50 57]
# image # 4078, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 48 50 57]
# image # 4100, layer # layer1.0.relu has outliers [15 16 19 23 24 35 39 41 43 45 47 48 57]
# image # 4115, layer # layer1.0.relu has outliers [16 17 19 23 32 35 39 41 43 45 48 57]
# image # 4155, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 48 50 57]
# image # 4256, layer # layer1.0.relu has outliers [12 16 19 23 46 47 48 50]
# image # 4317, layer # layer1.0.relu has outliers [12 16 19 23 35 41 45 46 47 48 50]
# image # 4342, layer # layer1.0.relu has outliers [16 19 23 34 35 41 45 46 47 48 50 57]
# image # 4365, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 48 50 57]
# image # 4374, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 47 48 50 57]
# image # 4388, layer # layer1.0.relu has outliers [ 9 16 19 23 35 41 45 46 48 50 57]
# image # 4452, layer # layer1.0.relu has outliers [16 17 19 23 35 39 41 43 45 48 57]
# image # 4484, layer # layer1.0.relu has outliers [15 16 19 23 35 41 43 45 47 48 57]
# image # 4486, layer # layer1.0.relu has outliers [16 19 23 35 41 45 47 48 50 57]
# image # 4509, layer # layer1.0.relu has outliers [ 9 12 15 16 23 45 46 47 48 50]
# image # 4533, layer # layer1.0.relu has outliers [12 15 16 19 23 41 45 46 47 48 50 57]
# image # 4647, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 47 48 50 57]
# image # 4785, layer # layer1.0.relu has outliers [16 19 23 41 45 46 47 48 50 57]
# image # 4792, layer # layer1.0.relu has outliers [12 16 19 23 45 46 47 48 50 57]
# image # 4855, layer # layer1.0.relu has outliers [15 16 17 19 39 41 43 45 48 50 57]
# image # 4933, layer # layer1.0.relu has outliers [17 19 23 35 39 41 43 45 48 57 59]
# image # 4980, layer # layer1.0.relu has outliers [16 19 23 41 45 46 47 48 50 57]
# image # 5018, layer # layer1.0.relu has outliers [16 19 23 25 31 34 35 41 45 46 47 48 57]
# image # 5049, layer # layer1.0.relu has outliers [12 15 16 19 23 41 45 46 47 48 50 57]
# image # 5193, layer # layer1.0.relu has outliers [12 16 19 23 35 41 45 46 48 50 57]
# image # 5217, layer # layer1.0.relu has outliers [12 15 16 19 23 35 41 45 46 47 48 50]
# image # 5268, layer # layer1.0.relu has outliers [12 16 23 25 35 41 45 46 47 48 50 57]
# image # 5341, layer # layer1.0.relu has outliers [12 16 19 23 34 35 41 45 46 48 50 57]
# image # 5392, layer # layer1.0.relu has outliers [12 16 19 23 25 34 45 46 47 48 50 57]
# image # 5434, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 47 48 50 57]
# image # 5490, layer # layer1.0.relu has outliers [15 16 19 23 41 46 47 48 50 57]
# image # 5504, layer # layer1.0.relu has outliers [16 19 23 25 34 35 41 45 46 47 48 57]
# image # 5518, layer # layer1.0.relu has outliers [16 19 23 41 45 46 47 48 50 57]
# image # 5533, layer # layer1.0.relu has outliers [12 15 16 23 31 34 35 36 41 45 46 47 48 50]
# image # 5576, layer # layer1.0.relu has outliers [16 19 23 25 34 35 41 45 46 47 48 50 57]
# image # 5589, layer # layer1.0.relu has outliers [16 19 23 25 35 39 41 45 48 57]
# image # 5615, layer # layer1.0.relu has outliers [16 19 23 24 45 46 47 48 50 57]
# image # 5619, layer # layer1.0.relu has outliers [12 16 19 23 45 46 47 48 50]
# image # 5633, layer # layer1.0.relu has outliers [16 19 23 25 35 41 45 48 50 57]
# image # 5682, layer # layer1.0.relu has outliers [16 19 23 45 46 47 48 50]
# image # 5710, layer # layer1.0.relu has outliers [15 16 19 23 41 45 46 47 48 50 57]
# image # 5805, layer # layer1.0.relu has outliers [15 16 19 23 35 41 45 46 47 48 50 57]
# image # 5958, layer # layer1.0.relu has outliers [16 19 23 35 39 41 43 45 47 48 57]
# image # 5988, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 48 50 57]
# image # 6046, layer # layer1.0.relu has outliers [16 17 19 35 39 41 43 45 47 49 57]
# image # 6114, layer # layer1.0.relu has outliers [16 19 23 25 35 36 39 41 43 45 47 57 59]
# image # 6124, layer # layer1.0.relu has outliers [12 16 19 23 25 35 41 43 45 47 48 50 57]
# image # 6237, layer # layer1.0.relu has outliers [16 19 23 34 35 39 41 45 46 47 48 50 57]
# image # 6249, layer # layer1.0.relu has outliers [12 16 19 23 41 45 46 47 48 50]
# image # 6285, layer # layer1.0.relu has outliers [16 19 23 25 34 35 41 45 46 47 48 50 57]
# image # 6346, layer # layer1.0.relu has outliers [12 16 19 23 45 46 47 48 50 57]
# image # 6388, layer # layer1.0.relu has outliers [16 19 23 25 35 39 41 43 45 48 57]
# image # 6395, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 48 50 57]
# image # 6426, layer # layer1.0.relu has outliers [16 19 23 34 35 41 45 46 47 48 50 57]
# image # 6436, layer # layer1.0.relu has outliers [16 17 19 23 35 39 41 43 45 48 57]
# image # 6499, layer # layer1.0.relu has outliers [12 16 19 23 35 41 45 46 47 48 50 57]
# image # 6513, layer # layer1.0.relu has outliers [ 9 12 16 19 23 41 45 46 47 48 50]
# image # 6600, layer # layer1.0.relu has outliers [ 9 12 16 19 23 35 41 45 46 48 50 57]
# image # 6614, layer # layer1.0.relu has outliers [15 16 19 23 25 35 41 43 45 47 57]
# image # 6747, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 48 50 57]
# image # 6751, layer # layer1.0.relu has outliers [16 19 23 25 35 39 41 43 45 47 48 57]
# image # 6820, layer # layer1.0.relu has outliers [16 19 23 35 39 41 43 45 48 50 57]
# image # 6824, layer # layer1.0.relu has outliers [15 16 19 23 25 41 45 46 47 48 50 57]
# image # 6908, layer # layer1.0.relu has outliers [15 16 19 23 34 41 46 47 48 50 57 60]
# image # 6931, layer # layer1.0.relu has outliers [12 16 19 23 25 41 45 46 47 48 50 57]
# image # 6964, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 48 50 57]
# image # 7055, layer # layer1.0.relu has outliers [16 19 23 35 39 41 43 45 47 48 57]
# image # 7114, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 46 48 57]
# image # 7139, layer # layer1.0.relu has outliers [15 16 19 23 25 31 34 41 45 46 47 48 50 57]
# image # 7164, layer # layer1.0.relu has outliers [15 16 19 24 25 34 35 39 41 43 45 47 48 49 57]
# image # 7189, layer # layer1.0.relu has outliers [16 19 23 24 41 45 46 48 50 57]
# image # 7190, layer # layer1.0.relu has outliers [12 15 16 19 23 25 46 47 48 50 57 60]
# image # 7195, layer # layer1.0.relu has outliers [16 19 23 45 46 48 50 57]
# image # 7232, layer # layer1.0.relu has outliers [16 19 23 24 41 45 48 50 57]
# image # 7310, layer # layer1.0.relu has outliers [ 9 12 16 19 23 35 41 45 46 47 48 50]
# image # 7385, layer # layer1.0.relu has outliers [16 19 23 35 41 43 45 48 50 57]
# image # 7416, layer # layer1.0.relu has outliers [16 19 23 35 41 45 47 48 50 57]
# image # 7504, layer # layer1.0.relu has outliers [16 19 23 25 41 45 46 47 48 50 57]
# image # 7515, layer # layer1.0.relu has outliers [16 19 23 35 41 45 48 57]
# image # 7659, layer # layer1.0.relu has outliers [ 9 12 16 19 23 41 45 46 48 50]
# image # 7718, layer # layer1.0.relu has outliers [16 19 23 25 34 35 41 45 46 47 48 50 57]
# image # 7725, layer # layer1.0.relu has outliers [16 19 23 35 39 41 43 45 48 50 57]
# image # 7781, layer # layer1.0.relu has outliers [15 16 19 24 46 47 48 50]
# image # 7828, layer # layer1.0.relu has outliers [15 16 23 46 47 48 50]
# image # 7847, layer # layer1.0.relu has outliers [15 16 19 23 35 41 45 47 48 50 57]
# image # 7878, layer # layer1.0.relu has outliers [12 16 19 23 25 34 35 41 45 46 47 48 50 57]
# image # 7962, layer # layer1.0.relu has outliers [17 19 23 35 39 41 43 45 48 57]
# image # 7969, layer # layer1.0.relu has outliers [17 19 23 35 39 41 43 45 48 57]
# image # 8011, layer # layer1.0.relu has outliers [15 16 19 23 34 35 41 46 47 48 50 57]
# image # 8014, layer # layer1.0.relu has outliers [16 19 23 41 45 46 47 48 50 57]
# image # 8059, layer # layer1.0.relu has outliers [16 19 23 34 35 41 45 46 47 48 50 57]
# image # 8101, layer # layer1.0.relu has outliers [ 9 12 16 19 23 25 35 41 45 46 48 50 57]
# image # 8122, layer # layer1.0.relu has outliers [12 16 19 23 25 34 35 41 46 47 48 50 57]
# image # 8161, layer # layer1.0.relu has outliers [16 19 23 25 35 39 41 43 45 48 57]
# image # 8166, layer # layer1.0.relu has outliers [12 16 19 23 25 41 45 46 47 48 50 57]
# image # 8174, layer # layer1.0.relu has outliers [12 15 16 19 23 25 34 41 45 46 47 48 50 57]
# image # 8198, layer # layer1.0.relu has outliers [16 19 23 25 35 41 45 46 48 50 55 57]
# image # 8342, layer # layer1.0.relu has outliers [16 19 23 25 35 41 45 46 47 48 50 57]
# image # 8353, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 47 48 50 57]
# image # 8390, layer # layer1.0.relu has outliers [17 19 23 35 39 41 43 45 48 57]
# image # 8414, layer # layer1.0.relu has outliers [16 19 23 35 39 41 43 45 47 48 57]
# image # 8483, layer # layer1.0.relu has outliers [12 16 19 23 41 45 46 48 50 57]
# image # 8535, layer # layer1.0.relu has outliers [12 16 19 23 25 41 45 46 48 50 57]
# image # 8544, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 47 48 50 57]
# image # 8576, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 48 50 57]
# image # 8612, layer # layer1.0.relu has outliers [12 16 19 23 41 45 46 47 48 50 57]
# image # 8670, layer # layer1.0.relu has outliers [ 9 15 16 19 23 25 41 45 46 47 48 50 57]
# image # 8690, layer # layer1.0.relu has outliers [12 16 23 46 47 48 50]
# image # 8717, layer # layer1.0.relu has outliers [ 9 12 16 19 23 35 36 41 45 46 48 50 57]
# image # 8742, layer # layer1.0.relu has outliers [ 9 12 16 23 25 45 46 47 48 50]
# image # 8746, layer # layer1.0.relu has outliers [16 19 23 46 47 48 50]
# image # 8755, layer # layer1.0.relu has outliers [16 17 19 23 35 39 41 43 45 48 57]
# image # 8760, layer # layer1.0.relu has outliers [15 16 19 23 35 39 41 43 45 47 57]
# image # 8800, layer # layer1.0.relu has outliers [15 16 19 23 25 35 39 41 43 45 47 48 57]
# image # 8882, layer # layer1.0.relu has outliers [12 16 19 23 41 45 46 48 50 57]
# image # 8909, layer # layer1.0.relu has outliers [16 19 23 25 35 41 45 46 48 50 57]
# image # 8933, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 47 48 50 57]
# image # 9102, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 48 50 57]
# image # 9111, layer # layer1.0.relu has outliers [16 19 23 25 35 39 41 45 48 57]
# image # 9126, layer # layer1.0.relu has outliers [17 19 23 25 35 39 41 43 45 48 49 57]
# image # 9173, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 48 50 57]
# image # 9208, layer # layer1.0.relu has outliers [16 19 23 24 41 43 45 48 50 57]
# image # 9287, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 48 50 57]
# image # 9320, layer # layer1.0.relu has outliers [15 16 19 23 24 35 41 45 48 50 57]
# image # 9334, layer # layer1.0.relu has outliers [ 9 12 16 19 23 45 46 47 48 50]
# image # 9339, layer # layer1.0.relu has outliers [12 16 19 23 45 46 47 48 50]
# image # 9388, layer # layer1.0.relu has outliers [15 16 19 23 25 35 41 45 46 47 48 50 57]
# image # 9398, layer # layer1.0.relu has outliers [16 19 23 35 41 45 48 50 57]
# image # 9544, layer # layer1.0.relu has outliers [ 9 12 16 19 23 41 45 46 48 50]
# image # 9585, layer # layer1.0.relu has outliers [12 16 19 23 41 46 47 48 50 57]
# image # 9611, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 47 48 50 57]
# image # 9655, layer # layer1.0.relu has outliers [16 19 23 41 45 46 47 48 50 57]
# image # 9690, layer # layer1.0.relu has outliers [12 16 19 23 35 41 45 46 47 48 50 57]
# image # 9716, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 47 48 50 57]
# image # 9721, layer # layer1.0.relu has outliers [15 16 19 23 34 35 41 45 46 47 48 50 57]
# image # 9774, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 47 48 50 57]
# image # 9807, layer # layer1.0.relu has outliers [16 19 23 41 45 46 47 48 50 57]
# image # 9870, layer # layer1.0.relu has outliers [12 16 19 23 41 45 46 48 50 57]
# image # 9914, layer # layer1.0.relu has outliers [16 19 23 25 35 41 45 48 57]
# image # 9952, layer # layer1.0.relu has outliers [15 16 19 23 34 45 46 47 48 50 57]
# image # 10053, layer # layer1.0.relu has outliers [16 19 23 25 35 41 43 45 47 48 57]
# image # 10063, layer # layer1.0.relu has outliers [16 19 23 34 35 41 45 46 47 48 50 57]
# image # 10144, layer # layer1.0.relu has outliers [16 19 23 35 39 41 45 47 48 57]
# image # 10193, layer # layer1.0.relu has outliers [15 16 19 23 24 41 45 46 48 50 57]
# image # 10225, layer # layer1.0.relu has outliers [16 17 19 23 25 35 39 41 43 45 48 57]
# image # 10257, layer # layer1.0.relu has outliers [12 15 16 23 34 45 46 47 48 50]
# image # 10259, layer # layer1.0.relu has outliers [16 19 23 35 41 45 48 50 57]
# image # 10269, layer # layer1.0.relu has outliers [16 19 23 25 34 35 41 45 46 47 48 50 57]
# image # 10274, layer # layer1.0.relu has outliers [12 16 19 23 25 35 41 45 46 47 48 50 57]
# image # 10296, layer # layer1.0.relu has outliers [12 16 19 23 25 35 41 45 46 48 50 57]
# image # 10297, layer # layer1.0.relu has outliers [12 15 16 23 46 47 48 50]
# image # 10338, layer # layer1.0.relu has outliers [15 16 19 23 25 41 45 46 47 48 50 57]
# image # 10343, layer # layer1.0.relu has outliers [12 15 16 19 23 41 45 46 47 48 50 57]
# image # 10385, layer # layer1.0.relu has outliers [16 19 23 24 45 46 48 50 57]
# image # 10398, layer # layer1.0.relu has outliers [15 16 19 23 35 41 45 46 47 48 50 57]
# image # 10417, layer # layer1.0.relu has outliers [16 19 23 25 35 41 45 46 47 48 50 57]
# image # 10418, layer # layer1.0.relu has outliers [15 16 19 23 25 35 41 43 45 47 48 49 57]
# image # 10485, layer # layer1.0.relu has outliers [16 19 23 25 35 41 45 47 48 57]
# image # 10496, layer # layer1.0.relu has outliers [ 9 12 16 23 25 36 45 46 47 48 50]
# image # 10513, layer # layer1.0.relu has outliers [16 19 23 24 45 48 50]
# image # 10524, layer # layer1.0.relu has outliers [ 9 12 16 19 23 25 35 36 41 45 46 47 48 50 57]
# image # 10660, layer # layer1.0.relu has outliers [16 19 23 35 41 45 46 48 50 57]
# image # 10686, layer # layer1.0.relu has outliers [ 4 16 19 23 25 35 36 41 45 48 55 57]
# image # 10781, layer # layer1.0.relu has outliers [15 16 19 23 35 41 43 45 47 48 50 57]
# image # 10817, layer # layer1.0.relu has outliers [19 23 35 39 41 45 47 48 57]
# image # 10818, layer # layer1.0.relu has outliers [ 9 12 16 19 23 25 35 41 45 46 47 48 50 57]
# image # 10821, layer # layer1.0.relu has outliers [15 16 19 23 35 41 43 45 47 48 49 57]
# image # 10946, layer # layer1.0.relu has outliers [16 17 19 35 39 41 43 45 49 57]
# layer layer1.1.relu
# image # 3, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50 57]
# image # 19, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50 57]
# image # 134, layer # layer1.1.relu has outliers [ 9 19 29 35 39 48 50 57 59]
# image # 171, layer # layer1.1.relu has outliers [ 9 17 19 29 32 35 39 48 50 57]
# image # 224, layer # layer1.1.relu has outliers [19 29 32 35 39 48 50 57]
# image # 283, layer # layer1.1.relu has outliers [ 9 17 19 35 39 48]
# image # 323, layer # layer1.1.relu has outliers [ 8 19 24 29 35 39 48 50 57]
# image # 349, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50 57 61]
# image # 384, layer # layer1.1.relu has outliers [ 9 17 19 32 35 39 43 48 51]
# image # 399, layer # layer1.1.relu has outliers [10 17 19 29 32 35 39 48 51]
# image # 460, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50 57]
# image # 540, layer # layer1.1.relu has outliers [19 29 35 39 48 50 57]
# image # 551, layer # layer1.1.relu has outliers [ 9 17 19 29 35 39 45 48]
# image # 579, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50 57]
# image # 594, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50 57 61]
# image # 736, layer # layer1.1.relu has outliers [19 29 35 39 48 50 57]
# image # 738, layer # layer1.1.relu has outliers [ 9 17 19 29 35 39 48]
# image # 739, layer # layer1.1.relu has outliers [ 8 17 19 29 32 35 39 48 50 57 61]
# image # 751, layer # layer1.1.relu has outliers [ 8  9 17 19 35 39 48 51]
# image # 762, layer # layer1.1.relu has outliers [19 29 34 35 39 48 50 57]
# image # 780, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50 57 61]
# image # 786, layer # layer1.1.relu has outliers [ 8  9 17 19 35 39 43 48 57]
# image # 818, layer # layer1.1.relu has outliers [17 19 29 32 35 39 48 50 57]
# image # 821, layer # layer1.1.relu has outliers [ 9 17 19 29 35 39 48 50 57]
# image # 1134, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50 57 61]
# image # 1176, layer # layer1.1.relu has outliers [17 19 29 35 39 48]
# image # 1180, layer # layer1.1.relu has outliers [ 8 17 19 24 29 35 39 48 50 57]
# image # 1195, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50 57]
# image # 1207, layer # layer1.1.relu has outliers [19 31 34 35 48 51 57 59 63]
# image # 1250, layer # layer1.1.relu has outliers [ 9 19 29 34 35 48 57 59]
# image # 1285, layer # layer1.1.relu has outliers [15 17 19 24 39 43 48 50]
# image # 1296, layer # layer1.1.relu has outliers [ 9 19 32 35 36 39 48 51 59]
# image # 1382, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50 57]
# image # 1457, layer # layer1.1.relu has outliers [ 9 19 29 35 39 48 50 57]
# image # 1487, layer # layer1.1.relu has outliers [19 24 29 35 39 48 50 57]
# image # 1520, layer # layer1.1.relu has outliers [15 16 19 29 39 48 50 57]
# image # 1545, layer # layer1.1.relu has outliers [ 8  9 17 19 29 35 39 48 57]
# image # 1724, layer # layer1.1.relu has outliers [ 8 17 19 29 32 35 39 48 50 57 59]
# image # 1777, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50 57]
# image # 1797, layer # layer1.1.relu has outliers [19 29 35 39 48 50 57 61]
# image # 1864, layer # layer1.1.relu has outliers [17 19 24 29 35 39 48 50 57 61]
# image # 1912, layer # layer1.1.relu has outliers [ 8 19 24 29 35 39 48 50 57]
# image # 1969, layer # layer1.1.relu has outliers [ 9 17 19 35 39 48 57]
# image # 1970, layer # layer1.1.relu has outliers [ 9 19 31 32 34 36 43 45 48 51 59]
# image # 1983, layer # layer1.1.relu has outliers [19 24 29 35 39 48 51 57]
# image # 2006, layer # layer1.1.relu has outliers [ 9 17 19 29 35 39 48 57]
# image # 2012, layer # layer1.1.relu has outliers [17 19 24 29 32 35 39 48]
# image # 2117, layer # layer1.1.relu has outliers [ 9 17 19 32 35 39 48 51 57]
# image # 2207, layer # layer1.1.relu has outliers [19 29 35 39 48 50 57]
# image # 2269, layer # layer1.1.relu has outliers [ 9 19 29 35 39 48 50 57]
# image # 2324, layer # layer1.1.relu has outliers [19 29 35 39 48 57]
# image # 2456, layer # layer1.1.relu has outliers [31 34 35 45 48 50 57 63]
# image # 2491, layer # layer1.1.relu has outliers [ 8  9 17 19 32 35 39 48]
# image # 2499, layer # layer1.1.relu has outliers [19 24 29 39 48 50 57]
# image # 2524, layer # layer1.1.relu has outliers [ 8 10 17 19 29 32 35 39 48 51]
# image # 2530, layer # layer1.1.relu has outliers [ 8  9 17 19 29 35 39 48 57]
# image # 2635, layer # layer1.1.relu has outliers [ 8 17 19 24 29 35 39 48 50 57 61]
# image # 2638, layer # layer1.1.relu has outliers [ 8  9 19 29 35 39 48 50 57]
# image # 2643, layer # layer1.1.relu has outliers [ 8 15 17 19 32 35 39 48 51]
# image # 2683, layer # layer1.1.relu has outliers [ 8 19 35 48 50 57]
# image # 2727, layer # layer1.1.relu has outliers [15 29 39 48 50 57]
# image # 2817, layer # layer1.1.relu has outliers [ 9 17 19 29 32 35 39 48 50 57]
# image # 2919, layer # layer1.1.relu has outliers [ 8 19 24 29 32 35 39 48 50 57]
# image # 2931, layer # layer1.1.relu has outliers [ 8  9 17 19 29 35 39 48 50 57 59]
# image # 2937, layer # layer1.1.relu has outliers [ 8 19 29 35 39 48 50 57]
# image # 2942, layer # layer1.1.relu has outliers [10 15 19 24 29 39 48 50]
# image # 2962, layer # layer1.1.relu has outliers [17 19 29 35 39 48 50]
# ...
#  208 211 219 222 223 224 225 229 236 238 240 251 254 264 266 275 280 290
#  297 303 308 314 315 328 341 343 355 358 360 369 371 386 405 407 409 412
#  425 434 439 441 445 451 470 472 476 495 497 510 511]
# image # 9655, layer # layer4.2.relu has outliers [  0   3  13  25  34  38  44  55  63  64  72  83  91  96  99 102 105 106
#  108 109 111 118 123 124 125 129 134 138 140 141 149 150 151 154 163 172
#  177 178 179 180 185 188 191 196 197 199 201 208 214 220 223 225 230 236
#  237 242 254 260 264 265 266 275 276 280 281 297 300 303 304 307 308 310
#  321 327 328 337 341 343 347 348 355 356 369 372 386 393 396 407 409 410
#  412 417 425 429 434 438 439 442 444 447 451 455 461 470 471 472 474 480
#  490 497 500 510]
# image # 9690, layer # layer4.2.relu has outliers [  0  25  26  38  44  55  62  63  65  81  83  91  96  99 102 105 106 108
#  109 125 129 134 138 139 140 141 143 144 149 150 151 154 160 163 168 171
#  172 178 179 180 183 185 188 196 197 199 203 208 214 220 223 225 226 230
#  236 237 240 242 250 254 260 266 275 276 280 281 285 290 300 304 307 308
#  310 315 321 327 328 341 343 347 355 356 369 372 386 396 406 407 409 410
#  412 417 426 434 439 442 443 447 451 455 461 470 472 480 486 490 495 497
#  500 508 510]
# image # 9716, layer # layer4.2.relu has outliers [  0   3   4  25  30  38  42  44  51  62  64  65  69  73  74  76  83  86
#   96 102 105 108 109 111 115 118 123 124 129 134 138 143 144 150 154 156
#  160 163 167 171 172 178 180 182 185 196 197 199 204 208 214 217 219 222
#  223 225 230 240 251 254 256 264 266 272 275 281 285 290 297 303 307 308
#  310 314 337 341 343 355 356 358 360 362 369 386 393 396 397 405 406 407
#  410 425 434 439 441 444 445 451 455 461 472 480 487 495 497 500 510 511]
# image # 9721, layer # layer4.2.relu has outliers [ 14  25  33  40  66  73  74  86  96 102 103 104 108 109 110 134 138 143
#  150 167 171 173 180 182 183 185 189 193 196 197 199 203 204 208 223 225
#  229 240 258 266 272 274 281 282 289 290 291 297 308 314 315 321 324 334
#  337 338 343 346 353 358 369 371 374 381 386 390 396 400 402 405 408 409
#  410 425 439 441 447 449 451 455 468 470 472 476 492 508 510]
# image # 9774, layer # layer4.2.relu has outliers [  0   3  73  87  99 102 104 108 109 111 123 129 134 138 150 152 167 182
#  185 197 203 204 208 211 222 225 230 254 266 289 297 303 306 307 360 371
#  385 386 405 407 410 415 425 439 441 455 472 476 495 497]
# image # 9807, layer # layer4.2.relu has outliers [  6  10  13  23  35  38  40  62  63  71  73  99 102 105 106 109 125 127
#  134 138 149 150 152 154 156 167 172 177 181 199 204 211 220 230 248 256
#  260 264 274 281 282 285 287 288 314 363 371 378 382 399 405 407 408 415
#  425 432 444 455 476 491]
# image # 9870, layer # layer4.2.relu has outliers [  0   3  30  34  38  40  42  47  50  55  62  63  73  74  76  81  83  96
#  102 105 106 108 109 111 123 125 129 134 138 143 150 154 156 167 169 172
#  177 178 180 181 182 185 188 196 197 199 203 208 211 214 220 222 223 225
#  228 230 240 251 256 264 266 275 280 281 285 289 290 294 307 309 310 314
#  315 321 327 337 341 343 355 358 369 371 386 405 406 409 410 412 415 426
#  434 439 441 445 447 451 455 461 467 470 472 480 489 490 495 498 500 510]
# image # 9914, layer # layer4.2.relu has outliers [  0   3   4  13  25  26  34  44  55  59  64  65  72  77  78  81  83  86
#   91  96 102 108 109 115 118 119 123 124 129 130 141 143 149 150 151 160
#  163 178 180 183 185 188 191 196 201 203 214 222 224 236 240 241 250 257
#  277 280 285 289 301 307 308 310 315 321 326 327 328 341 343 355 357 369
#  372 378 393 396 406 409 412 417 420 426 429 434 435 439 442 443 445 447
#  451 457 470 480 486 487 490 497 500]
# image # 9952, layer # layer4.2.relu has outliers [  0   3   4  17  25  34  38  42  44  47  51  55  62  64  65  73  76  77
#   80  83  86  91  96 102 108 109 110 111 118 123 125 129 132 134 138 140
#  143 150 151 160 163 167 178 180 181 182 185 188 191 196 197 199 201 203
#  204 208 214 219 222 223 225 236 251 254 264 266 272 275 280 281 285 289
#  290 297 299 303 304 307 308 310 314 315 319 321 327 337 341 343 355 358
#  369 380 386 397 405 406 407 409 410 412 415 420 434 439 442 444 445 447
#  451 455 470 472 474 480 495 497 498 500 510]
# image # 10053, layer # layer4.2.relu has outliers [  0   4  13  27  30  38  48  53  56  62  65  72  73  76  77  80  84 102
#  108 109 111 123 124 125 129 132 138 140 141 143 144 150 155 160 172 178
#  180 183 185 191 194 196 197 199 203 204 208 214 219 222 223 224 225 230
#  236 254 264 266 275 281 290 299 306 307 308 314 315 320 343 344 354 355
#  358 364 369 386 393 397 405 406 407 410 412 419 425 434 445 451 455 457
#  471 472 480 487 495 497 499 510]
# image # 10063, layer # layer4.2.relu has outliers [  0  12  25  26  34  38  43  47  50  62  63  64  68  74  76  77  81  83
#   91  96  99 105 106 115 123 125 129 131 138 139 144 150 156 159 163 166
#  168 171 172 178 181 185 196 201 208 214 217 219 222 223 230 236 237 242
#  251 257 264 272 275 285 299 300 304 309 310 315 318 337 338 340 341 343
#  345 348 349 355 356 358 372 380 386 404 406 407 412 424 434 442 445 455
#  470 472 474 480 495 498 500 510]
# image # 10144, layer # layer4.2.relu has outliers [  3   6  11  13  25  26  34  38  55  64  72  74  77  83  86  91  96 102
#  105 106 108 109 123 124 129 130 134 138 139 143 149 150 152 154 155 156
#  163 167 168 177 178 179 180 185 188 191 196 201 203 208 214 220 222 225
#  236 240 251 256 276 285 287 288 294 307 308 309 310 321 328 356 357 369
#  378 382 393 396 402 404 406 407 408 409 425 426 429 432 442 443 447 451
#  455 461 470 484 485 487 489 490 495 497 500]
# image # 10193, layer # layer4.2.relu has outliers [  0   3  13  25  26  42  47  50  51  62  63  64  69  74  77  80  83  91
#  102 105 109 118 123 124 125 129 138 140 150 152 154 156 157 167 178 185
#  188 191 197 201 208 217 219 222 224 225 232 236 240 251 264 266 275 281
#  285 297 303 306 309 337 338 341 355 358 360 362 378 393 396 399 404 406
#  407 412 425 434 441 442 444 445 449 455 470 472 480 489 495 498 500 510]
# image # 10225, layer # layer4.2.relu has outliers [  6  13  25  26  34  38  44  55  63  64  83  91  96  99 105 106 109 110
#  111 124 125 129 134 138 139 141 149 150 152 154 156 159 160 172 177 178
#  185 191 196 199 201 213 214 220 236 237 254 256 260 264 265 272 275 276
#  281 285 287 288 294 297 300 303 304 309 310 314 327 328 337 341 345 355
#  356 358 378 385 393 396 407 408 410 415 425 426 429 434 442 444 447 455
#  461 477 480 484 487 490 498 500]
# image # 10257, layer # layer4.2.relu has outliers [  0  17  25  40  42  47  51  73  76  86  87  96 102 104 110 111 123 138
#  143 150 167 171 180 182 185 196 197 199 203 204 208 211 214 217 219 222
#  223 225 228 229 230 232 251 264 266 275 281 282 289 303 307 308 314 315
#  337 338 343 355 358 371 380 386 399 405 406 407 410 415 425 439 441 445
#  451 455 470 472 476 480 495 510]
# image # 10259, layer # layer4.2.relu has outliers [  4  12  13  15  25  26  39  49  51  59  64  67  69  72  77  81  83  91
#  105 115 124 131 135 139 149 155 163 166 175 179 202 214 224 226 235 236
#  237 259 260 269 272 276 301 304 310 318 321 324 328 335 337 338 340 348
#  349 372 379 381 393 394 396 404 406 419 424 434 435 442 461 470 477 481
#  482 485 487 508]
# image # 10269, layer # layer4.2.relu has outliers [  0  25  38  40  41  50  60  62  69  73  74  75  76  89 102 103 104 108
#  109 111 121 122 125 138 150 152 157 167 168 171 180 182 185 193 197 199
#  203 204 208 211 214 218 223 228 229 231 233 244 251 253 258 263 266 274
#  281 282 290 302 303 308 314 315 337 338 350 355 358 360 362 371 386 400
#  405 410 415 425 427 436 437 440 441 449 462 470 472 476 482 495 508]
# image # 10274, layer # layer4.2.relu has outliers [  0   3  13  25  34  38  55  63  64  69  74  76  80  83  91  96 101 102
#  103 105 106 108 109 111 114 118 123 125 129 132 134 138 140 143 150 154
#  156 159 163 167 172 177 178 180 185 188 191 197 204 208 214 218 219 220
#  222 223 225 230 240 251 260 264 266 275 281 285 297 303 307 309 310 321
#  328 337 338 341 343 355 358 369 378 386 407 408 409 412 425 434 439 441
#  445 447 455 461 470 472 480 489 490 495 498 500 510]
# image # 10296, layer # layer4.2.relu has outliers [ 11  14  25  40  41  74  75  79 101 103 104 114 117 122 136 138 149 156
#  157 168 171 193 199 202 208 218 223 229 232 233 240 241 249 253 266 269
#  272 274 282 313 315 324 330 334 337 346 350 360 362 372 374 381 389 395
#  396 400 402 408 421 425 436 439 441 449 453 468 470 472 476 477 483 492
#  495 508]
# image # 10297, layer # layer4.2.relu has outliers [ 13  19  23  25  28  34  38  47  55  61  63  64  80  91  93  99 105 106
#  113 121 127 129 131 139 147 148 149 154 156 159 166 172 178 179 181 191
#  201 210 220 226 230 237 245 260 267 276 285 287 288 293 294 300 304 310
#  316 327 328 337 338 341 345 355 356 358 363 377 378 382 393 394 395 396
#  399 404 407 422 426 430 442 444 447 455 461 466 475 477 484 485 490 498
#  500]
# image # 10338, layer # layer4.2.relu has outliers [ 10  33  40  41  66  73  74  91  95  96 101 102 103 104 106 108 109 123
#  127 138 150 152 154 167 170 171 173 180 182 183 185 189 193 197 199 202
#  208 211 220 223 225 229 230 237 240 251 253 256 258 274 280 281 282 289
#  290 307 315 328 330 346 351 353 359 362 371 372 374 378 386 390 396 400
#  402 408 410 415 421 425 437 439 441 447 448 449 461 470 476 495 506]
# image # 10343, layer # layer4.2.relu has outliers [  1  11  25  64  69  74  91 101 102 103 104 108 109 117 122 124 138 149
#  150 152 154 156 167 185 188 191 193 197 208 240 251 256 264 285 303 330
#  357 360 362 369 374 378 381 382 389 393 396 402 408 421 425 436 439 441
#  442 449 468 470 489 495]
# image # 10385, layer # layer4.2.relu has outliers [  3  10  33  40  55  62  66  73  89  91  99 101 102 103 104 105 106 108
#  109 110 125 127 134 138 143 149 150 152 154 167 169 170 173 185 188 189
#  193 197 199 204 208 211 220 222 225 230 245 251 253 256 258 264 266 274
#  285 289 314 321 328 330 338 346 353 362 369 371 374 378 383 390 396 399
#  400 402 405 407 408 415 421 425 439 441 447 448 449 451 472 476 495 506]
# image # 10398, layer # layer4.2.relu has outliers [  3  25  34  36  42  44  47  62  68  74  77  80  83 105 109 124 125 129
#  138 140 150 159 160 166 171 178 180 185 188 191 197 199 201 204 208 214
#  217 219 222 223 225 232 236 240 242 251 254 256 264 266 281 285 303 304
#  306 307 309 314 315 337 341 343 355 357 358 399 404 405 406 407 410 434
#  441 444 445 468 472 480 487 489 495 498 500 510]
# image # 10417, layer # layer4.2.relu has outliers [ 13  19  25  26  28  34  38  55  59  63  64  72  80  83  91  96 105 106
#  109 124 125 129 135 139 141 149 150 154 155 156 163 166 168 172 179 185
#  191 201 214 220 222 226 236 237 260 264 265 272 276 285 303 304 310 316
#  318 337 341 345 348 355 358 378 382 393 396 404 406 408 426 438 442 444
#  445 455 461 485 487 489 500]
# image # 10418, layer # layer4.2.relu has outliers [  0   3   4  13  25  26  27  42  44  48  51  55  59  64  65  72  74  77
#   79  80  83  91  96 102 105 108 109 115 118 124 125 129 138 140 143 150
#  151 155 160 163 167 178 180 185 188 191 194 196 197 201 208 214 219 222
#  224 225 236 240 250 251 264 275 280 281 285 297 301 306 307 310 315 321
#  327 328 341 343 355 358 360 369 378 393 404 406 409 412 425 426 434 439
#  441 442 445 451 455 470 472 480 486 489 495 500 510]
# image # 10485, layer # layer4.2.relu has outliers [  4  12  13  15  25  26  34  37  44  49  55  59  63  64  67  72  77  79
#   81  83 105 115 124 135 139 140 141 142 148 149 155 160 163 168 172 177
#  179 191 201 214 220 224 226 235 236 237 241 259 260 261 265 269 270 275
#  276 301 304 310 318 321 327 328 335 337 341 343 347 348 355 358 373 378
#  382 396 404 406 409 412 419 424 434 435 442 445 461 470 477 485 490]
# image # 10496, layer # layer4.2.relu has outliers [ 14  18  25  33  40  50  69  73  75  89 101 102 103 104 114 122 133 136
#  145 152 157 167 170 171 173 189 193 197 202 204 211 218 223 229 240 249
#  253 256 258 266 274 282 291 313 315 324 330 334 337 346 350 351 353 359
#  362 374 379 381 383 386 390 392 400 402 408 413 421 423 425 427 441 449
#  453 468 472 476 478 492 495 506 508 510]
# image # 10513, layer # layer4.2.relu has outliers [  0   4  34  44  48  55  56  63  64  65  72  76  81  83  96 102 105 108
#  118 123 129 131 132 135 141 142 143 144 151 159 160 163 166 178 179 180
#  184 188 196 199 203 214 219 226 235 236 242 257 259 275 276 280 289 290
#  299 301 304 308 309 310 315 318 319 321 327 328 335 337 338 341 343 348
#  355 358 369 406 409 412 419 420 424 426 434 439 442 447 451 457 461 470
#  474 480 497 498 500]
# image # 10524, layer # layer4.2.relu has outliers [  0  25  30  33  38  41  66  69  76  92 102 103 104 109 111 121 123 125
#  138 140 150 166 168 171 172 180 183 185 193 197 198 199 202 203 204 208
#  214 218 219 220 223 228 229 230 233 238 245 254 266 269 272 274 275 281
#  290 297 303 304 310 314 315 321 324 328 334 337 338 339 343 355 358 372
#  379 386 390 400 405 410 415 419 423 434 437 439 447 455 468 470 472 476
#  477 480 492 498 499 508 510]
# image # 10660, layer # layer4.2.relu has outliers [ 25  40  41  50  60  69  73  74  76  79 102 103 104 106 108 109 117 122
#  123 134 136 138 149 150 167 171 177 180 182 183 185 193 198 202 203 204
#  208 218 220 223 228 229 232 238 240 241 249 253 266 269 272 274 281 282
#  290 297 303 308 311 313 315 324 330 334 337 338 350 353 358 360 362 371
#  372 374 379 381 386 400 402 408 410 415 421 425 436 437 438 439 441 449
#  453 455 468 470 472 476 477 492 495 510 511]
# image # 10686, layer # layer4.2.relu has outliers [  3  25  26  38  55  63  65  77  79  81  83  91  96  99 102 105 108 109
#  111 115 125 129 134 135 138 139 140 143 149 152 154 155 163 167 168 177
#  178 179 180 185 196 197 204 208 214 220 222 224 225 232 237 240 250 254
#  260 264 266 276 281 290 303 307 308 310 328 341 343 348 355 369 378 382
#  385 386 396 404 406 407 408 409 421 425 434 439 442 445 451 455 461 470
#  485 489 490 495 497 500 510]
# image # 10781, layer # layer4.2.relu has outliers [  3   4  13  27  38  44  48  62  65  72  77  80  81  83  86  91  99 102
#  108 109 111 115 124 125 129 134 135 138 140 141 143 144 146 149 150 151
#  152 155 160 163 167 172 178 180 185 188 191 194 196 197 203 204 208 214
#  217 222 223 224 225 232 236 237 240 254 264 266 277 281 285 287 289 290
#  300 301 303 306 307 308 341 343 355 356 369 380 385 386 393 397 406 407
#  410 412 414 425 426 429 434 439 444 445 451 455 457 474 484 487 489 495
#  497 500 510]
# image # 10817, layer # layer4.2.relu has outliers [ 34  39  55  62  63  64  83  85  96  99 105 106 110 113 120 121 127 135
#  139 141 142 143 151 154 156 159 163 166 168 169 177 178 179 180 184 188
#  199 201 203 213 214 216 220 226 230 237 242 245 256 260 265 275 276 285
#  294 300 304 310 314 315 318 321 327 328 338 340 343 348 349 355 356 372
#  377 380 382 396 406 408 412 415 420 424 426 438 442 447 461 470 474 477
#  480 485 490 498]
# image # 10818, layer # layer4.2.relu has outliers [  0   3  17  23  38  42  47  65  73  76  80  87  99 102 104 109 111 123
#  124 125 129 134 138 140 143 150 172 178 180 182 185 191 196 197 199 203
#  208 217 219 222 223 225 228 230 251 254 264 266 275 281 289 290 297 303
#  307 308 314 315 337 343 355 356 358 371 372 386 405 407 410 415 425 434
#  439 441 445 451 455 470 472 476 480 487 495 497 500 510]
# image # 10821, layer # layer4.2.relu has outliers [  3  13  25  38  44  51  62  63  64  73  77  81  83  86  91  96  99 102
#  105 106 108 109 123 124 125 129 134 138 144 149 150 152 154 155 156 167
#  172 178 180 182 183 185 191 196 197 199 201 208 217 222 223 224 225 230
#  232 236 237 240 256 264 266 281 285 287 297 300 303 306 307 308 310 315
#  360 369 380 385 386 393 396 397 406 407 408 410 415 425 426 429 442 444
#  451 455 457 461 470 472 487 495 497 510]
# image # 10946, layer # layer4.2.relu has outliers [  1  11  12  13  15  16  19  25  26  28  37  39  41  43  49  64  67  70
#   77  78  82  83  85  91  97 105 107 112 117 119 124 126 131 135 139 142
#  147 149 155 163 164 168 174 175 179 184 191 201 209 215 224 226 232 235
#  236 237 239 255 261 269 270 271 276 277 279 287 292 310 312 316 317 318
#  324 325 331 335 354 363 366 367 373 375 376 382 389 391 393 394 396 401
#  404 406 408 419 424 431 432 435 437 438 442 458 460 473 477 484 485 487
#  496 501 502]

# %% [markdown]
# ## activation level for the whole test set

# %%
print(num_filters)
# Out:
# {'relu': 64, 'layer1.0.relu': 64, 'layer1.1.relu': 64, 'layer1.2.relu': 64, 'layer2.0.relu': 128, 'layer2.1.relu': 128, 'layer2.2.relu': 128, 'layer2.3.relu': 128, 'layer3.0.relu': 256, 'layer3.1.relu': 256, 'layer3.2.relu': 256, 'layer3.3.relu': 256, 'layer3.4.relu': 256, 'layer3.5.relu': 256, 'layer4.0.relu': 512, 'layer4.1.relu': 512, 'layer4.2.relu': 512}

# %%
# outliers for each layer for each image
z_score_threshold = 2
all_outliers_for_image = {x: {} for x in hooked_layer_names}
num_times_being_outlier = {}

for layer_name in hooked_layer_names:
    print("layer {}".format(layer_name))
    num_times_being_outlier[layer_name] = [0] * num_filters[layer_name]
    for image in range(num_test_images):
        all_outliers_for_image[layer_name][image] = find_outliers_zscore(filtersum_all_images[image][layer_name], threshold=z_score_threshold)
        for k in all_outliers_for_image[layer_name][image]:
            num_times_being_outlier[layer_name][k] += 1
# Out:
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu

# %%
non_activation_ratio_whole_data = {}
ratio_threshold = 0.01
for layer_name in hooked_layer_names:
    print("layer {}".format(layer_name))
    s = {x: num_times_being_outlier[layer_name][x] / num_test_images for x in range(num_filters[layer_name]) if num_times_being_outlier[layer_name][x] > 0}
    non_activation_ratio_whole_data[layer_name] = {k: v for k, v in s.items() if v > ratio_threshold}
    # non_activation_ratio_whole_data[layer_name] = [x/num_test_images for x in num_times_being_outlier[layer_name]]
# Out:
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu

# %%
for layer_name in hooked_layer_names:
    print(layer_name, non_activation_ratio_whole_data[layer_name])
# Out:
# relu {}
# layer1.0.relu {}
# layer1.1.relu {}
# layer1.2.relu {39: 0.028117582618221653}
# layer2.0.relu {}
# layer2.1.relu {1: 0.011411356582070476}
# layer2.2.relu {60: 0.013511046193171445, 105: 0.01314588278254519}
# layer2.3.relu {105: 0.034873105714807374}
# layer3.0.relu {7: 0.012415555961292679, 22: 0.023096585722110645, 144: 0.013237173635201752, 156: 0.01031586635019171, 231: 0.08864341792952346, 241: 0.05513967500456454, 251: 0.02300529486945408}
# layer3.1.relu {18: 0.020996896111009678, 111: 0.08188789483293774, 118: 0.07750593390542268, 144: 0.07960562351652364, 146: 0.15775059339054226, 151: 0.021179477816322803, 162: 0.027204674091656018, 180: 0.23114843892641956, 197: 0.3521088186963666, 205: 0.012598137666605806, 208: 0.01077232061347453, 213: 0.04035055687420121, 229: 0.016341062625524923, 231: 0.05723936461566551, 236: 0.10744933357677561, 251: 0.16359320796056234}
# layer3.2.relu {18: 0.02683951068102976, 118: 0.09905057513237174, 130: 0.013054591929888625, 151: 0.025287566185868176, 162: 0.014697827277706774, 179: 0.010589738908161402, 200: 0.010863611466131094, 205: 0.05632645608909987, 225: 0.05970421763739273, 241: 0.02756983750228227}
# layer3.3.relu {118: 0.0383421581157568, 141: 0.01652364433083805, 156: 0.05970421763739273, 162: 0.011046193171444221, 200: 0.06855943034507943, 205: 0.023279167427423773}
# layer3.4.relu {118: 0.026656928975716632, 134: 0.01077232061347453, 205: 0.024922402775241922, 251: 0.01077232061347453}
# layer3.5.relu {}
# layer4.0.relu {}
# layer4.1.relu {}
# layer4.2.relu {}

# %% [markdown]
# ## non-activation times ratio for different classes, for right/wrong

# %%
# outliers for each layer for each image
z_score_threshold = 2
all_outliers_for_miss_predicated_image = {x: {} for x in hooked_layer_names}
num_times_being_outlier_miss_predicated_images = {}

for layer_name in hooked_layer_names:
    print("layer {}".format(layer_name))
    num_times_being_outlier_miss_predicated_images[layer_name] = [0] * num_filters[layer_name]
    for image in wrong_images:
        all_outliers_for_miss_predicated_image[layer_name][image] = find_outliers_zscore(filtersum_all_images[image][layer_name], threshold=z_score_threshold)
        for k in all_outliers_for_miss_predicated_image[layer_name][image]:
            num_times_being_outlier_miss_predicated_images[layer_name][k] += 1
# Out:
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu

# %%
non_activation_ratio_miss_predicated_image = {}
num_miss_predicated_images = len(wrong_images)

for layer_name in hooked_layer_names:
    print("layer {}".format(layer_name))
    s = {x: num_times_being_outlier_miss_predicated_images[layer_name][x] / num_miss_predicated_images for x in range(num_filters[layer_name]) if num_times_being_outlier_miss_predicated_images[layer_name][x] > 0}
    non_activation_ratio_miss_predicated_image[layer_name] = {k: v for k, v in s.items() if v > ratio_threshold}


for layer_name in hooked_layer_names:
    print(layer_name, non_activation_ratio_miss_predicated_image[layer_name])
# Out:
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu
# relu {}
# layer1.0.relu {}
# layer1.1.relu {}
# layer1.2.relu {39: 0.027131782945736434}
# layer2.0.relu {}
# layer2.1.relu {1: 0.011627906976744186}
# layer2.2.relu {31: 0.011627906976744186, 60: 0.015503875968992248, 105: 0.01937984496124031}
# layer2.3.relu {105: 0.031007751937984496}
# layer3.0.relu {7: 0.011627906976744186, 22: 0.04263565891472868, 144: 0.011627906976744186, 231: 0.05426356589147287, 241: 0.08914728682170543, 251: 0.015503875968992248}
# layer3.1.relu {18: 0.015503875968992248, 111: 0.050387596899224806, 118: 0.07751937984496124, 139: 0.011627906976744186, 144: 0.046511627906976744, 146: 0.12015503875968993, 151: 0.011627906976744186, 162: 0.031007751937984496, 179: 0.011627906976744186, 180: 0.2131782945736434, 197: 0.2596899224806202, 205: 0.015503875968992248, 213: 0.031007751937984496, 231: 0.03875968992248062, 236: 0.06589147286821706, 251: 0.18992248062015504}
# layer3.2.relu {18: 0.027131782945736434, 55: 0.023255813953488372, 118: 0.09689922480620156, 130: 0.01937984496124031, 139: 0.011627906976744186, 151: 0.03875968992248062, 162: 0.011627906976744186, 179: 0.011627906976744186, 200: 0.01937984496124031, 205: 0.05813953488372093, 225: 0.050387596899224806, 241: 0.03488372093023256}
# layer3.3.relu {18: 0.011627906976744186, 118: 0.03875968992248062, 139: 0.01937984496124031, 141: 0.031007751937984496, 156: 0.06201550387596899, 162: 0.011627906976744186, 200: 0.06589147286821706, 205: 0.03875968992248062}
# layer3.4.relu {62: 0.011627906976744186, 118: 0.03488372093023256, 134: 0.011627906976744186, 139: 0.011627906976744186, 205: 0.03488372093023256, 214: 0.011627906976744186}
# layer3.5.relu {}
# layer4.0.relu {}
# layer4.1.relu {}
# layer4.2.relu {}

# %% [markdown]
# ## non-activation times for different classes

# %%
all_outliers_for_classes = {x: {y: {} for y in range(len(classes))} for x in hooked_layer_names}
num_times_being_outlier_classes = {y: {} for y in range(len(classes))}

for layer_name in hooked_layer_names:
    print("layer {}".format(layer_name))
    for cla in range(len(classes)):
        num_times_being_outlier_classes[cla][layer_name] = [0] * num_filters[layer_name]
        for image in image_predictation_result[cla]:
            all_outliers_for_classes[layer_name][cla][image] = find_outliers_zscore(filtersum_all_images[image][layer_name], threshold=z_score_threshold)
            for k in all_outliers_for_classes[layer_name][cla][image]:
                num_times_being_outlier_classes[cla][layer_name][k] += 1
# Out:
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu

# %%
non_activation_ratio_classes = {y: {} for y in range(len(classes))}
ratio_threshold = 0.01
for cla in range(len(classes)):
    for layer_name in hooked_layer_names:
        print("layer {}".format(layer_name))
        s = {x: num_times_being_outlier_classes[cla][layer_name][x] / len(image_predictation_result[cla]) for x in range(num_filters[layer_name]) if num_times_being_outlier_classes[cla][layer_name][x] > 0}
        non_activation_ratio_classes[cla][layer_name] = {k: v for k, v in s.items() if v > ratio_threshold}
# Out:
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu
# layer relu
# layer layer1.0.relu
# layer layer1.1.relu
# layer layer1.2.relu
# layer layer2.0.relu
# layer layer2.1.relu
# layer layer2.2.relu
# layer layer2.3.relu
# layer layer3.0.relu
# layer layer3.1.relu
# layer layer3.2.relu
# layer layer3.3.relu
# layer layer3.4.relu
# layer layer3.5.relu
# layer layer4.0.relu
# layer layer4.1.relu
# layer layer4.2.relu

# %%
# for cla in range(len(classes)):
#     for layer_name in hooked_layer_names:
#         print(layer_name, non_activation_ratio_classes[cla][layer_name])

# less non-activation classes: 0, 2, 4, 8
# many: 1, 3, 5, 6, 7, 9
cla = 9
print('Accuracy of {} : {:.0f}% of {} images'.format(classes[cla], 100 * class_correct[cla] / class_total[cla], class_total[cla]))
for layer_name in hooked_layer_names:
    print(layer_name, non_activation_ratio_classes[cla][layer_name])
# Out:
# Accuracy of Middle Eastern+Male : 68% of 813 images
# relu {}
# layer1.0.relu {}
# layer1.1.relu {}
# layer1.2.relu {39: 0.02706027060270603}
# layer2.0.relu {}
# layer2.1.relu {1: 0.024600246002460024, 80: 0.01107011070110701}
# layer2.2.relu {105: 0.017220172201722016}
# layer2.3.relu {76: 0.012300123001230012, 105: 0.05289052890528905}
# layer3.0.relu {7: 0.028290282902829027, 22: 0.03690036900369004, 118: 0.013530135301353014, 121: 0.015990159901599015, 122: 0.01968019680196802, 144: 0.012300123001230012, 156: 0.01845018450184502, 231: 0.0971709717097171, 241: 0.038130381303813035, 251: 0.028290282902829027}
# layer3.1.relu {18: 0.01845018450184502, 111: 0.11193111931119311, 118: 0.14514145141451415, 144: 0.06888068880688807, 146: 0.2029520295202952, 151: 0.03075030750307503, 161: 0.017220172201722016, 162: 0.023370233702337023, 180: 0.22878228782287824, 197: 0.3997539975399754, 200: 0.012300123001230012, 213: 0.05781057810578106, 225: 0.015990159901599015, 229: 0.013530135301353014, 231: 0.06765067650676507, 236: 0.14883148831488316, 251: 0.2902829028290283}
# layer3.2.relu {18: 0.020910209102091022, 35: 0.03075030750307503, 111: 0.013530135301353014, 118: 0.14022140221402213, 130: 0.01845018450184502, 151: 0.033210332103321034, 159: 0.015990159901599015, 162: 0.013530135301353014, 205: 0.01845018450184502, 225: 0.10947109471094711, 241: 0.02214022140221402}
# layer3.3.relu {118: 0.05781057810578106, 141: 0.01968019680196802, 156: 0.07626076260762607, 162: 0.015990159901599015, 200: 0.055350553505535055, 251: 0.01107011070110701}
# layer3.4.relu {118: 0.03567035670356704, 205: 0.01107011070110701, 251: 0.02952029520295203}
# layer3.5.relu {}
# layer4.0.relu {}
# layer4.1.relu {}
# layer4.2.relu {}
